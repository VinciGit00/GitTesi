# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import seaborn as sns
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
table = read_csv('/content/drive/MyDrive/Thesis/csvs/NNdata14_20.csv')
table.head()
# Out:
#                    Date  IDStation  ... Wind_direction_max  Rainfall
# 0  2014-01-01T00:00:00Z        681  ...              143.0       0.0
# 1  2014-01-02T00:00:00Z        681  ...              153.0       7.8
# 2  2014-01-03T00:00:00Z        681  ...              152.0       0.0
# 3  2014-01-04T00:00:00Z        681  ...              164.0      35.8
# 4  2014-01-05T00:00:00Z        681  ...              136.0      25.0
#
# [5 rows x 28 columns]

# %%
#Moggio = table.loc[table.loc[:,"NameStation"]=="Moggio",:]
Moggio = table.loc[:,["Date","PM25","Ammonia","Wind_speed","Wind_direction","Temperature","Rainfall"]]
#Moggio = Moggio.dropna(how="any")
Moggio = Moggio.reset_index()
Moggio = Moggio.iloc[:-365,:] # we train not using 2020, for now
Moggio.head()
# Out:
#    index                  Date  PM25  ...  Wind_direction  Temperature  Rainfall
# 0      0  2014-01-01T00:00:00Z   7.0  ...            99.0    -0.334965       0.0
# 1      1  2014-01-02T00:00:00Z   5.0  ...           105.0    -0.486111       7.8
# 2      2  2014-01-03T00:00:00Z   4.0  ...           120.0     2.220588       0.0
# 3      3  2014-01-04T00:00:00Z   7.0  ...           175.0     2.137063      35.8
# 4      4  2014-01-05T00:00:00Z   8.0  ...            94.0     2.416084      25.0
#
# [5 rows x 8 columns]

# %%
# sns.lineplot(x='Date', y='PM25', data=Moggio)

# %% [markdown]
# ##Convert series to supervised learning
# ### Activation function = tanh and logistic (s curve)

# %% [markdown]
# ###Conversion Function

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	"""
	Frame a time series as a supervised learning dataset.
	Arguments:
		data: Sequence of observations as a list or NumPy array.
		n_in: Number of lag observations as input (X).
		n_out: Number of observations as output (y).
		dropnan: Boolean whether or not to drop rows with NaN values.
	Returns:
		Pandas DataFrame of series framed for supervised learning.
	"""
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %% [markdown]
# ### Conversion of Moggio

# %%
values = Moggio.iloc[:,2:].values
# ensure all data is float
values = values.astype('float32') #cast in float 32 bit per evitare problemi
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# REPLACING MISSING VALUES WITH -1 !!!
scaled = DataFrame(scaled)
scaled.fillna(-1, inplace=True)
scaled = scaled.values
# frame as supervised learning
n_days = 5 #Memoria della NN
reframed = series_to_supervised(scaled, n_days, 1) # info of the past 5 days to determine next (1) day
# drop columns we don't want to predict (we therefore keep Ammonia)
reframed.drop(reframed.columns[[31,32,33,34,35]], axis=1, inplace=True)

reframed.head()
# Out:
#    var1(t-5)  var2(t-5)  var3(t-5)  ...  var5(t-1)  var6(t-1)   var1(t)
# 5   0.088608        0.0   0.163005  ...   0.358295   0.112816  0.025316
# 6   0.063291        0.0   0.130139  ...   0.406390   0.000000  0.088608
# 7   0.050633        0.0   0.074531  ...   0.397825   0.000000  0.050633
# 8   0.088608        0.0   0.381024  ...   0.408315   0.000000  0.088608
# 9   0.101266        0.0   0.246694  ...   0.392536   0.000000  0.063291
#
# [5 rows x 31 columns]

# %%
# split into train and test sets
values = reframed.values
n_features = 6 # number of variables, including the one to be predicted
n_train_days = 1312 # we train using only the first year
train = values[:n_train_days, :]
test = values[n_train_days:, :] # we test using all successive years 
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
# reshape from 2D to 3D
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1312, 30) 1312 (1312,)
# (1312, 5, 6) (1312,) (875, 5, 6) (875,)

# %% [markdown]
# # Modeling and training

# %%
# design the neural network
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
early_stopping = EarlyStopping(patience=50, restore_best_weights = True)
history = model.fit(train_X, train_y, epochs=500, batch_size=100, validation_data=(test_X, test_y), verbose=2, shuffle=False, callbacks=early_stopping)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/500
# 14/14 - 17s - loss: 0.2130 - val_loss: 0.1551 - 17s/epoch - 1s/step
# Epoch 2/500
# 14/14 - 0s - loss: 0.2082 - val_loss: 0.1518 - 498ms/epoch - 36ms/step
# Epoch 3/500
# 14/14 - 0s - loss: 0.2052 - val_loss: 0.1511 - 451ms/epoch - 32ms/step
# Epoch 4/500
# 14/14 - 0s - loss: 0.2041 - val_loss: 0.1510 - 440ms/epoch - 31ms/step
# Epoch 5/500
# 14/14 - 1s - loss: 0.2040 - val_loss: 0.1506 - 613ms/epoch - 44ms/step
# Epoch 6/500
# 14/14 - 1s - loss: 0.2034 - val_loss: 0.1504 - 571ms/epoch - 41ms/step
# Epoch 7/500
# 14/14 - 0s - loss: 0.2030 - val_loss: 0.1502 - 492ms/epoch - 35ms/step
# Epoch 8/500
# 14/14 - 1s - loss: 0.2028 - val_loss: 0.1498 - 559ms/epoch - 40ms/step
# Epoch 9/500
# 14/14 - 1s - loss: 0.2019 - val_loss: 0.1498 - 524ms/epoch - 37ms/step
# Epoch 10/500
# 14/14 - 1s - loss: 0.2017 - val_loss: 0.1495 - 597ms/epoch - 43ms/step
# Epoch 11/500
# 14/14 - 1s - loss: 0.2015 - val_loss: 0.1493 - 542ms/epoch - 39ms/step
# Epoch 12/500
# 14/14 - 1s - loss: 0.2011 - val_loss: 0.1493 - 532ms/epoch - 38ms/step
# Epoch 13/500
# 14/14 - 0s - loss: 0.2011 - val_loss: 0.1492 - 454ms/epoch - 32ms/step
# Epoch 14/500
# 14/14 - 0s - loss: 0.2009 - val_loss: 0.1486 - 451ms/epoch - 32ms/step
# Epoch 15/500
# 14/14 - 0s - loss: 0.2001 - val_loss: 0.1484 - 450ms/epoch - 32ms/step
# Epoch 16/500
# 14/14 - 0s - loss: 0.1996 - val_loss: 0.1486 - 461ms/epoch - 33ms/step
# Epoch 17/500
# 14/14 - 0s - loss: 0.1993 - val_loss: 0.1483 - 498ms/epoch - 36ms/step
# Epoch 18/500
# 14/14 - 1s - loss: 0.1991 - val_loss: 0.1481 - 525ms/epoch - 37ms/step
# Epoch 19/500
# 14/14 - 1s - loss: 0.1987 - val_loss: 0.1479 - 626ms/epoch - 45ms/step
# Epoch 20/500
# 14/14 - 1s - loss: 0.1982 - val_loss: 0.1483 - 594ms/epoch - 42ms/step
# Epoch 21/500
# 14/14 - 0s - loss: 0.1981 - val_loss: 0.1482 - 499ms/epoch - 36ms/step
# Epoch 22/500
# 14/14 - 1s - loss: 0.1974 - val_loss: 0.1480 - 560ms/epoch - 40ms/step
# Epoch 23/500
# 14/14 - 1s - loss: 0.1960 - val_loss: 0.1485 - 676ms/epoch - 48ms/step
# Epoch 24/500
# 14/14 - 1s - loss: 0.1952 - val_loss: 0.1497 - 547ms/epoch - 39ms/step
# Epoch 25/500
# 14/14 - 1s - loss: 0.1936 - val_loss: 0.1504 - 546ms/epoch - 39ms/step
# Epoch 26/500
# 14/14 - 0s - loss: 0.1913 - val_loss: 0.1487 - 285ms/epoch - 20ms/step
# Epoch 27/500
# 14/14 - 0s - loss: 0.1914 - val_loss: 0.1486 - 284ms/epoch - 20ms/step
# Epoch 28/500
# 14/14 - 0s - loss: 0.1909 - val_loss: 0.1514 - 278ms/epoch - 20ms/step
# Epoch 29/500
# 14/14 - 0s - loss: 0.1891 - val_loss: 0.1491 - 291ms/epoch - 21ms/step
# Epoch 30/500
# 14/14 - 0s - loss: 0.1911 - val_loss: 0.1487 - 280ms/epoch - 20ms/step
# Epoch 31/500
# 14/14 - 0s - loss: 0.1894 - val_loss: 0.1519 - 273ms/epoch - 20ms/step
# Epoch 32/500
# 14/14 - 0s - loss: 0.1885 - val_loss: 0.1475 - 286ms/epoch - 20ms/step
# Epoch 33/500
# 14/14 - 0s - loss: 0.1883 - val_loss: 0.1488 - 266ms/epoch - 19ms/step
# Epoch 34/500
# 14/14 - 0s - loss: 0.1870 - val_loss: 0.1479 - 263ms/epoch - 19ms/step
# Epoch 35/500
# 14/14 - 0s - loss: 0.1873 - val_loss: 0.1488 - 267ms/epoch - 19ms/step
# Epoch 36/500
# 14/14 - 0s - loss: 0.1880 - val_loss: 0.1470 - 272ms/epoch - 19ms/step
# Epoch 37/500
# 14/14 - 0s - loss: 0.1876 - val_loss: 0.1511 - 265ms/epoch - 19ms/step
# Epoch 38/500
# 14/14 - 0s - loss: 0.1886 - val_loss: 0.1484 - 272ms/epoch - 19ms/step
# Epoch 39/500
# 14/14 - 0s - loss: 0.1877 - val_loss: 0.1464 - 283ms/epoch - 20ms/step
# Epoch 40/500
# 14/14 - 0s - loss: 0.1858 - val_loss: 0.1462 - 304ms/epoch - 22ms/step
# Epoch 41/500
# 14/14 - 0s - loss: 0.1856 - val_loss: 0.1467 - 294ms/epoch - 21ms/step
# Epoch 42/500
# 14/14 - 0s - loss: 0.1847 - val_loss: 0.1472 - 292ms/epoch - 21ms/step
# Epoch 43/500
# 14/14 - 0s - loss: 0.1844 - val_loss: 0.1483 - 299ms/epoch - 21ms/step
# Epoch 44/500
# 14/14 - 0s - loss: 0.1854 - val_loss: 0.1463 - 305ms/epoch - 22ms/step
# Epoch 45/500
# 14/14 - 0s - loss: 0.1853 - val_loss: 0.1504 - 286ms/epoch - 20ms/step
# Epoch 46/500
# 14/14 - 0s - loss: 0.1856 - val_loss: 0.1458 - 314ms/epoch - 22ms/step
# Epoch 47/500
# 14/14 - 0s - loss: 0.1849 - val_loss: 0.1465 - 314ms/epoch - 22ms/step
# Epoch 48/500
# 14/14 - 0s - loss: 0.1843 - val_loss: 0.1465 - 316ms/epoch - 23ms/step
# Epoch 49/500
# 14/14 - 0s - loss: 0.1852 - val_loss: 0.1469 - 311ms/epoch - 22ms/step
# Epoch 50/500
# 14/14 - 0s - loss: 0.1854 - val_loss: 0.1463 - 292ms/epoch - 21ms/step
# Epoch 51/500
# 14/14 - 0s - loss: 0.1841 - val_loss: 0.1447 - 285ms/epoch - 20ms/step
# Epoch 52/500
# 14/14 - 0s - loss: 0.1831 - val_loss: 0.1463 - 274ms/epoch - 20ms/step
# Epoch 53/500
# 14/14 - 0s - loss: 0.1851 - val_loss: 0.1528 - 303ms/epoch - 22ms/step
# Epoch 54/500
# 14/14 - 0s - loss: 0.1853 - val_loss: 0.1453 - 293ms/epoch - 21ms/step
# Epoch 55/500
# 14/14 - 0s - loss: 0.1827 - val_loss: 0.1458 - 313ms/epoch - 22ms/step
# Epoch 56/500
# 14/14 - 0s - loss: 0.1826 - val_loss: 0.1496 - 330ms/epoch - 24ms/step
# Epoch 57/500
# 14/14 - 0s - loss: 0.1842 - val_loss: 0.1475 - 352ms/epoch - 25ms/step
# Epoch 58/500
# 14/14 - 0s - loss: 0.1818 - val_loss: 0.1456 - 311ms/epoch - 22ms/step
# Epoch 59/500
# 14/14 - 0s - loss: 0.1818 - val_loss: 0.1486 - 309ms/epoch - 22ms/step
# Epoch 60/500
# 14/14 - 0s - loss: 0.1821 - val_loss: 0.1472 - 298ms/epoch - 21ms/step
# Epoch 61/500
# 14/14 - 0s - loss: 0.1804 - val_loss: 0.1484 - 306ms/epoch - 22ms/step
# Epoch 62/500
# 14/14 - 0s - loss: 0.1827 - val_loss: 0.1464 - 303ms/epoch - 22ms/step
# Epoch 63/500
# 14/14 - 0s - loss: 0.1806 - val_loss: 0.1465 - 323ms/epoch - 23ms/step
# Epoch 64/500
# 14/14 - 0s - loss: 0.1805 - val_loss: 0.1503 - 298ms/epoch - 21ms/step
# Epoch 65/500
# 14/14 - 0s - loss: 0.1807 - val_loss: 0.1464 - 286ms/epoch - 20ms/step
# Epoch 66/500
# 14/14 - 0s - loss: 0.1797 - val_loss: 0.1484 - 305ms/epoch - 22ms/step
# Epoch 67/500
# 14/14 - 0s - loss: 0.1793 - val_loss: 0.1481 - 259ms/epoch - 18ms/step
# Epoch 68/500
# 14/14 - 0s - loss: 0.1786 - val_loss: 0.1485 - 296ms/epoch - 21ms/step
# Epoch 69/500
# 14/14 - 0s - loss: 0.1785 - val_loss: 0.1482 - 292ms/epoch - 21ms/step
# Epoch 70/500
# 14/14 - 0s - loss: 0.1786 - val_loss: 0.1493 - 287ms/epoch - 21ms/step
# Epoch 71/500
# 14/14 - 0s - loss: 0.1803 - val_loss: 0.1467 - 283ms/epoch - 20ms/step
# Epoch 72/500
# 14/14 - 0s - loss: 0.1781 - val_loss: 0.1521 - 286ms/epoch - 20ms/step
# Epoch 73/500
# 14/14 - 0s - loss: 0.1793 - val_loss: 0.1458 - 298ms/epoch - 21ms/step
# Epoch 74/500
# 14/14 - 0s - loss: 0.1788 - val_loss: 0.1523 - 279ms/epoch - 20ms/step
# Epoch 75/500
# 14/14 - 0s - loss: 0.1785 - val_loss: 0.1476 - 283ms/epoch - 20ms/step
# Epoch 76/500
# 14/14 - 0s - loss: 0.1778 - val_loss: 0.1467 - 293ms/epoch - 21ms/step
# Epoch 77/500
# 14/14 - 0s - loss: 0.1770 - val_loss: 0.1505 - 286ms/epoch - 20ms/step
# Epoch 78/500
# 14/14 - 0s - loss: 0.1773 - val_loss: 0.1471 - 272ms/epoch - 19ms/step
# Epoch 79/500
# 14/14 - 0s - loss: 0.1760 - val_loss: 0.1501 - 282ms/epoch - 20ms/step
# Epoch 80/500
# 14/14 - 0s - loss: 0.1754 - val_loss: 0.1474 - 270ms/epoch - 19ms/step
# Epoch 81/500
# 14/14 - 0s - loss: 0.1770 - val_loss: 0.1519 - 282ms/epoch - 20ms/step
# Epoch 82/500
# 14/14 - 0s - loss: 0.1789 - val_loss: 0.1478 - 272ms/epoch - 19ms/step
# Epoch 83/500
# 14/14 - 0s - loss: 0.1762 - val_loss: 0.1460 - 273ms/epoch - 20ms/step
# Epoch 84/500
# 14/14 - 0s - loss: 0.1760 - val_loss: 0.1529 - 291ms/epoch - 21ms/step
# Epoch 85/500
# 14/14 - 0s - loss: 0.1784 - val_loss: 0.1481 - 273ms/epoch - 20ms/step
# Epoch 86/500
# 14/14 - 0s - loss: 0.1751 - val_loss: 0.1503 - 279ms/epoch - 20ms/step
# Epoch 87/500
# 14/14 - 0s - loss: 0.1754 - val_loss: 0.1492 - 285ms/epoch - 20ms/step
# Epoch 88/500
# 14/14 - 0s - loss: 0.1765 - val_loss: 0.1464 - 281ms/epoch - 20ms/step
# Epoch 89/500
# 14/14 - 0s - loss: 0.1747 - val_loss: 0.1523 - 260ms/epoch - 19ms/step
# Epoch 90/500
# 14/14 - 0s - loss: 0.1737 - val_loss: 0.1490 - 286ms/epoch - 20ms/step
# Epoch 91/500
# 14/14 - 0s - loss: 0.1724 - val_loss: 0.1508 - 281ms/epoch - 20ms/step
# Epoch 92/500
# 14/14 - 0s - loss: 0.1720 - val_loss: 0.1521 - 317ms/epoch - 23ms/step
# Epoch 93/500
# 14/14 - 0s - loss: 0.1739 - val_loss: 0.1470 - 304ms/epoch - 22ms/step
# Epoch 94/500
# 14/14 - 0s - loss: 0.1737 - val_loss: 0.1540 - 269ms/epoch - 19ms/step
# Epoch 95/500
# 14/14 - 0s - loss: 0.1728 - val_loss: 0.1501 - 297ms/epoch - 21ms/step
# Epoch 96/500
# 14/14 - 0s - loss: 0.1703 - val_loss: 0.1483 - 282ms/epoch - 20ms/step
# Epoch 97/500
# 14/14 - 0s - loss: 0.1716 - val_loss: 0.1537 - 294ms/epoch - 21ms/step
# Epoch 98/500
# 14/14 - 0s - loss: 0.1730 - val_loss: 0.1492 - 295ms/epoch - 21ms/step
# Epoch 99/500
# 14/14 - 0s - loss: 0.1710 - val_loss: 0.1524 - 295ms/epoch - 21ms/step
# Epoch 100/500
# 14/14 - 0s - loss: 0.1706 - val_loss: 0.1500 - 277ms/epoch - 20ms/step
# Epoch 101/500
# 14/14 - 0s - loss: 0.1719 - val_loss: 0.1491 - 273ms/epoch - 19ms/step

# %% [markdown]
# ## Predictions of the year 2019

# %%
# make a prediction
yhat = model.predict(test_X)
#Convert from 3D to 2D
test_X = test_X.reshape((test_X.shape[0], n_days*n_features))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -5:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -5:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 23.945

# %% [markdown]
# #### Prediciton plots

# %%
pyplot.plot(inv_yhat, label = 'Prediction')

pyplot.plot(inv_y, label = 'Real')
pyplot.legend()
pyplot.show()

# %%
pyplot.plot(inv_yhat, label = 'Prediction')
inv_y[inv_y<1] = 0
pyplot.plot(inv_y, label = 'Real')
pyplot.legend()
pyplot.show()

# %%
inv_y[inv_y<1] = 0
inv_yhat[inv_yhat<1] = 0
pyplot.plot(inv_yhat, label = 'Prediction')
pyplot.plot(inv_y, label = 'Real')
pyplot.legend()
pyplot.show()

# %% [markdown]
# # Modeling with hyperparamenter search
# # Goal: reduce the MSE without overfitting

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 98 kB 3.2 MB/s

# %%
import tensorflow as tf
from tensorflow import keras
import keras_tuner as kt #Keras Creates a better model

# %%
tf.config.list_physical_devices('GPU') #To undestand which GPU using during the training
# Out:
# []

# %% [markdown]
# ## Function to create new models

# %%
def model_builder(hp):
  #design network
  #object created with keras_tuner -> iterates some parameters to create the model
  #units = neurons we use 32 steps for each time
  hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
  #Initialization of the model
  model = Sequential() 
  model.add(LSTM(units = hp_units,return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
  #for loop to iterate different quantities of layer (from 1 to 3 layer)
  for i in range(hp.Int('layers',1,3)):
   model.add(LSTM(units = hp_units, return_sequences=True))
  model.add(LSTM(units = hp_units, return_sequences=False))
  model.add(Dense(1))
  #Choose from a list of given instructions -> we choose leanrning rates
  #We look the performances
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
  model.compile(loss='mae', optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate))
  return model

# %% [markdown]
# # Creation of the object with model_builder(hp)
# ## Parameter to look at: validation loss

# %%
tuner = kt.RandomSearch(
    model_builder,
    objective='val_loss',
    max_trials=10,
    executions_per_trial =3,
    directory = 'dir',
    project_name = 'namee')
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 3
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 3, 'step': 1, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
early_stopping = EarlyStopping(monitor='val_loss',patience=10)
tuner.search(train_X, train_y, epochs=100, batch_size=72, validation_data=(test_X, test_y),shuffle=False, callbacks=[early_stopping])
# Out:
# Trial 10 Complete [00h 16m 14s]
# val_loss: 0.08407227694988251
#
# Best val_loss So Far: 0.06101139013965925
# Total elapsed time: 01h 00m 09s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in dir/namee
# Showing 10 best trials
# Objective(name='val_loss', direction='min')

# %% [markdown]
# ### Hyperband

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_loss',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')
# Out:
# INFO:tensorflow:Reloading Oracle from existing project my_dir/intro_to_kt/oracle.json
# INFO:tensorflow:Reloading Tuner from my_dir/intro_to_kt/tuner0.json

# %%
tuner.search(train_X, train_y, epochs=1000, batch_size=72, validation_data=(test_X, test_y),shuffle=False, callbacks=[early_stopping])
