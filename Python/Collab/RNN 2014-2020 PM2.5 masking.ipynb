# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import seaborn as sns
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
table = read_csv('/content/drive/MyDrive/Thesis/csvs/NNdata14_20.csv')
table.head()
# Out:
#                    Date  IDStation  ... Wind_direction_max  Rainfall
# 0  2014-01-01T00:00:00Z        681  ...              143.0       0.0
# 1  2014-01-02T00:00:00Z        681  ...              153.0       7.8
# 2  2014-01-03T00:00:00Z        681  ...              152.0       0.0
# 3  2014-01-04T00:00:00Z        681  ...              164.0      35.8
# 4  2014-01-05T00:00:00Z        681  ...              136.0      25.0
#
# [5 rows x 28 columns]

# %%
#Moggio = table.loc[table.loc[:,"NameStation"]=="Moggio",:]
Moggio = table.loc[:,["Date","PM25","Ammonia","Wind_speed","Wind_direction","Temperature","Rainfall"]]
#Moggio = Moggio.dropna(how="any")
Moggio = Moggio.reset_index()
Moggio = Moggio.iloc[:-365,:] # we train not using 2020, for now
Moggio.head()
# Out:
#    index                  Date  PM25  ...  Wind_direction  Temperature  Rainfall
# 0      0  2014-01-01T00:00:00Z   7.0  ...            99.0    -0.334965       0.0
# 1      1  2014-01-02T00:00:00Z   5.0  ...           105.0    -0.486111       7.8
# 2      2  2014-01-03T00:00:00Z   4.0  ...           120.0     2.220588       0.0
# 3      3  2014-01-04T00:00:00Z   7.0  ...           175.0     2.137063      35.8
# 4      4  2014-01-05T00:00:00Z   8.0  ...            94.0     2.416084      25.0
#
# [5 rows x 8 columns]

# %%
# sns.lineplot(x='Date', y='PM25', data=Moggio)

# %% [markdown]
# ##Convert series to supervised learning
# ### Activation function = tanh and logistic (s curve)

# %% [markdown]
# ###Conversion Function

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	"""
	Frame a time series as a supervised learning dataset.
	Arguments:
		data: Sequence of observations as a list or NumPy array.
		n_in: Number of lag observations as input (X).
		n_out: Number of observations as output (y).
		dropnan: Boolean whether or not to drop rows with NaN values.
	Returns:
		Pandas DataFrame of series framed for supervised learning.
	"""
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
		# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %% [markdown]
# ### Conversion of Moggio

# %%
values = Moggio.iloc[:,2:].values
# ensure all data is float
values = values.astype('float32') #cast in float 32 bit per evitare problemi
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# REPLACING MISSING VALUES WITH -1 !!!
scaled = DataFrame(scaled)
scaled.fillna(-1, inplace=True)
scaled = scaled.values
# frame as supervised learning
n_days = 5 #Memoria della NN
reframed = series_to_supervised(scaled, n_days, 1) # info of the past 5 days to determine next (1) day
# drop columns we don't want to predict (we therefore keep Ammonia)
reframed.drop(reframed.columns[[31,32,33,34,35]], axis=1, inplace=True)

reframed.head()
# Out:
#    var1(t-5)  var2(t-5)  var3(t-5)  ...  var5(t-1)  var6(t-1)   var1(t)
# 5   0.088608        0.0   0.163005  ...   0.358295   0.112816  0.025316
# 6   0.063291        0.0   0.130139  ...   0.406390   0.000000  0.088608
# 7   0.050633        0.0   0.074531  ...   0.397825   0.000000  0.050633
# 8   0.088608        0.0   0.381024  ...   0.408315   0.000000  0.088608
# 9   0.101266        0.0   0.246694  ...   0.392536   0.000000  0.063291
#
# [5 rows x 31 columns]

# %%
# split into train and test sets
values = reframed.loc[10:,:].values
n_features = 6 # number of variables, including the one to be predicted
n_train_days = 1312 # we train using only the first year
train = values[:n_train_days, :]
test = values[n_train_days:, :] # we test using all successive years 
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1312, 30) 1312 (1312,)
# (1312, 5, 6) (1312,) (870, 5, 6) (870,)

# %% [markdown]
# # Modeling and training

# %%
from tensorflow.keras.layers import Masking
# design the neural network
model = Sequential()
# ADDING A MASKING INPUT LAYER
model.add(Masking(mask_value=-1.0,input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(LSTM(50, return_sequences=True, mask_value=-1))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
early_stopping = EarlyStopping(patience=50, restore_best_weights = True)
history = model.fit(train_X, train_y, epochs=500, batch_size=100, validation_data=(test_X, test_y), verbose=2, shuffle=False, callbacks=early_stopping)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/500
# 14/14 - 16s - loss: 0.2132 - val_loss: 0.1574 - 16s/epoch - 1s/step
# Epoch 2/500
# 14/14 - 0s - loss: 0.2079 - val_loss: 0.1531 - 358ms/epoch - 26ms/step
# Epoch 3/500
# 14/14 - 0s - loss: 0.2041 - val_loss: 0.1523 - 359ms/epoch - 26ms/step
# Epoch 4/500
# 14/14 - 0s - loss: 0.2042 - val_loss: 0.1520 - 362ms/epoch - 26ms/step
# Epoch 5/500
# 14/14 - 0s - loss: 0.2036 - val_loss: 0.1518 - 366ms/epoch - 26ms/step
# Epoch 6/500
# 14/14 - 0s - loss: 0.2032 - val_loss: 0.1516 - 379ms/epoch - 27ms/step
# Epoch 7/500
# 14/14 - 0s - loss: 0.2029 - val_loss: 0.1513 - 361ms/epoch - 26ms/step
# Epoch 8/500
# 14/14 - 0s - loss: 0.2026 - val_loss: 0.1510 - 386ms/epoch - 28ms/step
# Epoch 9/500
# 14/14 - 0s - loss: 0.2022 - val_loss: 0.1507 - 369ms/epoch - 26ms/step
# Epoch 10/500
# 14/14 - 0s - loss: 0.2019 - val_loss: 0.1503 - 364ms/epoch - 26ms/step
# Epoch 11/500
# 14/14 - 0s - loss: 0.2015 - val_loss: 0.1500 - 380ms/epoch - 27ms/step
# Epoch 12/500
# 14/14 - 0s - loss: 0.2010 - val_loss: 0.1499 - 383ms/epoch - 27ms/step
# Epoch 13/500
# 14/14 - 0s - loss: 0.2007 - val_loss: 0.1499 - 359ms/epoch - 26ms/step
# Epoch 14/500
# 14/14 - 0s - loss: 0.2005 - val_loss: 0.1496 - 382ms/epoch - 27ms/step
# Epoch 15/500
# 14/14 - 0s - loss: 0.2001 - val_loss: 0.1492 - 359ms/epoch - 26ms/step
# Epoch 16/500
# 14/14 - 0s - loss: 0.1994 - val_loss: 0.1492 - 366ms/epoch - 26ms/step
# Epoch 17/500
# 14/14 - 0s - loss: 0.1990 - val_loss: 0.1494 - 374ms/epoch - 27ms/step
# Epoch 18/500
# 14/14 - 0s - loss: 0.1989 - val_loss: 0.1490 - 364ms/epoch - 26ms/step
# Epoch 19/500
# 14/14 - 0s - loss: 0.1984 - val_loss: 0.1487 - 386ms/epoch - 28ms/step
# Epoch 20/500
# 14/14 - 0s - loss: 0.1982 - val_loss: 0.1484 - 378ms/epoch - 27ms/step
# Epoch 21/500
# 14/14 - 0s - loss: 0.1980 - val_loss: 0.1479 - 364ms/epoch - 26ms/step
# Epoch 22/500
# 14/14 - 0s - loss: 0.1978 - val_loss: 0.1474 - 387ms/epoch - 28ms/step
# Epoch 23/500
# 14/14 - 0s - loss: 0.1973 - val_loss: 0.1472 - 364ms/epoch - 26ms/step
# Epoch 24/500
# 14/14 - 0s - loss: 0.1966 - val_loss: 0.1472 - 381ms/epoch - 27ms/step
# Epoch 25/500
# 14/14 - 0s - loss: 0.1961 - val_loss: 0.1467 - 357ms/epoch - 25ms/step
# Epoch 26/500
# 14/14 - 0s - loss: 0.1953 - val_loss: 0.1464 - 363ms/epoch - 26ms/step
# Epoch 27/500
# 14/14 - 0s - loss: 0.1941 - val_loss: 0.1461 - 374ms/epoch - 27ms/step
# Epoch 28/500
# 14/14 - 0s - loss: 0.1932 - val_loss: 0.1464 - 353ms/epoch - 25ms/step
# Epoch 29/500
# 14/14 - 0s - loss: 0.1920 - val_loss: 0.1450 - 357ms/epoch - 26ms/step
# Epoch 30/500
# 14/14 - 0s - loss: 0.1914 - val_loss: 0.1449 - 380ms/epoch - 27ms/step
# Epoch 31/500
# 14/14 - 0s - loss: 0.1907 - val_loss: 0.1447 - 380ms/epoch - 27ms/step
# Epoch 32/500
# 14/14 - 0s - loss: 0.1911 - val_loss: 0.1450 - 378ms/epoch - 27ms/step
# Epoch 33/500
# 14/14 - 0s - loss: 0.1905 - val_loss: 0.1467 - 381ms/epoch - 27ms/step
# Epoch 34/500
# 14/14 - 0s - loss: 0.1892 - val_loss: 0.1484 - 371ms/epoch - 27ms/step
# Epoch 35/500
# 14/14 - 0s - loss: 0.1883 - val_loss: 0.1458 - 380ms/epoch - 27ms/step
# Epoch 36/500
# 14/14 - 0s - loss: 0.1879 - val_loss: 0.1472 - 370ms/epoch - 26ms/step
# Epoch 37/500
# 14/14 - 0s - loss: 0.1856 - val_loss: 0.1462 - 357ms/epoch - 26ms/step
# Epoch 38/500
# 14/14 - 0s - loss: 0.1870 - val_loss: 0.1451 - 383ms/epoch - 27ms/step
# Epoch 39/500
# 14/14 - 0s - loss: 0.1859 - val_loss: 0.1462 - 369ms/epoch - 26ms/step
# Epoch 40/500
# 14/14 - 0s - loss: 0.1848 - val_loss: 0.1462 - 357ms/epoch - 26ms/step
# Epoch 41/500
# 14/14 - 0s - loss: 0.1854 - val_loss: 0.1449 - 384ms/epoch - 27ms/step
# Epoch 42/500
# 14/14 - 0s - loss: 0.1845 - val_loss: 0.1464 - 352ms/epoch - 25ms/step
# Epoch 43/500
# 14/14 - 0s - loss: 0.1841 - val_loss: 0.1450 - 374ms/epoch - 27ms/step
# Epoch 44/500
# 14/14 - 0s - loss: 0.1842 - val_loss: 0.1465 - 369ms/epoch - 26ms/step
# Epoch 45/500
# 14/14 - 0s - loss: 0.1829 - val_loss: 0.1453 - 358ms/epoch - 26ms/step
# Epoch 46/500
# 14/14 - 0s - loss: 0.1838 - val_loss: 0.1458 - 372ms/epoch - 27ms/step
# Epoch 47/500
# 14/14 - 0s - loss: 0.1834 - val_loss: 0.1458 - 357ms/epoch - 26ms/step
# Epoch 48/500
# 14/14 - 0s - loss: 0.1834 - val_loss: 0.1456 - 354ms/epoch - 25ms/step
# Epoch 49/500
# 14/14 - 0s - loss: 0.1830 - val_loss: 0.1457 - 371ms/epoch - 27ms/step
# Epoch 50/500
# 14/14 - 0s - loss: 0.1825 - val_loss: 0.1456 - 369ms/epoch - 26ms/step
# Epoch 51/500
# 14/14 - 0s - loss: 0.1831 - val_loss: 0.1449 - 378ms/epoch - 27ms/step
# Epoch 52/500
# 14/14 - 0s - loss: 0.1831 - val_loss: 0.1463 - 370ms/epoch - 26ms/step
# Epoch 53/500
# 14/14 - 0s - loss: 0.1883 - val_loss: 0.1444 - 359ms/epoch - 26ms/step
# Epoch 54/500
# 14/14 - 0s - loss: 0.1850 - val_loss: 0.1450 - 363ms/epoch - 26ms/step
# Epoch 55/500
# 14/14 - 0s - loss: 0.1820 - val_loss: 0.1440 - 389ms/epoch - 28ms/step
# Epoch 56/500
# 14/14 - 0s - loss: 0.1819 - val_loss: 0.1458 - 368ms/epoch - 26ms/step
# Epoch 57/500
# 14/14 - 0s - loss: 0.1815 - val_loss: 0.1446 - 385ms/epoch - 28ms/step
# Epoch 58/500
# 14/14 - 0s - loss: 0.1828 - val_loss: 0.1449 - 373ms/epoch - 27ms/step
# Epoch 59/500
# 14/14 - 0s - loss: 0.1828 - val_loss: 0.1446 - 366ms/epoch - 26ms/step
# Epoch 60/500
# 14/14 - 0s - loss: 0.1813 - val_loss: 0.1443 - 376ms/epoch - 27ms/step
# Epoch 61/500
# 14/14 - 0s - loss: 0.1803 - val_loss: 0.1448 - 365ms/epoch - 26ms/step
# Epoch 62/500
# 14/14 - 0s - loss: 0.1810 - val_loss: 0.1461 - 368ms/epoch - 26ms/step
# Epoch 63/500
# 14/14 - 0s - loss: 0.1815 - val_loss: 0.1443 - 384ms/epoch - 27ms/step
# Epoch 64/500
# 14/14 - 0s - loss: 0.1800 - val_loss: 0.1447 - 368ms/epoch - 26ms/step
# Epoch 65/500
# 14/14 - 0s - loss: 0.1790 - val_loss: 0.1447 - 379ms/epoch - 27ms/step
# Epoch 66/500
# 14/14 - 0s - loss: 0.1786 - val_loss: 0.1449 - 364ms/epoch - 26ms/step
# Epoch 67/500
# 14/14 - 0s - loss: 0.1786 - val_loss: 0.1443 - 363ms/epoch - 26ms/step
# Epoch 68/500
# 14/14 - 0s - loss: 0.1786 - val_loss: 0.1444 - 364ms/epoch - 26ms/step
# Epoch 69/500
# 14/14 - 0s - loss: 0.1789 - val_loss: 0.1456 - 372ms/epoch - 27ms/step
# Epoch 70/500
# 14/14 - 0s - loss: 0.1787 - val_loss: 0.1443 - 362ms/epoch - 26ms/step
# Epoch 71/500
# 14/14 - 0s - loss: 0.1784 - val_loss: 0.1459 - 380ms/epoch - 27ms/step
# Epoch 72/500
# 14/14 - 0s - loss: 0.1785 - val_loss: 0.1445 - 372ms/epoch - 27ms/step
# Epoch 73/500
# 14/14 - 0s - loss: 0.1784 - val_loss: 0.1451 - 367ms/epoch - 26ms/step
# Epoch 74/500
# 14/14 - 0s - loss: 0.1773 - val_loss: 0.1447 - 373ms/epoch - 27ms/step
# Epoch 75/500
# 14/14 - 0s - loss: 0.1772 - val_loss: 0.1462 - 356ms/epoch - 25ms/step
# Epoch 76/500
# 14/14 - 0s - loss: 0.1773 - val_loss: 0.1448 - 364ms/epoch - 26ms/step
# Epoch 77/500
# 14/14 - 0s - loss: 0.1801 - val_loss: 0.1500 - 371ms/epoch - 26ms/step
# Epoch 78/500
# 14/14 - 0s - loss: 0.1787 - val_loss: 0.1460 - 362ms/epoch - 26ms/step
# Epoch 79/500
# 14/14 - 0s - loss: 0.1765 - val_loss: 0.1447 - 378ms/epoch - 27ms/step
# Epoch 80/500
# 14/14 - 0s - loss: 0.1764 - val_loss: 0.1444 - 358ms/epoch - 26ms/step
# Epoch 81/500
# 14/14 - 0s - loss: 0.1770 - val_loss: 0.1451 - 363ms/epoch - 26ms/step
# Epoch 82/500
# 14/14 - 0s - loss: 0.1743 - val_loss: 0.1467 - 370ms/epoch - 26ms/step
# Epoch 83/500
# 14/14 - 0s - loss: 0.1752 - val_loss: 0.1457 - 355ms/epoch - 25ms/step
# Epoch 84/500
# 14/14 - 0s - loss: 0.1753 - val_loss: 0.1442 - 362ms/epoch - 26ms/step
# Epoch 85/500
# 14/14 - 0s - loss: 0.1755 - val_loss: 0.1454 - 384ms/epoch - 27ms/step
# Epoch 86/500
# 14/14 - 0s - loss: 0.1721 - val_loss: 0.1465 - 360ms/epoch - 26ms/step
# Epoch 87/500
# 14/14 - 0s - loss: 0.1739 - val_loss: 0.1452 - 374ms/epoch - 27ms/step
# Epoch 88/500
# 14/14 - 0s - loss: 0.1724 - val_loss: 0.1453 - 372ms/epoch - 27ms/step
# Epoch 89/500
# 14/14 - 0s - loss: 0.1731 - val_loss: 0.1452 - 355ms/epoch - 25ms/step
# Epoch 90/500
# 14/14 - 0s - loss: 0.1737 - val_loss: 0.1483 - 377ms/epoch - 27ms/step
# Epoch 91/500
# 14/14 - 0s - loss: 0.1730 - val_loss: 0.1457 - 362ms/epoch - 26ms/step
# Epoch 92/500
# 14/14 - 0s - loss: 0.1722 - val_loss: 0.1471 - 361ms/epoch - 26ms/step
# Epoch 93/500
# 14/14 - 0s - loss: 0.1744 - val_loss: 0.1442 - 377ms/epoch - 27ms/step
# Epoch 94/500
# 14/14 - 0s - loss: 0.1724 - val_loss: 0.1461 - 365ms/epoch - 26ms/step
# Epoch 95/500
# 14/14 - 0s - loss: 0.1725 - val_loss: 0.1451 - 363ms/epoch - 26ms/step
# Epoch 96/500
# 14/14 - 0s - loss: 0.1729 - val_loss: 0.1462 - 363ms/epoch - 26ms/step
# Epoch 97/500
# 14/14 - 0s - loss: 0.1714 - val_loss: 0.1438 - 365ms/epoch - 26ms/step
# Epoch 98/500
# 14/14 - 0s - loss: 0.1706 - val_loss: 0.1456 - 358ms/epoch - 26ms/step
# Epoch 99/500
# 14/14 - 0s - loss: 0.1703 - val_loss: 0.1477 - 361ms/epoch - 26ms/step
# Epoch 100/500
# 14/14 - 0s - loss: 0.1707 - val_loss: 0.1462 - 356ms/epoch - 25ms/step
# Epoch 101/500
# 14/14 - 0s - loss: 0.1694 - val_loss: 0.1449 - 356ms/epoch - 25ms/step
# Epoch 102/500
# 14/14 - 0s - loss: 0.1709 - val_loss: 0.1450 - 368ms/epoch - 26ms/step
# Epoch 103/500
# 14/14 - 0s - loss: 0.1701 - val_loss: 0.1459 - 360ms/epoch - 26ms/step
# Epoch 104/500
# 14/14 - 0s - loss: 0.1694 - val_loss: 0.1464 - 365ms/epoch - 26ms/step
# Epoch 105/500
# 14/14 - 0s - loss: 0.1685 - val_loss: 0.1453 - 351ms/epoch - 25ms/step
# Epoch 106/500
# 14/14 - 0s - loss: 0.1687 - val_loss: 0.1459 - 353ms/epoch - 25ms/step
# Epoch 107/500
# 14/14 - 0s - loss: 0.1671 - val_loss: 0.1451 - 381ms/epoch - 27ms/step
# Epoch 108/500
# 14/14 - 0s - loss: 0.1689 - val_loss: 0.1458 - 356ms/epoch - 25ms/step
# Epoch 109/500
# 14/14 - 0s - loss: 0.1673 - val_loss: 0.1446 - 356ms/epoch - 25ms/step
# Epoch 110/500
# 14/14 - 0s - loss: 0.1683 - val_loss: 0.1460 - 365ms/epoch - 26ms/step
# Epoch 111/500
# 14/14 - 0s - loss: 0.1678 - val_loss: 0.1456 - 376ms/epoch - 27ms/step
# Epoch 112/500
# 14/14 - 0s - loss: 0.1677 - val_loss: 0.1454 - 354ms/epoch - 25ms/step
# Epoch 113/500
# 14/14 - 0s - loss: 0.1665 - val_loss: 0.1460 - 362ms/epoch - 26ms/step
# Epoch 114/500
# 14/14 - 0s - loss: 0.1682 - val_loss: 0.1468 - 353ms/epoch - 25ms/step
# Epoch 115/500
# 14/14 - 0s - loss: 0.1667 - val_loss: 0.1480 - 360ms/epoch - 26ms/step
# Epoch 116/500
# 14/14 - 0s - loss: 0.1657 - val_loss: 0.1464 - 362ms/epoch - 26ms/step
# Epoch 117/500
# 14/14 - 0s - loss: 0.1664 - val_loss: 0.1474 - 363ms/epoch - 26ms/step
# Epoch 118/500
# 14/14 - 0s - loss: 0.1654 - val_loss: 0.1454 - 374ms/epoch - 27ms/step
# Epoch 119/500
# 14/14 - 0s - loss: 0.1643 - val_loss: 0.1501 - 354ms/epoch - 25ms/step
# Epoch 120/500
# 14/14 - 0s - loss: 0.1663 - val_loss: 0.1451 - 354ms/epoch - 25ms/step
# Epoch 121/500
# 14/14 - 0s - loss: 0.1663 - val_loss: 0.1469 - 362ms/epoch - 26ms/step
# Epoch 122/500
# 14/14 - 0s - loss: 0.1655 - val_loss: 0.1483 - 355ms/epoch - 25ms/step
# Epoch 123/500
# 14/14 - 0s - loss: 0.1656 - val_loss: 0.1515 - 350ms/epoch - 25ms/step
# Epoch 124/500
# 14/14 - 0s - loss: 0.1653 - val_loss: 0.1461 - 355ms/epoch - 25ms/step
# Epoch 125/500
# 14/14 - 0s - loss: 0.1655 - val_loss: 0.1470 - 355ms/epoch - 25ms/step
# Epoch 126/500
# 14/14 - 0s - loss: 0.1642 - val_loss: 0.1516 - 351ms/epoch - 25ms/step
# Epoch 127/500
# 14/14 - 0s - loss: 0.1633 - val_loss: 0.1474 - 379ms/epoch - 27ms/step
# Epoch 128/500
# 14/14 - 0s - loss: 0.1629 - val_loss: 0.1464 - 351ms/epoch - 25ms/step
# Epoch 129/500
# 14/14 - 0s - loss: 0.1623 - val_loss: 0.1507 - 356ms/epoch - 25ms/step
# Epoch 130/500
# 14/14 - 0s - loss: 0.1615 - val_loss: 0.1513 - 372ms/epoch - 27ms/step
# Epoch 131/500
# 14/14 - 0s - loss: 0.1627 - val_loss: 0.1491 - 365ms/epoch - 26ms/step
# Epoch 132/500
# 14/14 - 0s - loss: 0.1611 - val_loss: 0.1461 - 375ms/epoch - 27ms/step
# Epoch 133/500
# 14/14 - 0s - loss: 0.1639 - val_loss: 0.1536 - 371ms/epoch - 26ms/step
# Epoch 134/500
# 14/14 - 0s - loss: 0.1633 - val_loss: 0.1501 - 359ms/epoch - 26ms/step
# Epoch 135/500
# 14/14 - 0s - loss: 0.1633 - val_loss: 0.1504 - 376ms/epoch - 27ms/step
# Epoch 136/500
# 14/14 - 0s - loss: 0.1613 - val_loss: 0.1466 - 366ms/epoch - 26ms/step
# Epoch 137/500
# 14/14 - 0s - loss: 0.1601 - val_loss: 0.1525 - 367ms/epoch - 26ms/step
# Epoch 138/500
# 14/14 - 0s - loss: 0.1593 - val_loss: 0.1519 - 381ms/epoch - 27ms/step
# Epoch 139/500
# 14/14 - 0s - loss: 0.1592 - val_loss: 0.1486 - 377ms/epoch - 27ms/step
# Epoch 140/500
# 14/14 - 0s - loss: 0.1614 - val_loss: 0.1518 - 354ms/epoch - 25ms/step
# Epoch 141/500
# 14/14 - 0s - loss: 0.1636 - val_loss: 0.1486 - 375ms/epoch - 27ms/step
# Epoch 142/500
# 14/14 - 0s - loss: 0.1597 - val_loss: 0.1545 - 367ms/epoch - 26ms/step
# Epoch 143/500
# 14/14 - 0s - loss: 0.1610 - val_loss: 0.1501 - 378ms/epoch - 27ms/step
# Epoch 144/500
# 14/14 - 0s - loss: 0.1592 - val_loss: 0.1547 - 369ms/epoch - 26ms/step
# Epoch 145/500
# 14/14 - 0s - loss: 0.1573 - val_loss: 0.1530 - 362ms/epoch - 26ms/step
# Epoch 146/500
# 14/14 - 0s - loss: 0.1578 - val_loss: 0.1495 - 375ms/epoch - 27ms/step
# Epoch 147/500
# 14/14 - 0s - loss: 0.1597 - val_loss: 0.1501 - 368ms/epoch - 26ms/step

# %% [markdown]
# ## Predictions of the year 2019

# %%
# make a prediction
yhat = model.predict(test_X)
#Convert from 3D to 2D
test_X = test_X.reshape((test_X.shape[0], n_days*n_features))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -5:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -5:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 24.203

# %% [markdown]
# #### Prediciton plots

# %%
pyplot.plot(inv_yhat, label = 'Prediction')
pyplot.plot(inv_y, label = 'Real')
pyplot.legend()
pyplot.show()

# %% [markdown]
# # Modeling with hyperparamenter search
# # Goal: reduce the MSE without overfitting

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 98 kB 3.2 MB/s

# %%
import tensorflow as tf
from tensorflow import keras
import keras_tuner as kt #Keras Creates a better model

# %%
tf.config.list_physical_devices('GPU') #To undestand which GPU using during the training
# Out:
# []

# %% [markdown]
# ## Function to create new models

# %%
def model_builder(hp):
  #design network
  #object created with keras_tuner -> iterates some parameters to create the model
  #units = neurons we use 32 steps for each time
  hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
  #Initialization of the model
  model = Sequential() 
  model.add(LSTM(units = hp_units,return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
  #for loop to iterate different quantities of layer (from 1 to 3 layer)
  for i in range(hp.Int('layers',1,3)):
   model.add(LSTM(units = hp_units, return_sequences=True))
  model.add(LSTM(units = hp_units, return_sequences=False))
  model.add(Dense(1))
  #Choose from a list of given instructions -> we choose leanrning rates
  #We look the performances
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
  model.compile(loss='mae', optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate))
  return model

# %% [markdown]
# # Creation of the object with model_builder(hp)
# ## Parameter to look at: validation loss

# %%
tuner = kt.RandomSearch(
    model_builder,
    objective='val_loss',
    max_trials=10,
    executions_per_trial =3,
    directory = 'dir',
    project_name = 'namee')
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 3
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 3, 'step': 1, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
early_stopping = EarlyStopping(monitor='val_loss',patience=10)
tuner.search(train_X, train_y, epochs=100, batch_size=72, validation_data=(test_X, test_y),shuffle=False, callbacks=[early_stopping])
# Out:
# Trial 10 Complete [00h 16m 14s]
# val_loss: 0.08407227694988251
#
# Best val_loss So Far: 0.06101139013965925
# Total elapsed time: 01h 00m 09s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in dir/namee
# Showing 10 best trials
# Objective(name='val_loss', direction='min')

# %% [markdown]
# ### Hyperband

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_loss',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')
# Out:
# INFO:tensorflow:Reloading Oracle from existing project my_dir/intro_to_kt/oracle.json
# INFO:tensorflow:Reloading Tuner from my_dir/intro_to_kt/tuner0.json

# %%
tuner.search(train_X, train_y, epochs=1000, batch_size=72, validation_data=(test_X, test_y),shuffle=False, callbacks=[early_stopping])
