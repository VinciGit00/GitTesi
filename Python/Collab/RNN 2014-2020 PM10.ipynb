# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import seaborn as sns
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
table = read_csv('/content/drive/MyDrive/Thesis/csvs/NNdata14_20.csv')
table.head()
# Out:
#                    Date  IDStation  ... Wind_direction_max  Rainfall
# 0  2014-01-01T00:00:00Z        681  ...              143.0       0.0
# 1  2014-01-02T00:00:00Z        681  ...              153.0       7.8
# 2  2014-01-03T00:00:00Z        681  ...              152.0       0.0
# 3  2014-01-04T00:00:00Z        681  ...              164.0      35.8
# 4  2014-01-05T00:00:00Z        681  ...              136.0      25.0
#
# [5 rows x 28 columns]

# %%
#Moggio = table.loc[table.loc[:,"NameStation"]=="Moggio",:]
#PM 2.5 were removed
Moggio = table.loc[:,["Date","PM10","Ammonia","Wind_speed","Wind_direction","Temperature","Rainfall"]]
Moggio = Moggio.dropna(how="any")
Moggio = Moggio.reset_index()
Moggio = Moggio.iloc[:-365,:] # we train not using 2020, for now
Moggio.head()
# Out:
#    index                  Date  PM10  ...  Wind_direction  Temperature  Rainfall
# 0      0  2014-01-01T00:00:00Z   6.0  ...            99.0    -0.334965       0.0
# 1      1  2014-01-02T00:00:00Z   6.0  ...           105.0    -0.486111       7.8
# 2      2  2014-01-03T00:00:00Z  11.0  ...           120.0     2.220588       0.0
# 3      3  2014-01-04T00:00:00Z   6.0  ...           175.0     2.137063      35.8
# 4      4  2014-01-05T00:00:00Z   3.0  ...            94.0     2.416084      25.0
#
# [5 rows x 8 columns]

# %%
# sns.lineplot(x='Date', y='PM25', data=Moggio)

# %% [markdown]
# ##Convert series to supervised learning
# ### Activation function = tanh and logistic (s curve)

# %% [markdown]
# ###Conversion Function

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	"""
	Frame a time series as a supervised learning dataset.
	Arguments:
		data: Sequence of observations as a list or NumPy array.
		n_in: Number of lag observations as input (X).
		n_out: Number of observations as output (y).
		dropnan: Boolean whether or not to drop rows with NaN values.
	Returns:
		Pandas DataFrame of series framed for supervised learning.
	"""
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %% [markdown]
# ### Conversion of Moggio

# %%
values = Moggio.iloc[:,2:].values
# ensure all data is float
values = values.astype('float32') #cast in float 32 bit per evitare problemi
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
n_days = 5 #Memoria della NN
reframed = series_to_supervised(scaled, n_days, 1) # info of the past 5 days to determine next (1) day
# drop columns we don't want to predict (we therefore keep Ammonia)
reframed.drop(reframed.columns[[31,32,33,34,35]], axis=1, inplace=True)

reframed.head()
# Out:
#    var1(t-5)  var2(t-5)  var3(t-5)  ...  var5(t-1)  var6(t-1)   var1(t)
# 5   0.066667        0.0   0.163005  ...   0.358295   0.112816  0.022222
# 6   0.066667        0.0   0.130139  ...   0.406390   0.000000  0.077778
# 7   0.122222        0.0   0.074531  ...   0.397825   0.000000  0.044444
# 8   0.066667        0.0   0.381024  ...   0.408315   0.000000  0.044444
# 9   0.033333        0.0   0.246694  ...   0.392536   0.000000  0.133333
#
# [5 rows x 31 columns]

# %%
# split into train and test sets
values = reframed.values
n_features = 6 # number of variables, including the one to be predicted
n_train_days = 1312 # we train using only the first year
train = values[:n_train_days, :]
test = values[n_train_days:, :] # we test using all successive years 
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
# reshape from 2D to 3D
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1312, 30) 1312 (1312,)
# (1312, 5, 6) (1312,) (419, 5, 6) (419,)

# %% [markdown]
# # Modeling and training

# %%
# design the neural network
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
early_stopping = EarlyStopping(patience=50, restore_best_weights = True)
history = model.fit(train_X, train_y, epochs=500, batch_size=100, validation_data=(test_X, test_y), verbose=2, shuffle=False, callbacks=early_stopping)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/500
# 14/14 - 10s - loss: 0.1143 - val_loss: 0.0968 - 10s/epoch - 686ms/step
# Epoch 2/500
# 14/14 - 0s - loss: 0.0961 - val_loss: 0.0880 - 276ms/epoch - 20ms/step
# Epoch 3/500
# 14/14 - 0s - loss: 0.0919 - val_loss: 0.0876 - 277ms/epoch - 20ms/step
# Epoch 4/500
# 14/14 - 0s - loss: 0.0916 - val_loss: 0.0859 - 264ms/epoch - 19ms/step
# Epoch 5/500
# 14/14 - 0s - loss: 0.0904 - val_loss: 0.0855 - 267ms/epoch - 19ms/step
# Epoch 6/500
# 14/14 - 0s - loss: 0.0897 - val_loss: 0.0859 - 267ms/epoch - 19ms/step
# Epoch 7/500
# 14/14 - 0s - loss: 0.0892 - val_loss: 0.0849 - 263ms/epoch - 19ms/step
# Epoch 8/500
# 14/14 - 0s - loss: 0.0893 - val_loss: 0.0871 - 263ms/epoch - 19ms/step
# Epoch 9/500
# 14/14 - 0s - loss: 0.0889 - val_loss: 0.0871 - 264ms/epoch - 19ms/step
# Epoch 10/500
# 14/14 - 0s - loss: 0.0884 - val_loss: 0.0869 - 257ms/epoch - 18ms/step
# Epoch 11/500
# 14/14 - 0s - loss: 0.0880 - val_loss: 0.0843 - 266ms/epoch - 19ms/step
# Epoch 12/500
# 14/14 - 0s - loss: 0.0873 - val_loss: 0.0846 - 257ms/epoch - 18ms/step
# Epoch 13/500
# 14/14 - 0s - loss: 0.0869 - val_loss: 0.0847 - 259ms/epoch - 19ms/step
# Epoch 14/500
# 14/14 - 0s - loss: 0.0864 - val_loss: 0.0842 - 248ms/epoch - 18ms/step
# Epoch 15/500
# 14/14 - 0s - loss: 0.0860 - val_loss: 0.0851 - 249ms/epoch - 18ms/step
# Epoch 16/500
# 14/14 - 0s - loss: 0.0853 - val_loss: 0.0855 - 245ms/epoch - 18ms/step
# Epoch 17/500
# 14/14 - 0s - loss: 0.0848 - val_loss: 0.0854 - 260ms/epoch - 19ms/step
# Epoch 18/500
# 14/14 - 0s - loss: 0.0837 - val_loss: 0.0825 - 252ms/epoch - 18ms/step
# Epoch 19/500
# 14/14 - 0s - loss: 0.0818 - val_loss: 0.0796 - 254ms/epoch - 18ms/step
# Epoch 20/500
# 14/14 - 0s - loss: 0.0800 - val_loss: 0.0768 - 298ms/epoch - 21ms/step
# Epoch 21/500
# 14/14 - 0s - loss: 0.0786 - val_loss: 0.0736 - 273ms/epoch - 19ms/step
# Epoch 22/500
# 14/14 - 0s - loss: 0.0775 - val_loss: 0.0714 - 257ms/epoch - 18ms/step
# Epoch 23/500
# 14/14 - 0s - loss: 0.0762 - val_loss: 0.0706 - 253ms/epoch - 18ms/step
# Epoch 24/500
# 14/14 - 0s - loss: 0.0749 - val_loss: 0.0690 - 253ms/epoch - 18ms/step
# Epoch 25/500
# 14/14 - 0s - loss: 0.0753 - val_loss: 0.0684 - 256ms/epoch - 18ms/step
# Epoch 26/500
# 14/14 - 0s - loss: 0.0739 - val_loss: 0.0691 - 250ms/epoch - 18ms/step
# Epoch 27/500
# 14/14 - 0s - loss: 0.0759 - val_loss: 0.0711 - 248ms/epoch - 18ms/step
# Epoch 28/500
# 14/14 - 0s - loss: 0.0795 - val_loss: 0.0746 - 256ms/epoch - 18ms/step
# Epoch 29/500
# 14/14 - 0s - loss: 0.0856 - val_loss: 0.0728 - 265ms/epoch - 19ms/step
# Epoch 30/500
# 14/14 - 0s - loss: 0.0795 - val_loss: 0.0751 - 257ms/epoch - 18ms/step
# Epoch 31/500
# 14/14 - 0s - loss: 0.0750 - val_loss: 0.0682 - 261ms/epoch - 19ms/step
# Epoch 32/500
# 14/14 - 0s - loss: 0.0737 - val_loss: 0.0669 - 256ms/epoch - 18ms/step
# Epoch 33/500
# 14/14 - 0s - loss: 0.0753 - val_loss: 0.0688 - 255ms/epoch - 18ms/step
# Epoch 34/500
# 14/14 - 0s - loss: 0.0741 - val_loss: 0.0716 - 274ms/epoch - 20ms/step
# Epoch 35/500
# 14/14 - 0s - loss: 0.0722 - val_loss: 0.0691 - 246ms/epoch - 18ms/step
# Epoch 36/500
# 14/14 - 0s - loss: 0.0716 - val_loss: 0.0668 - 253ms/epoch - 18ms/step
# Epoch 37/500
# 14/14 - 0s - loss: 0.0715 - val_loss: 0.0668 - 269ms/epoch - 19ms/step
# Epoch 38/500
# 14/14 - 0s - loss: 0.0718 - val_loss: 0.0675 - 260ms/epoch - 19ms/step
# Epoch 39/500
# 14/14 - 0s - loss: 0.0715 - val_loss: 0.0689 - 268ms/epoch - 19ms/step
# Epoch 40/500
# 14/14 - 0s - loss: 0.0711 - val_loss: 0.0676 - 274ms/epoch - 20ms/step
# Epoch 41/500
# 14/14 - 0s - loss: 0.0710 - val_loss: 0.0669 - 260ms/epoch - 19ms/step
# Epoch 42/500
# 14/14 - 0s - loss: 0.0710 - val_loss: 0.0667 - 258ms/epoch - 18ms/step
# Epoch 43/500
# 14/14 - 0s - loss: 0.0711 - val_loss: 0.0667 - 265ms/epoch - 19ms/step
# Epoch 44/500
# 14/14 - 0s - loss: 0.0712 - val_loss: 0.0670 - 253ms/epoch - 18ms/step
# Epoch 45/500
# 14/14 - 0s - loss: 0.0709 - val_loss: 0.0678 - 263ms/epoch - 19ms/step
# Epoch 46/500
# 14/14 - 0s - loss: 0.0707 - val_loss: 0.0678 - 269ms/epoch - 19ms/step
# Epoch 47/500
# 14/14 - 0s - loss: 0.0706 - val_loss: 0.0680 - 255ms/epoch - 18ms/step
# Epoch 48/500
# 14/14 - 0s - loss: 0.0704 - val_loss: 0.0683 - 276ms/epoch - 20ms/step
# Epoch 49/500
# 14/14 - 0s - loss: 0.0704 - val_loss: 0.0674 - 263ms/epoch - 19ms/step
# Epoch 50/500
# 14/14 - 0s - loss: 0.0705 - val_loss: 0.0670 - 265ms/epoch - 19ms/step
# Epoch 51/500
# 14/14 - 0s - loss: 0.0705 - val_loss: 0.0668 - 259ms/epoch - 18ms/step
# Epoch 52/500
# 14/14 - 0s - loss: 0.0707 - val_loss: 0.0668 - 258ms/epoch - 18ms/step
# Epoch 53/500
# 14/14 - 0s - loss: 0.0710 - val_loss: 0.0668 - 251ms/epoch - 18ms/step
# Epoch 54/500
# 14/14 - 0s - loss: 0.0713 - val_loss: 0.0670 - 260ms/epoch - 19ms/step
# Epoch 55/500
# 14/14 - 0s - loss: 0.0711 - val_loss: 0.0672 - 243ms/epoch - 17ms/step
# Epoch 56/500
# 14/14 - 0s - loss: 0.0707 - val_loss: 0.0674 - 272ms/epoch - 19ms/step
# Epoch 57/500
# 14/14 - 0s - loss: 0.0712 - val_loss: 0.0684 - 253ms/epoch - 18ms/step
# Epoch 58/500
# 14/14 - 0s - loss: 0.0704 - val_loss: 0.0683 - 256ms/epoch - 18ms/step
# Epoch 59/500
# 14/14 - 0s - loss: 0.0702 - val_loss: 0.0709 - 256ms/epoch - 18ms/step
# Epoch 60/500
# 14/14 - 0s - loss: 0.0709 - val_loss: 0.0697 - 259ms/epoch - 18ms/step
# Epoch 61/500
# 14/14 - 0s - loss: 0.0699 - val_loss: 0.0700 - 253ms/epoch - 18ms/step
# Epoch 62/500
# 14/14 - 0s - loss: 0.0705 - val_loss: 0.0690 - 249ms/epoch - 18ms/step
# Epoch 63/500
# 14/14 - 0s - loss: 0.0701 - val_loss: 0.0677 - 259ms/epoch - 18ms/step
# Epoch 64/500
# 14/14 - 0s - loss: 0.0697 - val_loss: 0.0673 - 251ms/epoch - 18ms/step
# Epoch 65/500
# 14/14 - 0s - loss: 0.0699 - val_loss: 0.0668 - 249ms/epoch - 18ms/step
# Epoch 66/500
# 14/14 - 0s - loss: 0.0700 - val_loss: 0.0669 - 256ms/epoch - 18ms/step
# Epoch 67/500
# 14/14 - 0s - loss: 0.0706 - val_loss: 0.0674 - 245ms/epoch - 17ms/step
# Epoch 68/500
# 14/14 - 0s - loss: 0.0700 - val_loss: 0.0677 - 256ms/epoch - 18ms/step
# Epoch 69/500
# 14/14 - 0s - loss: 0.0706 - val_loss: 0.0689 - 260ms/epoch - 19ms/step
# Epoch 70/500
# 14/14 - 0s - loss: 0.0699 - val_loss: 0.0685 - 247ms/epoch - 18ms/step
# Epoch 71/500
# 14/14 - 0s - loss: 0.0695 - val_loss: 0.0695 - 240ms/epoch - 17ms/step
# Epoch 72/500
# 14/14 - 0s - loss: 0.0698 - val_loss: 0.0699 - 257ms/epoch - 18ms/step
# Epoch 73/500
# 14/14 - 0s - loss: 0.0699 - val_loss: 0.0690 - 253ms/epoch - 18ms/step
# Epoch 74/500
# 14/14 - 0s - loss: 0.0694 - val_loss: 0.0681 - 258ms/epoch - 18ms/step
# Epoch 75/500
# 14/14 - 0s - loss: 0.0693 - val_loss: 0.0672 - 247ms/epoch - 18ms/step
# Epoch 76/500
# 14/14 - 0s - loss: 0.0695 - val_loss: 0.0671 - 300ms/epoch - 21ms/step
# Epoch 77/500
# 14/14 - 0s - loss: 0.0701 - val_loss: 0.0675 - 262ms/epoch - 19ms/step
# Epoch 78/500
# 14/14 - 0s - loss: 0.0696 - val_loss: 0.0677 - 254ms/epoch - 18ms/step
# Epoch 79/500
# 14/14 - 0s - loss: 0.0707 - val_loss: 0.0684 - 265ms/epoch - 19ms/step
# Epoch 80/500
# 14/14 - 0s - loss: 0.0692 - val_loss: 0.0684 - 262ms/epoch - 19ms/step
# Epoch 81/500
# 14/14 - 0s - loss: 0.0691 - val_loss: 0.0701 - 265ms/epoch - 19ms/step
# Epoch 82/500
# 14/14 - 0s - loss: 0.0697 - val_loss: 0.0688 - 263ms/epoch - 19ms/step
# Epoch 83/500
# 14/14 - 0s - loss: 0.0688 - val_loss: 0.0688 - 261ms/epoch - 19ms/step
# Epoch 84/500
# 14/14 - 0s - loss: 0.0690 - val_loss: 0.0683 - 253ms/epoch - 18ms/step
# Epoch 85/500
# 14/14 - 0s - loss: 0.0687 - val_loss: 0.0677 - 267ms/epoch - 19ms/step
# Epoch 86/500
# 14/14 - 0s - loss: 0.0689 - val_loss: 0.0681 - 243ms/epoch - 17ms/step
# Epoch 87/500
# 14/14 - 0s - loss: 0.0692 - val_loss: 0.0678 - 257ms/epoch - 18ms/step
# Epoch 88/500
# 14/14 - 0s - loss: 0.0696 - val_loss: 0.0693 - 251ms/epoch - 18ms/step
# Epoch 89/500
# 14/14 - 0s - loss: 0.0686 - val_loss: 0.0683 - 262ms/epoch - 19ms/step
# Epoch 90/500
# 14/14 - 0s - loss: 0.0691 - val_loss: 0.0700 - 247ms/epoch - 18ms/step
# Epoch 91/500
# 14/14 - 0s - loss: 0.0690 - val_loss: 0.0680 - 262ms/epoch - 19ms/step
# Epoch 92/500
# 14/14 - 0s - loss: 0.0694 - val_loss: 0.0706 - 271ms/epoch - 19ms/step
# Epoch 93/500
# 14/14 - 0s - loss: 0.0692 - val_loss: 0.0683 - 262ms/epoch - 19ms/step

# %% [markdown]
# ## Predictions of the year 2019

# %%
# make a prediction
yhat = model.predict(test_X)
#Convert from 3D to 2D
test_X = test_X.reshape((test_X.shape[0], n_days*n_features))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -5:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -5:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 7.889

# %% [markdown]
# #### Prediciton plots

# %%
pyplot.plot(inv_yhat, label = 'Prediction')
pyplot.plot(inv_y, label = 'Real')
pyplot.legend()
pyplot.show()

# %% [markdown]
# # Modeling with hyperparamenter search
# # Goal: reduce the MSE without overfitting

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 98 kB 3.2 MB/s

# %%
import tensorflow as tf
from tensorflow import keras
import keras_tuner as kt #Keras Creates a better model

# %%
tf.config.list_physical_devices('GPU') #To undestand which GPU using during the training
# Out:
# []

# %% [markdown]
# ## Function to create new models

# %%
def model_builder(hp):
  #design network
  #object created with keras_tuner -> iterates some parameters to create the model
  #units = neurons we use 32 steps for each time
  hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
  #Initialization of the model
  model = Sequential() 
  model.add(LSTM(units = hp_units,return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
  #for loop to iterate different quantities of layer (from 1 to 3 layer)
  for i in range(hp.Int('layers',1,3)):
   model.add(LSTM(units = hp_units, return_sequences=True))
  model.add(LSTM(units = hp_units, return_sequences=False))
  model.add(Dense(1))
  #Choose from a list of given instructions -> we choose leanrning rates
  #We look the performances
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
  model.compile(loss='mae', optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate))
  return model

# %% [markdown]
# # Creation of the object with model_builder(hp)
# ## Parameter to look at: validation loss

# %%
tuner = kt.RandomSearch(
    model_builder,
    objective='val_loss',
    max_trials=10,
    executions_per_trial =3,
    directory = 'dir',
    project_name = 'namee')
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 3
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 3, 'step': 1, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
early_stopping = EarlyStopping(monitor='val_loss',patience=10)
tuner.search(train_X, train_y, epochs=100, batch_size=72, validation_data=(test_X, test_y),shuffle=False, callbacks=[early_stopping])
# Out:
# Trial 10 Complete [00h 16m 14s]
# val_loss: 0.08407227694988251
#
# Best val_loss So Far: 0.06101139013965925
# Total elapsed time: 01h 00m 09s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in dir/namee
# Showing 10 best trials
# Objective(name='val_loss', direction='min')

# %% [markdown]
# ### Hyperband

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_loss',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')
# Out:
# INFO:tensorflow:Reloading Oracle from existing project my_dir/intro_to_kt/oracle.json
# INFO:tensorflow:Reloading Tuner from my_dir/intro_to_kt/tuner0.json

# %%
tuner.search(train_X, train_y, epochs=1000, batch_size=72, validation_data=(test_X, test_y),shuffle=False, callbacks=[early_stopping])
