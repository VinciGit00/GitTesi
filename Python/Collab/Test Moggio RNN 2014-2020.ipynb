# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import seaborn as sns
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
table = read_csv('/content/drive/MyDrive/Thesis/csvs/NNdata14_20.csv')
table.head()
# Out:
#                    Date  IDStation  ... Wind_direction_max  Rainfall
# 0  2014-01-01T00:00:00Z        681  ...              143.0       0.0
# 1  2014-01-02T00:00:00Z        681  ...              153.0       7.8
# 2  2014-01-03T00:00:00Z        681  ...              152.0       0.0
# 3  2014-01-04T00:00:00Z        681  ...              164.0      35.8
# 4  2014-01-05T00:00:00Z        681  ...              136.0      25.0
#
# [5 rows x 28 columns]

# %%
#Moggio = table.loc[table.loc[:,"NameStation"]=="Moggio",:]
Moggio = table.loc[:,["Date","Ammonia","PM10","PM25","Wind_speed","Wind_direction","Temperature","Rainfall"]]
Moggio = Moggio.dropna(how="any")
Moggio = Moggio.reset_index()
Moggio = Moggio.iloc[:-365,:] # we train not using 2020, for now
Moggio.head()
# Out:
#    index                  Date  Ammonia  ...  Wind_direction  Temperature  Rainfall
# 0      0  2014-01-01T00:00:00Z      0.0  ...            99.0    -0.334965       0.0
# 1      1  2014-01-02T00:00:00Z      0.0  ...           105.0    -0.486111       7.8
# 2      2  2014-01-03T00:00:00Z      0.0  ...           120.0     2.220588       0.0
# 3      3  2014-01-04T00:00:00Z      0.0  ...           175.0     2.137063      35.8
# 4      4  2014-01-05T00:00:00Z      0.0  ...            94.0     2.416084      25.0
#
# [5 rows x 9 columns]

# %%
sns.lineplot(x='Date', y='Ammonia', data=Moggio)

# %% [markdown]
# ##Convert series to supervised learning
# ### Activation function = tanh and logistic (s curve)

# %% [markdown]
# ###Conversion Function

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	"""
	Frame a time series as a supervised learning dataset.
	Arguments:
		data: Sequence of observations as a list or NumPy array.
		n_in: Number of lag observations as input (X).
		n_out: Number of observations as output (y).
		dropnan: Boolean whether or not to drop rows with NaN values.
	Returns:
		Pandas DataFrame of series framed for supervised learning.
	"""
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %% [markdown]
# ### Conversion of Moggio

# %%
values = Moggio.iloc[:,2:].values
# ensure all data is float
values = values.astype('float32') #cast in float 32 bit per evitare problemi
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
n_days = 5 #Memoria della NN
reframed = series_to_supervised(scaled, n_days, 1) # info of the past 5 days to determine next (1) day
# drop columns we don't want to predict (we therefore keep Ammonia)
reframed.drop(reframed.columns[[36,37,38,39,40,41]], axis=1, inplace=True)

reframed.head()
# Out:
#    var1(t-5)  var2(t-5)  var3(t-5)  ...  var6(t-1)  var7(t-1)  var1(t)
# 5        0.0   0.066667   0.088608  ...   0.358295   0.112816      0.0
# 6        0.0   0.066667   0.063291  ...   0.406390   0.000000      0.0
# 7        0.0   0.122222   0.050633  ...   0.397825   0.000000      0.0
# 8        0.0   0.066667   0.088608  ...   0.408315   0.000000      0.0
# 9        0.0   0.033333   0.101266  ...   0.392536   0.000000      0.0
#
# [5 rows x 36 columns]

# %%
# split into train and test sets
values = reframed.values
n_features = 7 # number of variables, including the one to be predicted
n_train_days = 1312 # we train using only the first few year
train = values[:n_train_days, :]
test = values[n_train_days:, :] # we test using all successive years 
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
# reshape from 2D to 3D
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1312, 35) 1312 (1312,)
# (1312, 5, 7) (1312,) (365, 5, 7) (365,)

# %% [markdown]
# # Modeling and training

# %%
# design the neural network
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
early_stopping = EarlyStopping(patience=10, restore_best_weights = True)
history = model.fit(train_X, train_y, epochs=500, batch_size=50, validation_data=(test_X, test_y), verbose=2, shuffle=False, callbacks=early_stopping)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/500
# 27/27 - 7s - loss: 0.1208 - val_loss: 0.1837 - 7s/epoch - 262ms/step
# Epoch 2/500
# 27/27 - 0s - loss: 0.1092 - val_loss: 0.1606 - 397ms/epoch - 15ms/step
# Epoch 3/500
# 27/27 - 0s - loss: 0.1074 - val_loss: 0.1445 - 409ms/epoch - 15ms/step
# Epoch 4/500
# 27/27 - 0s - loss: 0.0885 - val_loss: 0.0736 - 397ms/epoch - 15ms/step
# Epoch 5/500
# 27/27 - 0s - loss: 0.0623 - val_loss: 0.0839 - 407ms/epoch - 15ms/step
# Epoch 6/500
# 27/27 - 0s - loss: 0.0911 - val_loss: 0.1003 - 381ms/epoch - 14ms/step
# Epoch 7/500
# 27/27 - 0s - loss: 0.0562 - val_loss: 0.0719 - 384ms/epoch - 14ms/step
# Epoch 8/500
# 27/27 - 0s - loss: 0.0517 - val_loss: 0.0749 - 401ms/epoch - 15ms/step
# Epoch 9/500
# 27/27 - 0s - loss: 0.0639 - val_loss: 0.0704 - 406ms/epoch - 15ms/step
# Epoch 10/500
# 27/27 - 0s - loss: 0.0614 - val_loss: 0.0693 - 412ms/epoch - 15ms/step
# Epoch 11/500
# 27/27 - 0s - loss: 0.0549 - val_loss: 0.0688 - 418ms/epoch - 15ms/step
# Epoch 12/500
# 27/27 - 0s - loss: 0.0528 - val_loss: 0.0684 - 391ms/epoch - 14ms/step
# Epoch 13/500
# 27/27 - 0s - loss: 0.0528 - val_loss: 0.0667 - 405ms/epoch - 15ms/step
# Epoch 14/500
# 27/27 - 0s - loss: 0.0498 - val_loss: 0.0665 - 385ms/epoch - 14ms/step
# Epoch 15/500
# 27/27 - 0s - loss: 0.0500 - val_loss: 0.0651 - 380ms/epoch - 14ms/step
# Epoch 16/500
# 27/27 - 0s - loss: 0.0473 - val_loss: 0.0652 - 402ms/epoch - 15ms/step
# Epoch 17/500
# 27/27 - 0s - loss: 0.0480 - val_loss: 0.0637 - 385ms/epoch - 14ms/step
# Epoch 18/500
# 27/27 - 0s - loss: 0.0460 - val_loss: 0.0632 - 413ms/epoch - 15ms/step
# Epoch 19/500
# 27/27 - 0s - loss: 0.0462 - val_loss: 0.0629 - 398ms/epoch - 15ms/step
# Epoch 20/500
# 27/27 - 0s - loss: 0.0454 - val_loss: 0.0615 - 382ms/epoch - 14ms/step
# Epoch 21/500
# 27/27 - 0s - loss: 0.0442 - val_loss: 0.0595 - 394ms/epoch - 15ms/step
# Epoch 22/500
# 27/27 - 0s - loss: 0.0431 - val_loss: 0.0581 - 387ms/epoch - 14ms/step
# Epoch 23/500
# 27/27 - 0s - loss: 0.0420 - val_loss: 0.0560 - 397ms/epoch - 15ms/step
# Epoch 24/500
# 27/27 - 0s - loss: 0.0409 - val_loss: 0.0553 - 378ms/epoch - 14ms/step
# Epoch 25/500
# 27/27 - 0s - loss: 0.0405 - val_loss: 0.0541 - 374ms/epoch - 14ms/step
# Epoch 26/500
# 27/27 - 0s - loss: 0.0393 - val_loss: 0.0531 - 404ms/epoch - 15ms/step
# Epoch 27/500
# 27/27 - 0s - loss: 0.0379 - val_loss: 0.0527 - 390ms/epoch - 14ms/step
# Epoch 28/500
# 27/27 - 0s - loss: 0.0371 - val_loss: 0.0506 - 386ms/epoch - 14ms/step
# Epoch 29/500
# 27/27 - 0s - loss: 0.0360 - val_loss: 0.0482 - 388ms/epoch - 14ms/step
# Epoch 30/500
# 27/27 - 0s - loss: 0.0358 - val_loss: 0.0493 - 361ms/epoch - 13ms/step
# Epoch 31/500
# 27/27 - 0s - loss: 0.0350 - val_loss: 0.0484 - 400ms/epoch - 15ms/step
# Epoch 32/500
# 27/27 - 0s - loss: 0.0337 - val_loss: 0.0484 - 384ms/epoch - 14ms/step
# Epoch 33/500
# 27/27 - 0s - loss: 0.0341 - val_loss: 0.0492 - 390ms/epoch - 14ms/step
# Epoch 34/500
# 27/27 - 0s - loss: 0.0341 - val_loss: 0.0488 - 401ms/epoch - 15ms/step
# Epoch 35/500
# 27/27 - 0s - loss: 0.0338 - val_loss: 0.0488 - 359ms/epoch - 13ms/step
# Epoch 36/500
# 27/27 - 0s - loss: 0.0337 - val_loss: 0.0481 - 368ms/epoch - 14ms/step
# Epoch 37/500
# 27/27 - 0s - loss: 0.0336 - val_loss: 0.0487 - 384ms/epoch - 14ms/step
# Epoch 38/500
# 27/27 - 0s - loss: 0.0334 - val_loss: 0.0482 - 378ms/epoch - 14ms/step
# Epoch 39/500
# 27/27 - 0s - loss: 0.0331 - val_loss: 0.0478 - 391ms/epoch - 14ms/step
# Epoch 40/500
# 27/27 - 0s - loss: 0.0331 - val_loss: 0.0482 - 374ms/epoch - 14ms/step
# Epoch 41/500
# 27/27 - 0s - loss: 0.0326 - val_loss: 0.0467 - 380ms/epoch - 14ms/step
# Epoch 42/500
# 27/27 - 0s - loss: 0.0322 - val_loss: 0.0474 - 390ms/epoch - 14ms/step
# Epoch 43/500
# 27/27 - 0s - loss: 0.0320 - val_loss: 0.0458 - 364ms/epoch - 13ms/step
# Epoch 44/500
# 27/27 - 0s - loss: 0.0310 - val_loss: 0.0450 - 409ms/epoch - 15ms/step
# Epoch 45/500
# 27/27 - 0s - loss: 0.0308 - val_loss: 0.0461 - 379ms/epoch - 14ms/step
# Epoch 46/500
# 27/27 - 0s - loss: 0.0313 - val_loss: 0.0461 - 373ms/epoch - 14ms/step
# Epoch 47/500
# 27/27 - 0s - loss: 0.0308 - val_loss: 0.0448 - 383ms/epoch - 14ms/step
# Epoch 48/500
# 27/27 - 0s - loss: 0.0305 - val_loss: 0.0459 - 373ms/epoch - 14ms/step
# Epoch 49/500
# 27/27 - 0s - loss: 0.0315 - val_loss: 0.0459 - 372ms/epoch - 14ms/step
# Epoch 50/500
# 27/27 - 0s - loss: 0.0309 - val_loss: 0.0455 - 383ms/epoch - 14ms/step
# Epoch 51/500
# 27/27 - 0s - loss: 0.0309 - val_loss: 0.0475 - 370ms/epoch - 14ms/step
# Epoch 52/500
# 27/27 - 0s - loss: 0.0319 - val_loss: 0.0467 - 361ms/epoch - 13ms/step
# Epoch 53/500
# 27/27 - 0s - loss: 0.0330 - val_loss: 0.0467 - 374ms/epoch - 14ms/step
# Epoch 54/500
# 27/27 - 0s - loss: 0.0334 - val_loss: 0.0464 - 374ms/epoch - 14ms/step
# Epoch 55/500
# 27/27 - 0s - loss: 0.0325 - val_loss: 0.0465 - 394ms/epoch - 15ms/step
# Epoch 56/500
# 27/27 - 0s - loss: 0.0317 - val_loss: 0.0465 - 370ms/epoch - 14ms/step
# Epoch 57/500
# 27/27 - 0s - loss: 0.0321 - val_loss: 0.0452 - 390ms/epoch - 14ms/step

# %% [markdown]
# ## Predictions of the year 2019

# %%
# make a prediction
yhat = model.predict(test_X)
#Convert from 3D to 2D
test_X = test_X.reshape((test_X.shape[0], n_days*n_features))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -6:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -6:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 1.349

# %% [markdown]
# #### Prediciton plots

# %%
pyplot.plot(inv_yhat, label = 'Prediction')
pyplot.plot(inv_y, label = 'Real')
pyplot.legend()
pyplot.show()

# %% [markdown]
# # Modeling with hyperparamenter search
# # Goal: reduce the MSE without overfitting

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 98 kB 3.2 MB/s

# %%
import tensorflow as tf
from tensorflow import keras
import keras_tuner as kt #Keras Creates a better model

# %%
tf.config.list_physical_devices('GPU') #To undestand which GPU using during the training
# Out:
# []

# %% [markdown]
# ## Function to create new models

# %%
def model_builder(hp):
  #design network
  #object created with keras_tuner -> iterates some parameters to create the model
  #units = neurons we use 32 steps for each time
  hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
  #Initialization of the model
  model = Sequential() 
  model.add(LSTM(units = hp_units,return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
  #for loop to iterate different quantities of layer (from 1 to 3 layer)
  for i in range(hp.Int('layers',1,3)):
   model.add(LSTM(units = hp_units, return_sequences=True))
  model.add(LSTM(units = hp_units, return_sequences=False))
  model.add(Dense(1))
  #Choose from a list of given instructions -> we choose leanrning rates
  #We look the performances
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
  model.compile(loss='mae', optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate))
  return model

# %% [markdown]
# # Creation of the object with model_builder(hp)
# ## Parameter to look at: validation loss

# %%
tuner = kt.RandomSearch(
    model_builder,
    objective='val_loss',
    max_trials=10,
    executions_per_trial =3,
    directory = 'dir',
    project_name = 'namee')
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 3
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 3, 'step': 1, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
early_stopping = EarlyStopping(monitor='val_loss',patience=10)
tuner.search(train_X, train_y, epochs=100, batch_size=72, validation_data=(test_X, test_y),shuffle=False, callbacks=[early_stopping])
# Out:
# Trial 10 Complete [00h 16m 14s]
# val_loss: 0.08407227694988251
#
# Best val_loss So Far: 0.06101139013965925
# Total elapsed time: 01h 00m 09s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in dir/namee
# Showing 10 best trials
# Objective(name='val_loss', direction='min')

# %% [markdown]
# ### Hyperband

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_loss',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')
# Out:
# INFO:tensorflow:Reloading Oracle from existing project my_dir/intro_to_kt/oracle.json
# INFO:tensorflow:Reloading Tuner from my_dir/intro_to_kt/tuner0.json

# %%
tuner.search(train_X, train_y, epochs=1000, batch_size=72, validation_data=(test_X, test_y),shuffle=False, callbacks=[early_stopping])
