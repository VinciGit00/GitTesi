# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import seaborn as sns
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
table = read_csv('/content/drive/MyDrive/Quadranti.csv')
table.head()
# Out:
#    Unnamed: 0                  Date  Ammonia  ...  Temperature  Rainfall  Quadrante
# 0           0  2014-01-01T00:00:00Z      0.0  ...    -0.334965       0.0          2
# 1           1  2014-01-02T00:00:00Z      0.0  ...    -0.486111       7.8          2
# 2           2  2014-01-03T00:00:00Z      0.0  ...     2.220588       0.0          2
# 3           3  2014-01-04T00:00:00Z      0.0  ...     2.137063      35.8          2
# 4           4  2014-01-05T00:00:00Z      0.0  ...     2.416084      25.0          2
#
# [5 rows x 9 columns]

# %%
#Moggio = table.loc[table.loc[:,"NameStation"]=="Moggio",:]
#PM 2.5 were removed
Moggio = table.loc[:,["Date","PM10","Ammonia","Wind_speed","Quadrante","Temperature","Rainfall"]]
Moggio = Moggio.dropna(how="any")
Moggio = Moggio.reset_index()
Moggio = Moggio.iloc[:-365,:] # we train not using 2020, for now
Moggio.head()
# Out:
#    index                  Date  PM10  ...  Quadrante  Temperature  Rainfall
# 0      0  2014-01-01T00:00:00Z   6.0  ...          2    -0.334965       0.0
# 1      1  2014-01-02T00:00:00Z   6.0  ...          2    -0.486111       7.8
# 2      2  2014-01-03T00:00:00Z  11.0  ...          2     2.220588       0.0
# 3      3  2014-01-04T00:00:00Z   6.0  ...          2     2.137063      35.8
# 4      4  2014-01-05T00:00:00Z   3.0  ...          2     2.416084      25.0
#
# [5 rows x 8 columns]

# %%
# sns.lineplot(x='Date', y='PM25', data=Moggio)

# %% [markdown]
# ##Convert series to supervised learning
# ### Activation function = tanh and logistic (s curve)

# %% [markdown]
# ###Conversion Function

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	"""
	Frame a time series as a supervised learning dataset.
	Arguments:
		data: Sequence of observations as a list or NumPy array.
		n_in: Number of lag observations as input (X).
		n_out: Number of observations as output (y).
		dropnan: Boolean whether or not to drop rows with NaN values.
	Returns:
		Pandas DataFrame of series framed for supervised learning.
	"""
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %% [markdown]
# ### Conversion of Moggio

# %%
values = Moggio.iloc[:,2:].values
# ensure all data is float
values = values.astype('float32') #cast in float 32 bit per evitare problemi
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
n_days = 5 #Memoria della NN
reframed = series_to_supervised(scaled, n_days, 1) # info of the past 5 days to determine next (1) day
# drop columns we don't want to predict (we therefore keep Ammonia)
reframed.drop(reframed.columns[[31,32,33,34,35]], axis=1, inplace=True)

reframed.head()
# Out:
#    var1(t-5)  var2(t-5)  var3(t-5)  ...  var5(t-1)  var6(t-1)   var1(t)
# 5   0.066667        0.0   0.163005  ...   0.358295   0.112816  0.022222
# 6   0.066667        0.0   0.130139  ...   0.406390   0.000000  0.077778
# 7   0.122222        0.0   0.074531  ...   0.397825   0.000000  0.044444
# 8   0.066667        0.0   0.381024  ...   0.408315   0.000000  0.044444
# 9   0.033333        0.0   0.246694  ...   0.392536   0.000000  0.133333
#
# [5 rows x 31 columns]

# %%
# split into train and test sets
values = reframed.values
n_features = 6 # number of variables, including the one to be predicted
n_train_days = 1312 # we train using only the first year
train = values[:n_train_days, :]
test = values[n_train_days:, :] # we test using all successive years 
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
# reshape from 2D to 3D
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1312, 30) 1312 (1312,)
# (1312, 5, 6) (1312,) (404, 5, 6) (404,)

# %% [markdown]
# # Modeling and training

# %%
# design the neural network
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
early_stopping = EarlyStopping(patience=50, restore_best_weights = True)
history = model.fit(train_X, train_y, epochs=500, batch_size=100, validation_data=(test_X, test_y), verbose=2, shuffle=False, callbacks=early_stopping)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/500
# 14/14 - 7s - loss: 0.1078 - val_loss: 0.0916 - 7s/epoch - 492ms/step
# Epoch 2/500
# 14/14 - 0s - loss: 0.0937 - val_loss: 0.0870 - 234ms/epoch - 17ms/step
# Epoch 3/500
# 14/14 - 0s - loss: 0.0911 - val_loss: 0.0863 - 232ms/epoch - 17ms/step
# Epoch 4/500
# 14/14 - 0s - loss: 0.0907 - val_loss: 0.0862 - 231ms/epoch - 17ms/step
# Epoch 5/500
# 14/14 - 0s - loss: 0.0899 - val_loss: 0.0856 - 224ms/epoch - 16ms/step
# Epoch 6/500
# 14/14 - 0s - loss: 0.0897 - val_loss: 0.0864 - 236ms/epoch - 17ms/step
# Epoch 7/500
# 14/14 - 0s - loss: 0.0896 - val_loss: 0.0869 - 217ms/epoch - 15ms/step
# Epoch 8/500
# 14/14 - 0s - loss: 0.0891 - val_loss: 0.0868 - 225ms/epoch - 16ms/step
# Epoch 9/500
# 14/14 - 0s - loss: 0.0886 - val_loss: 0.0853 - 218ms/epoch - 16ms/step
# Epoch 10/500
# 14/14 - 0s - loss: 0.0884 - val_loss: 0.0855 - 221ms/epoch - 16ms/step
# Epoch 11/500
# 14/14 - 0s - loss: 0.0884 - val_loss: 0.0870 - 234ms/epoch - 17ms/step
# Epoch 12/500
# 14/14 - 0s - loss: 0.0880 - val_loss: 0.0857 - 225ms/epoch - 16ms/step
# Epoch 13/500
# 14/14 - 0s - loss: 0.0873 - val_loss: 0.0842 - 216ms/epoch - 15ms/step
# Epoch 14/500
# 14/14 - 0s - loss: 0.0867 - val_loss: 0.0842 - 230ms/epoch - 16ms/step
# Epoch 15/500
# 14/14 - 0s - loss: 0.0862 - val_loss: 0.0834 - 230ms/epoch - 16ms/step
# Epoch 16/500
# 14/14 - 0s - loss: 0.0859 - val_loss: 0.0846 - 214ms/epoch - 15ms/step
# Epoch 17/500
# 14/14 - 0s - loss: 0.0850 - val_loss: 0.0844 - 242ms/epoch - 17ms/step
# Epoch 18/500
# 14/14 - 0s - loss: 0.0839 - val_loss: 0.0825 - 218ms/epoch - 16ms/step
# Epoch 19/500
# 14/14 - 0s - loss: 0.0822 - val_loss: 0.0803 - 222ms/epoch - 16ms/step
# Epoch 20/500
# 14/14 - 0s - loss: 0.0802 - val_loss: 0.0760 - 227ms/epoch - 16ms/step
# Epoch 21/500
# 14/14 - 0s - loss: 0.0798 - val_loss: 0.0742 - 218ms/epoch - 16ms/step
# Epoch 22/500
# 14/14 - 0s - loss: 0.0779 - val_loss: 0.0729 - 224ms/epoch - 16ms/step
# Epoch 23/500
# 14/14 - 0s - loss: 0.0770 - val_loss: 0.0721 - 221ms/epoch - 16ms/step
# Epoch 24/500
# 14/14 - 0s - loss: 0.0762 - val_loss: 0.0713 - 238ms/epoch - 17ms/step
# Epoch 25/500
# 14/14 - 0s - loss: 0.0755 - val_loss: 0.0709 - 232ms/epoch - 17ms/step
# Epoch 26/500
# 14/14 - 0s - loss: 0.0782 - val_loss: 0.0749 - 217ms/epoch - 16ms/step
# Epoch 27/500
# 14/14 - 0s - loss: 0.0823 - val_loss: 0.0720 - 215ms/epoch - 15ms/step
# Epoch 28/500
# 14/14 - 0s - loss: 0.0835 - val_loss: 0.0781 - 234ms/epoch - 17ms/step
# Epoch 29/500
# 14/14 - 0s - loss: 0.0767 - val_loss: 0.0728 - 220ms/epoch - 16ms/step
# Epoch 30/500
# 14/14 - 0s - loss: 0.0733 - val_loss: 0.0678 - 217ms/epoch - 16ms/step
# Epoch 31/500
# 14/14 - 0s - loss: 0.0719 - val_loss: 0.0669 - 215ms/epoch - 15ms/step
# Epoch 32/500
# 14/14 - 0s - loss: 0.0734 - val_loss: 0.0674 - 223ms/epoch - 16ms/step
# Epoch 33/500
# 14/14 - 0s - loss: 0.0747 - val_loss: 0.0693 - 227ms/epoch - 16ms/step
# Epoch 34/500
# 14/14 - 0s - loss: 0.0728 - val_loss: 0.0711 - 223ms/epoch - 16ms/step
# Epoch 35/500
# 14/14 - 0s - loss: 0.0716 - val_loss: 0.0684 - 215ms/epoch - 15ms/step
# Epoch 36/500
# 14/14 - 0s - loss: 0.0714 - val_loss: 0.0669 - 210ms/epoch - 15ms/step
# Epoch 37/500
# 14/14 - 0s - loss: 0.0715 - val_loss: 0.0665 - 214ms/epoch - 15ms/step
# Epoch 38/500
# 14/14 - 0s - loss: 0.0724 - val_loss: 0.0671 - 229ms/epoch - 16ms/step
# Epoch 39/500
# 14/14 - 0s - loss: 0.0722 - val_loss: 0.0697 - 218ms/epoch - 16ms/step
# Epoch 40/500
# 14/14 - 0s - loss: 0.0713 - val_loss: 0.0696 - 223ms/epoch - 16ms/step
# Epoch 41/500
# 14/14 - 0s - loss: 0.0712 - val_loss: 0.0670 - 221ms/epoch - 16ms/step
# Epoch 42/500
# 14/14 - 0s - loss: 0.0710 - val_loss: 0.0664 - 234ms/epoch - 17ms/step
# Epoch 43/500
# 14/14 - 0s - loss: 0.0713 - val_loss: 0.0668 - 219ms/epoch - 16ms/step
# Epoch 44/500
# 14/14 - 0s - loss: 0.0717 - val_loss: 0.0676 - 214ms/epoch - 15ms/step
# Epoch 45/500
# 14/14 - 0s - loss: 0.0721 - val_loss: 0.0714 - 219ms/epoch - 16ms/step
# Epoch 46/500
# 14/14 - 0s - loss: 0.0714 - val_loss: 0.0693 - 219ms/epoch - 16ms/step
# Epoch 47/500
# 14/14 - 0s - loss: 0.0716 - val_loss: 0.0668 - 233ms/epoch - 17ms/step
# Epoch 48/500
# 14/14 - 0s - loss: 0.0707 - val_loss: 0.0663 - 223ms/epoch - 16ms/step
# Epoch 49/500
# 14/14 - 0s - loss: 0.0715 - val_loss: 0.0668 - 219ms/epoch - 16ms/step
# Epoch 50/500
# 14/14 - 0s - loss: 0.0717 - val_loss: 0.0687 - 213ms/epoch - 15ms/step
# Epoch 51/500
# 14/14 - 0s - loss: 0.0707 - val_loss: 0.0692 - 227ms/epoch - 16ms/step
# Epoch 52/500
# 14/14 - 0s - loss: 0.0704 - val_loss: 0.0679 - 215ms/epoch - 15ms/step
# Epoch 53/500
# 14/14 - 0s - loss: 0.0704 - val_loss: 0.0667 - 221ms/epoch - 16ms/step
# Epoch 54/500
# 14/14 - 0s - loss: 0.0703 - val_loss: 0.0666 - 220ms/epoch - 16ms/step
# Epoch 55/500
# 14/14 - 0s - loss: 0.0707 - val_loss: 0.0673 - 220ms/epoch - 16ms/step
# Epoch 56/500
# 14/14 - 0s - loss: 0.0708 - val_loss: 0.0676 - 229ms/epoch - 16ms/step
# Epoch 57/500
# 14/14 - 0s - loss: 0.0710 - val_loss: 0.0702 - 219ms/epoch - 16ms/step
# Epoch 58/500
# 14/14 - 0s - loss: 0.0705 - val_loss: 0.0684 - 219ms/epoch - 16ms/step
# Epoch 59/500
# 14/14 - 0s - loss: 0.0706 - val_loss: 0.0668 - 225ms/epoch - 16ms/step
# Epoch 60/500
# 14/14 - 0s - loss: 0.0701 - val_loss: 0.0665 - 219ms/epoch - 16ms/step
# Epoch 61/500
# 14/14 - 0s - loss: 0.0706 - val_loss: 0.0670 - 233ms/epoch - 17ms/step
# Epoch 62/500
# 14/14 - 0s - loss: 0.0705 - val_loss: 0.0674 - 210ms/epoch - 15ms/step
# Epoch 63/500
# 14/14 - 0s - loss: 0.0709 - val_loss: 0.0698 - 216ms/epoch - 15ms/step
# Epoch 64/500
# 14/14 - 0s - loss: 0.0700 - val_loss: 0.0685 - 225ms/epoch - 16ms/step
# Epoch 65/500
# 14/14 - 0s - loss: 0.0701 - val_loss: 0.0671 - 227ms/epoch - 16ms/step
# Epoch 66/500
# 14/14 - 0s - loss: 0.0697 - val_loss: 0.0663 - 213ms/epoch - 15ms/step
# Epoch 67/500
# 14/14 - 0s - loss: 0.0702 - val_loss: 0.0668 - 217ms/epoch - 16ms/step
# Epoch 68/500
# 14/14 - 0s - loss: 0.0702 - val_loss: 0.0672 - 256ms/epoch - 18ms/step
# Epoch 69/500
# 14/14 - 0s - loss: 0.0710 - val_loss: 0.0704 - 218ms/epoch - 16ms/step
# Epoch 70/500
# 14/14 - 0s - loss: 0.0702 - val_loss: 0.0676 - 231ms/epoch - 16ms/step
# Epoch 71/500
# 14/14 - 0s - loss: 0.0698 - val_loss: 0.0666 - 223ms/epoch - 16ms/step
# Epoch 72/500
# 14/14 - 0s - loss: 0.0693 - val_loss: 0.0674 - 221ms/epoch - 16ms/step
# Epoch 73/500
# 14/14 - 0s - loss: 0.0693 - val_loss: 0.0673 - 214ms/epoch - 15ms/step
# Epoch 74/500
# 14/14 - 0s - loss: 0.0700 - val_loss: 0.0685 - 236ms/epoch - 17ms/step
# Epoch 75/500
# 14/14 - 0s - loss: 0.0698 - val_loss: 0.0702 - 228ms/epoch - 16ms/step
# Epoch 76/500
# 14/14 - 0s - loss: 0.0701 - val_loss: 0.0671 - 221ms/epoch - 16ms/step
# Epoch 77/500
# 14/14 - 0s - loss: 0.0693 - val_loss: 0.0666 - 222ms/epoch - 16ms/step
# Epoch 78/500
# 14/14 - 0s - loss: 0.0692 - val_loss: 0.0671 - 236ms/epoch - 17ms/step
# Epoch 79/500
# 14/14 - 0s - loss: 0.0692 - val_loss: 0.0672 - 246ms/epoch - 18ms/step
# Epoch 80/500
# 14/14 - 0s - loss: 0.0700 - val_loss: 0.0695 - 223ms/epoch - 16ms/step
# Epoch 81/500
# 14/14 - 0s - loss: 0.0692 - val_loss: 0.0686 - 221ms/epoch - 16ms/step
# Epoch 82/500
# 14/14 - 0s - loss: 0.0692 - val_loss: 0.0670 - 216ms/epoch - 15ms/step
# Epoch 83/500
# 14/14 - 0s - loss: 0.0687 - val_loss: 0.0669 - 229ms/epoch - 16ms/step
# Epoch 84/500
# 14/14 - 0s - loss: 0.0687 - val_loss: 0.0673 - 217ms/epoch - 16ms/step
# Epoch 85/500
# 14/14 - 0s - loss: 0.0687 - val_loss: 0.0673 - 226ms/epoch - 16ms/step
# Epoch 86/500
# 14/14 - 0s - loss: 0.0693 - val_loss: 0.0683 - 214ms/epoch - 15ms/step
# Epoch 87/500
# 14/14 - 0s - loss: 0.0688 - val_loss: 0.0688 - 233ms/epoch - 17ms/step
# Epoch 88/500
# 14/14 - 0s - loss: 0.0688 - val_loss: 0.0674 - 218ms/epoch - 16ms/step
# Epoch 89/500
# 14/14 - 0s - loss: 0.0684 - val_loss: 0.0675 - 214ms/epoch - 15ms/step
# Epoch 90/500
# 14/14 - 0s - loss: 0.0683 - val_loss: 0.0670 - 212ms/epoch - 15ms/step
# Epoch 91/500
# 14/14 - 0s - loss: 0.0683 - val_loss: 0.0671 - 208ms/epoch - 15ms/step
# Epoch 92/500
# 14/14 - 0s - loss: 0.0688 - val_loss: 0.0670 - 226ms/epoch - 16ms/step
# Epoch 93/500
# 14/14 - 0s - loss: 0.0690 - val_loss: 0.0683 - 210ms/epoch - 15ms/step
# Epoch 94/500
# 14/14 - 0s - loss: 0.0685 - val_loss: 0.0680 - 204ms/epoch - 15ms/step
# Epoch 95/500
# 14/14 - 0s - loss: 0.0685 - val_loss: 0.0676 - 212ms/epoch - 15ms/step
# Epoch 96/500
# 14/14 - 0s - loss: 0.0679 - val_loss: 0.0678 - 217ms/epoch - 15ms/step
# Epoch 97/500
# 14/14 - 0s - loss: 0.0679 - val_loss: 0.0676 - 223ms/epoch - 16ms/step
# Epoch 98/500
# 14/14 - 0s - loss: 0.0683 - val_loss: 0.0678 - 210ms/epoch - 15ms/step

# %% [markdown]
# ## Predictions of the year 2019

# %%
# make a prediction
yhat = model.predict(test_X)
#Convert from 3D to 2D
test_X = test_X.reshape((test_X.shape[0], n_days*n_features))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -5:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -5:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 7.919

# %% [markdown]
# #### Prediciton plots

# %%
pyplot.plot(inv_yhat, label = 'Prediction')
pyplot.plot(inv_y, label = 'Real')
pyplot.legend()
pyplot.title("Previsione solo con Ammonia ")
pyplot.xlabel('Days') 
pyplot.ylabel('PM10') 
pyplot.show()

# %% [markdown]
# prediction with 2020

# %%
#Moggio = table.loc[table.loc[:,"NameStation"]=="Moggio",:]
#PM 2.5 were removed

Moggio = table.loc[:,["Date","PM10","Ammonia","Wind_speed","Quadrante","Temperature","Rainfall"]]
Moggio = Moggio.dropna(how="any")
Moggio = Moggio.reset_index()
Moggio = Moggio.iloc[:,:] # this is the differrence!!!!
Moggio.head()
values = Moggio.iloc[:,2:].values
# ensure all data is float
values = values.astype('float32') #cast in float 32 bit per evitare problemi
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
n_days = 5 #Memoria della NN
reframed = series_to_supervised(scaled, n_days, 1) # info of the past 5 days to determine next (1) day
# drop columns we don't want to predict (we therefore keep Ammonia)
reframed.drop(reframed.columns[[31,32,33,34,35]], axis=1, inplace=True)

# split into train and test sets
values = reframed.values
n_features = 6 # number of variables, including the one to be predicted
n_train_days = 1312 # we train using only the first year
train = values[:n_train_days, :]
test = values[n_train_days:, :] # we test using all successive years 
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
# reshape from 2D to 3D
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1312, 30) 1312 (1312,)
# (1312, 5, 6) (1312,) (769, 5, 6) (769,)

# %%
# make a prediction
yhat = model.predict(test_X)
#Convert from 3D to 2D
test_X = test_X.reshape((test_X.shape[0], n_days*n_features))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -5:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -5:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 7.333

# %%
pyplot.plot(inv_yhat[-365:], label = 'Prediction')
pyplot.plot(inv_y[-365:], label = 'Real')
pyplot.legend()
pyplot.title("Previsione solo con Ammonia ")
pyplot.xlabel('Days') 
pyplot.ylabel('PM10') 
pyplot.show()
