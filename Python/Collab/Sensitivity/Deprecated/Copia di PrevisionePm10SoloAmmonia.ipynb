# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow.keras as keras

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
table = read_csv('/content/drive/MyDrive/Quadranti.csv')
Moggio = table.dropna(how="any")
Moggio
# Out:
#       Unnamed: 0                  Date  ...  Rainfall  Quadrante
# 0              0  2014-01-01T00:00:00Z  ...       0.0          2
# 1              1  2014-01-02T00:00:00Z  ...       7.8          2
# 2              2  2014-01-03T00:00:00Z  ...       0.0          2
# 3              3  2014-01-04T00:00:00Z  ...      35.8          2
# 4              4  2014-01-05T00:00:00Z  ...      25.0          2
# ...          ...                   ...  ...       ...        ...
# 2523        2523  2020-12-27T00:00:00Z  ...       0.0          1
# 2524        2524  2020-12-28T00:00:00Z  ...      27.6          2
# 2525        2525  2020-12-29T00:00:00Z  ...       2.2          2
# 2526        2526  2020-12-30T00:00:00Z  ...       0.0          3
# 2527        2527  2020-12-31T00:00:00Z  ...       0.0          2
#
# [2032 rows x 9 columns]

# %%
#Moggio = table.loc[table.loc[:,"NameStation"]=="Moggio",:]
#Moggio = Moggio.loc[:,["Date","Ammonia","PM10","PM25","Wind_speed","Wind_direction","Temperature","Rainfall"]]

Moggio = Moggio.reset_index()
Moggio = Moggio.iloc[:1667,:] # we train not using 2020, for now
Moggio = Moggio[['index','Unnamed: 0', 'Date','PM10','PM25', 'Ammonia', 'Wind_speed', 'Temperature','Rainfall', 'Quadrante']]

Moggio #Girare i posti delle variabili
# Out:
#       index  Unnamed: 0                  Date  ...  Temperature  Rainfall  Quadrante
# 0         0           0  2014-01-01T00:00:00Z  ...    -0.334965       0.0          2
# 1         1           1  2014-01-02T00:00:00Z  ...    -0.486111       7.8          2
# 2         2           2  2014-01-03T00:00:00Z  ...     2.220588       0.0          2
# 3         3           3  2014-01-04T00:00:00Z  ...     2.137063      35.8          2
# 4         4           4  2014-01-05T00:00:00Z  ...     2.416084      25.0          2
# ...     ...         ...                   ...  ...          ...       ...        ...
# 1662   2112        2112  2019-11-09T00:00:00Z  ...     3.863889       0.0          2
# 1663   2113        2113  2019-11-10T00:00:00Z  ...     3.068056       0.0          2
# 1664   2114        2114  2019-11-11T00:00:00Z  ...     2.556250      21.6          3
# 1665   2115        2115  2019-11-12T00:00:00Z  ...     3.682639      20.2          1
# 1666   2116        2116  2019-11-13T00:00:00Z  ...     2.556944       0.0          4
#
# [1667 rows x 10 columns]

# %% [markdown]
# ##Convert series to supervised learning

# %% [markdown]
# ###Conversion Function

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	"""
	Frame a time series as a supervised learning dataset.
	Arguments:
		data: Sequence of observations as a list or NumPy array.
		n_in: Number of lag observations as input (X).
		n_out: Number of observations as output (y).
		dropnan: Boolean whether or not to drop rows with NaN values.
	Returns:
		Pandas DataFrame of series framed for supervised learning.
	"""
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %% [markdown]
# ### Conversion of Moggio

# %%
values = Moggio.iloc[:,3:].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
n_days = 5
reframed = series_to_supervised(scaled, n_days, 1) # info of the past 5 days to determine next (1) day
# drop columns we don't want to predict (we therefore keep Ammonia)
reframed.drop(reframed.columns[[31,32,33,34,35]], axis=1, inplace=True)
print(reframed.shape)
reframed
# Out:
# (1662, 37)
#       var1(t-5)  var2(t-5)  var3(t-5)  ...   var5(t)   var6(t)   var7(t)
# 5      0.066667   0.088608   0.000000  ...  0.406390  0.000000  0.000000
# 6      0.066667   0.063291   0.000000  ...  0.397825  0.000000  0.000000
# 7      0.122222   0.050633   0.000000  ...  0.408315  0.000000  0.333333
# 8      0.066667   0.088608   0.000000  ...  0.392536  0.000000  0.000000
# 9      0.033333   0.101266   0.000000  ...  0.409331  0.000000  0.666667
# ...         ...        ...        ...  ...       ...       ...       ...
# 1662   0.044444   0.037975   0.024752  ...  0.396149  0.000000  0.333333
# 1663   0.000000   0.000000   0.059406  ...  0.375341  0.000000  0.333333
# 1664   0.033333   0.025316   0.009901  ...  0.361960  0.097473  0.666667
# 1665   0.044444   0.012658   0.000000  ...  0.391410  0.091155  0.000000
# 1666   0.011111   0.025316   0.000000  ...  0.361978  0.000000  1.000000
#
# [1662 rows x 37 columns]

# %%
# split into train and test sets
values = reframed.values
n_features = 7 # number of variables, including the one to be predicted
n_train_days = 1667-365 # we train using only the first year
train = values[:n_train_days, :]
test = values[n_train_days:, :] # we test using all successive years 
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1302, 35) 1302 (1302,)
# (1302, 5, 7) (1302,) (360, 5, 7) (360,)

# %% [markdown]
# # Modeling and training

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
from tensorflow.keras.layers import RNN
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.16.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.6 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.16.1

# %%
# design network
model = Sequential()
model.add(RNN(tfa.rnn.LayerNormLSTMCell(50), return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(RNN(tfa.rnn.LayerNormLSTMCell(50), return_sequences=True))
model.add(RNN(tfa.rnn.LayerNormLSTMCell(50), return_sequences=False))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')
# fit network
early_stopping = EarlyStopping(patience=70, restore_best_weights = True)
history = model.fit(train_X, train_y, epochs=1000, batch_size=50, validation_data=(test_X, test_y), verbose=2, shuffle=False, callbacks=early_stopping)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/1000
# 27/27 - 15s - loss: 0.1684 - val_loss: 0.1084 - 15s/epoch - 558ms/step
# Epoch 2/1000
# 27/27 - 1s - loss: 0.1000 - val_loss: 0.1105 - 1s/epoch - 42ms/step
# Epoch 3/1000
# 27/27 - 1s - loss: 0.0978 - val_loss: 0.1119 - 1s/epoch - 41ms/step
# Epoch 4/1000
# 27/27 - 1s - loss: 0.0966 - val_loss: 0.1132 - 1s/epoch - 42ms/step
# Epoch 5/1000
# 27/27 - 1s - loss: 0.0959 - val_loss: 0.1131 - 1s/epoch - 43ms/step
# Epoch 6/1000
# 27/27 - 1s - loss: 0.0945 - val_loss: 0.1175 - 1s/epoch - 43ms/step
# Epoch 7/1000
# 27/27 - 1s - loss: 0.0948 - val_loss: 0.1154 - 1s/epoch - 42ms/step
# Epoch 8/1000
# 27/27 - 1s - loss: 0.0904 - val_loss: 0.1233 - 1s/epoch - 43ms/step
# Epoch 9/1000
# 27/27 - 1s - loss: 0.0914 - val_loss: 0.1132 - 1s/epoch - 43ms/step
# Epoch 10/1000
# 27/27 - 1s - loss: 0.0862 - val_loss: 0.1268 - 1s/epoch - 42ms/step
# Epoch 11/1000
# 27/27 - 1s - loss: 0.0890 - val_loss: 0.1223 - 1s/epoch - 42ms/step
# Epoch 12/1000
# 27/27 - 1s - loss: 0.0846 - val_loss: 0.1237 - 1s/epoch - 42ms/step
# Epoch 13/1000
# 27/27 - 1s - loss: 0.0839 - val_loss: 0.1178 - 1s/epoch - 43ms/step
# Epoch 14/1000
# 27/27 - 1s - loss: 0.0809 - val_loss: 0.1181 - 1s/epoch - 42ms/step
# Epoch 15/1000
# 27/27 - 1s - loss: 0.0779 - val_loss: 0.1205 - 1s/epoch - 41ms/step
# Epoch 16/1000
# 27/27 - 1s - loss: 0.0735 - val_loss: 0.1200 - 1s/epoch - 42ms/step
# Epoch 17/1000
# 27/27 - 1s - loss: 0.0723 - val_loss: 0.1218 - 1s/epoch - 43ms/step
# Epoch 18/1000
# 27/27 - 1s - loss: 0.0720 - val_loss: 0.1305 - 1s/epoch - 42ms/step
# Epoch 19/1000
# 27/27 - 1s - loss: 0.0706 - val_loss: 0.1411 - 1s/epoch - 42ms/step
# Epoch 20/1000
# 27/27 - 1s - loss: 0.0699 - val_loss: 0.1343 - 1s/epoch - 41ms/step
# Epoch 21/1000
# 27/27 - 1s - loss: 0.0667 - val_loss: 0.1343 - 1s/epoch - 42ms/step
# Epoch 22/1000
# 27/27 - 1s - loss: 0.0635 - val_loss: 0.1398 - 1s/epoch - 42ms/step
# Epoch 23/1000
# 27/27 - 1s - loss: 0.0577 - val_loss: 0.1313 - 1s/epoch - 42ms/step
# Epoch 24/1000
# 27/27 - 1s - loss: 0.0558 - val_loss: 0.1256 - 1s/epoch - 42ms/step
# Epoch 25/1000
# 27/27 - 1s - loss: 0.0612 - val_loss: 0.1446 - 1s/epoch - 42ms/step
# Epoch 26/1000
# 27/27 - 1s - loss: 0.0604 - val_loss: 0.1318 - 1s/epoch - 42ms/step
# Epoch 27/1000
# 27/27 - 1s - loss: 0.0520 - val_loss: 0.1357 - 1s/epoch - 41ms/step
# Epoch 28/1000
# 27/27 - 1s - loss: 0.0544 - val_loss: 0.1406 - 1s/epoch - 41ms/step
# Epoch 29/1000
# 27/27 - 1s - loss: 0.0506 - val_loss: 0.1430 - 1s/epoch - 42ms/step
# Epoch 30/1000
# 27/27 - 1s - loss: 0.0462 - val_loss: 0.1420 - 1s/epoch - 54ms/step
# Epoch 31/1000
# 27/27 - 1s - loss: 0.0445 - val_loss: 0.1496 - 1s/epoch - 47ms/step
# Epoch 32/1000
# 27/27 - 1s - loss: 0.0426 - val_loss: 0.1370 - 1s/epoch - 41ms/step
# Epoch 33/1000
# 27/27 - 1s - loss: 0.0416 - val_loss: 0.1527 - 1s/epoch - 41ms/step
# Epoch 34/1000
# 27/27 - 1s - loss: 0.0443 - val_loss: 0.1421 - 1s/epoch - 41ms/step
# Epoch 35/1000
# 27/27 - 1s - loss: 0.0395 - val_loss: 0.1449 - 1s/epoch - 42ms/step
# Epoch 36/1000
# 27/27 - 1s - loss: 0.0404 - val_loss: 0.1414 - 1s/epoch - 43ms/step
# Epoch 37/1000
# 27/27 - 1s - loss: 0.0436 - val_loss: 0.1501 - 1s/epoch - 43ms/step
# Epoch 38/1000
# 27/27 - 1s - loss: 0.0394 - val_loss: 0.1391 - 1s/epoch - 42ms/step
# Epoch 39/1000
# 27/27 - 1s - loss: 0.0323 - val_loss: 0.1364 - 1s/epoch - 43ms/step
# Epoch 40/1000
# 27/27 - 1s - loss: 0.0318 - val_loss: 0.1467 - 1s/epoch - 43ms/step
# Epoch 41/1000
# 27/27 - 1s - loss: 0.0319 - val_loss: 0.1507 - 1s/epoch - 42ms/step
# Epoch 42/1000
# 27/27 - 1s - loss: 0.0375 - val_loss: 0.1529 - 1s/epoch - 42ms/step
# Epoch 43/1000
# 27/27 - 1s - loss: 0.0323 - val_loss: 0.1662 - 1s/epoch - 42ms/step
# Epoch 44/1000
# 27/27 - 1s - loss: 0.0349 - val_loss: 0.1610 - 1s/epoch - 42ms/step
# Epoch 45/1000
# 27/27 - 1s - loss: 0.0340 - val_loss: 0.1580 - 1s/epoch - 43ms/step
# Epoch 46/1000
# 27/27 - 1s - loss: 0.0383 - val_loss: 0.1399 - 1s/epoch - 42ms/step
# Epoch 47/1000
# 27/27 - 1s - loss: 0.0343 - val_loss: 0.1556 - 1s/epoch - 43ms/step
# Epoch 48/1000
# 27/27 - 1s - loss: 0.0294 - val_loss: 0.1770 - 1s/epoch - 42ms/step
# Epoch 49/1000
# 27/27 - 1s - loss: 0.0276 - val_loss: 0.1643 - 1s/epoch - 42ms/step
# Epoch 50/1000
# 27/27 - 1s - loss: 0.0293 - val_loss: 0.1502 - 1s/epoch - 41ms/step
# Epoch 51/1000
# 27/27 - 1s - loss: 0.0243 - val_loss: 0.1523 - 1s/epoch - 41ms/step
# Epoch 52/1000
# 27/27 - 1s - loss: 0.0219 - val_loss: 0.1448 - 1s/epoch - 43ms/step
# Epoch 53/1000
# 27/27 - 1s - loss: 0.0187 - val_loss: 0.1502 - 1s/epoch - 41ms/step
# Epoch 54/1000
# 27/27 - 1s - loss: 0.0171 - val_loss: 0.1552 - 1s/epoch - 42ms/step
# Epoch 55/1000
# 27/27 - 1s - loss: 0.0163 - val_loss: 0.1459 - 1s/epoch - 41ms/step
# Epoch 56/1000
# 27/27 - 1s - loss: 0.0153 - val_loss: 0.1559 - 1s/epoch - 41ms/step
# Epoch 57/1000
# 27/27 - 1s - loss: 0.0135 - val_loss: 0.1479 - 1s/epoch - 41ms/step
# Epoch 58/1000
# 27/27 - 1s - loss: 0.0108 - val_loss: 0.1500 - 1s/epoch - 42ms/step
# Epoch 59/1000
# 27/27 - 1s - loss: 0.0124 - val_loss: 0.1489 - 1s/epoch - 41ms/step
# Epoch 60/1000
# 27/27 - 1s - loss: 0.0116 - val_loss: 0.1535 - 1s/epoch - 42ms/step
# Epoch 61/1000
# 27/27 - 1s - loss: 0.0122 - val_loss: 0.1450 - 1s/epoch - 42ms/step
# Epoch 62/1000
# 27/27 - 1s - loss: 0.0137 - val_loss: 0.1512 - 1s/epoch - 42ms/step
# Epoch 63/1000
# 27/27 - 1s - loss: 0.0110 - val_loss: 0.1584 - 1s/epoch - 41ms/step
# Epoch 64/1000
# 27/27 - 1s - loss: 0.0090 - val_loss: 0.1548 - 1s/epoch - 42ms/step
# Epoch 65/1000
# 27/27 - 1s - loss: 0.0077 - val_loss: 0.1457 - 1s/epoch - 41ms/step
# Epoch 66/1000
# 27/27 - 1s - loss: 0.0081 - val_loss: 0.1447 - 1s/epoch - 41ms/step
# Epoch 67/1000
# 27/27 - 1s - loss: 0.0078 - val_loss: 0.1420 - 1s/epoch - 42ms/step
# Epoch 68/1000
# 27/27 - 1s - loss: 0.0060 - val_loss: 0.1518 - 1s/epoch - 42ms/step
# Epoch 69/1000
# 27/27 - 1s - loss: 0.0058 - val_loss: 0.1554 - 1s/epoch - 41ms/step
# Epoch 70/1000
# 27/27 - 1s - loss: 0.0055 - val_loss: 0.1543 - 1s/epoch - 42ms/step
# Epoch 71/1000
# 27/27 - 1s - loss: 0.0076 - val_loss: 0.1593 - 1s/epoch - 42ms/step

# %%
class LNSimpleRNNCell(keras.layers.Layer):
       def __init__(self, units, activation="tanh", **kwargs):         
         super().__init__(**kwargs)         
         self.state_size = units         
         self.output_size = units         
         self.simple_rnn_cell = tfa.rnn.LayerNormLSTMCell(units)                     
       def call(self, inputs, states):         
         outputs, new_states = self.simple_rnn_cell(inputs, states)                
         return outputs

# %% [markdown]
# ## Predictions

# %%
# make a prediction using 2020 (not used for training or validation, and has different dynamics due to covid)
# adding back the data from 2020
Moggio = table.dropna(how="any")
Moggio = Moggio.reset_index()
#scaling and creating the new testing data
values = Moggio.iloc[:,3:].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
n_days = 5
reframed = series_to_supervised(scaled, n_days, 1) # info of the past 5 days to determine next (1) day
# drop columns we don't want to predict (we therefore keep Ammonia)
reframed.drop(reframed.columns[[36,37,38,39,40,41]], axis=1, inplace=True)
# split into train and test sets
values = reframed.values
n_features = 7 # number of variables, including the one to be predicted
n_train_days = 365 # we train using only the first year
train = values[:n_train_days, :]
test = values[n_train_days:, :] # we test using all successive years 
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (365, 35) 365 (365,)
# (365, 5, 7) (365,) (1662, 5, 7) (1662,)

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], n_days*n_features))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -6:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -6:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 6.436

# %% [markdown]
# #### Prediciton plots

# %%
pyplot.plot(inv_yhat, label = 'Prediction')
pyplot.plot(inv_y, label = 'Real')
pyplot.legend()
pyplot.show()
