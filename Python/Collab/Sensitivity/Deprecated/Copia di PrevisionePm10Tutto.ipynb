# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow.keras as keras

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
table = read_csv('/content/drive/MyDrive/Quadranti.csv')
Moggio = table.dropna(how="any")
Moggio
# Out:
#       Unnamed: 0                  Date  ...  Rainfall  Quadrante
# 0              0  2014-01-01T00:00:00Z  ...       0.0          2
# 1              1  2014-01-02T00:00:00Z  ...       7.8          2
# 2              2  2014-01-03T00:00:00Z  ...       0.0          2
# 3              3  2014-01-04T00:00:00Z  ...      35.8          2
# 4              4  2014-01-05T00:00:00Z  ...      25.0          2
# ...          ...                   ...  ...       ...        ...
# 2523        2523  2020-12-27T00:00:00Z  ...       0.0          1
# 2524        2524  2020-12-28T00:00:00Z  ...      27.6          2
# 2525        2525  2020-12-29T00:00:00Z  ...       2.2          2
# 2526        2526  2020-12-30T00:00:00Z  ...       0.0          3
# 2527        2527  2020-12-31T00:00:00Z  ...       0.0          2
#
# [2032 rows x 9 columns]

# %%
#Moggio = table.loc[table.loc[:,"NameStation"]=="Moggio",:]
#Moggio = Moggio.loc[:,["Date","Ammonia","PM10","PM25","Wind_speed","Wind_direction","Temperature","Rainfall"]]

Moggio = Moggio.reset_index()
Moggio = Moggio.iloc[:1667,:] # we train not using 2020, for now
Moggio = Moggio[['index','Unnamed: 0','Date', 'PM10','Ammonia' ,'PM25', 'Wind_speed', 'Temperature','Rainfall', 'Quadrante']]

Moggio #Girare i posti delle variabili
# Out:
#       index  Unnamed: 0                  Date  ...  Temperature  Rainfall  Quadrante
# 0         0           0  2014-01-01T00:00:00Z  ...    -0.334965       0.0          2
# 1         1           1  2014-01-02T00:00:00Z  ...    -0.486111       7.8          2
# 2         2           2  2014-01-03T00:00:00Z  ...     2.220588       0.0          2
# 3         3           3  2014-01-04T00:00:00Z  ...     2.137063      35.8          2
# 4         4           4  2014-01-05T00:00:00Z  ...     2.416084      25.0          2
# ...     ...         ...                   ...  ...          ...       ...        ...
# 1662   2112        2112  2019-11-09T00:00:00Z  ...     3.863889       0.0          2
# 1663   2113        2113  2019-11-10T00:00:00Z  ...     3.068056       0.0          2
# 1664   2114        2114  2019-11-11T00:00:00Z  ...     2.556250      21.6          3
# 1665   2115        2115  2019-11-12T00:00:00Z  ...     3.682639      20.2          1
# 1666   2116        2116  2019-11-13T00:00:00Z  ...     2.556944       0.0          4
#
# [1667 rows x 10 columns]

# %% [markdown]
# ##Convert series to supervised learning

# %% [markdown]
# ###Conversion Function

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	"""
	Frame a time series as a supervised learning dataset.
	Arguments:
		data: Sequence of observations as a list or NumPy array.
		n_in: Number of lag observations as input (X).
		n_out: Number of observations as output (y).
		dropnan: Boolean whether or not to drop rows with NaN values.
	Returns:
		Pandas DataFrame of series framed for supervised learning.
	"""
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %% [markdown]
# ### Conversion of Moggio

# %%
values = Moggio.iloc[:,3:].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
n_days = 5
reframed = series_to_supervised(scaled, n_days, 1) # info of the past 5 days to determine next (1) day
# drop columns we don't want to predict (we therefore keep Ammonia)
reframed.drop(reframed.columns[[36,37,38,39,40,41]], axis=1, inplace=True)

reframed
# Out:
#       var1(t-5)  var2(t-5)  var3(t-5)  ...  var6(t-1)  var7(t-1)   var1(t)
# 5      0.066667   0.000000   0.088608  ...   0.112816   0.333333  0.022222
# 6      0.066667   0.000000   0.063291  ...   0.000000   0.000000  0.077778
# 7      0.122222   0.000000   0.050633  ...   0.000000   0.000000  0.044444
# 8      0.066667   0.000000   0.088608  ...   0.000000   0.333333  0.044444
# 9      0.033333   0.000000   0.101266  ...   0.000000   0.000000  0.133333
# ...         ...        ...        ...  ...        ...        ...       ...
# 1662   0.044444   0.024752   0.037975  ...   0.122744   0.333333  0.055556
# 1663   0.000000   0.059406   0.000000  ...   0.000000   0.333333  0.055556
# 1664   0.033333   0.009901   0.025316  ...   0.000000   0.333333  0.066667
# 1665   0.044444   0.000000   0.012658  ...   0.097473   0.666667  0.000000
# 1666   0.011111   0.000000   0.025316  ...   0.091155   0.000000  0.022222
#
# [1662 rows x 36 columns]

# %%
# split into train and test sets
values = reframed.values
n_features = 7 # number of variables, including the one to be predicted
n_train_days = 1667-365 # we train using only the first year
train = values[:n_train_days, :]
test = values[n_train_days:, :] # we test using all successive years 
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1302, 35) 1302 (1302,)
# (1302, 5, 7) (1302,) (360, 5, 7) (360,)

# %% [markdown]
# # Modeling and training

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
from tensorflow.keras.layers import RNN
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.7/dist-packages (0.16.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)

# %%
# design network
model = Sequential()
model.add(RNN(tfa.rnn.LayerNormLSTMCell(50), return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(RNN(tfa.rnn.LayerNormLSTMCell(50), return_sequences=True))
model.add(RNN(tfa.rnn.LayerNormLSTMCell(50), return_sequences=False))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')
# fit network
early_stopping = EarlyStopping(patience=50, restore_best_weights = True)
history = model.fit(train_X, train_y, epochs=1000, batch_size=25, validation_data=(test_X, test_y), verbose=2, shuffle=False, callbacks=early_stopping)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/1000
# 53/53 - 26s - loss: 0.0377 - val_loss: 0.0232 - 26s/epoch - 492ms/step
# Epoch 2/1000
# 53/53 - 2s - loss: 0.0213 - val_loss: 0.0143 - 2s/epoch - 43ms/step
# Epoch 3/1000
# 53/53 - 2s - loss: 0.0164 - val_loss: 0.0126 - 2s/epoch - 32ms/step
# Epoch 4/1000
# 53/53 - 2s - loss: 0.0157 - val_loss: 0.0115 - 2s/epoch - 33ms/step
# Epoch 5/1000
# 53/53 - 2s - loss: 0.0141 - val_loss: 0.0110 - 2s/epoch - 33ms/step
# Epoch 6/1000
# 53/53 - 2s - loss: 0.0137 - val_loss: 0.0137 - 2s/epoch - 32ms/step
# Epoch 7/1000
# 53/53 - 2s - loss: 0.0148 - val_loss: 0.0144 - 2s/epoch - 32ms/step
# Epoch 8/1000
# 53/53 - 2s - loss: 0.0130 - val_loss: 0.0100 - 2s/epoch - 33ms/step
# Epoch 9/1000
# 53/53 - 2s - loss: 0.0113 - val_loss: 0.0121 - 2s/epoch - 33ms/step
# Epoch 10/1000
# 53/53 - 2s - loss: 0.0115 - val_loss: 0.0129 - 2s/epoch - 33ms/step
# Epoch 11/1000
# 53/53 - 2s - loss: 0.0115 - val_loss: 0.0119 - 2s/epoch - 33ms/step
# Epoch 12/1000
# 53/53 - 2s - loss: 0.0108 - val_loss: 0.0126 - 2s/epoch - 32ms/step
# Epoch 13/1000
# 53/53 - 2s - loss: 0.0106 - val_loss: 0.0111 - 2s/epoch - 32ms/step
# Epoch 14/1000
# 53/53 - 2s - loss: 0.0100 - val_loss: 0.0120 - 2s/epoch - 33ms/step
# Epoch 15/1000
# 53/53 - 2s - loss: 0.0098 - val_loss: 0.0110 - 2s/epoch - 32ms/step
# Epoch 16/1000
# 53/53 - 2s - loss: 0.0093 - val_loss: 0.0125 - 2s/epoch - 32ms/step
# Epoch 17/1000
# 53/53 - 2s - loss: 0.0094 - val_loss: 0.0110 - 2s/epoch - 32ms/step
# Epoch 18/1000
# 53/53 - 2s - loss: 0.0091 - val_loss: 0.0150 - 2s/epoch - 33ms/step
# Epoch 19/1000
# 53/53 - 2s - loss: 0.0103 - val_loss: 0.0126 - 2s/epoch - 32ms/step
# Epoch 20/1000
# 53/53 - 2s - loss: 0.0090 - val_loss: 0.0109 - 2s/epoch - 32ms/step
# Epoch 21/1000
# 53/53 - 2s - loss: 0.0081 - val_loss: 0.0112 - 2s/epoch - 32ms/step
# Epoch 22/1000
# 53/53 - 2s - loss: 0.0078 - val_loss: 0.0115 - 2s/epoch - 32ms/step
# Epoch 23/1000
# 53/53 - 2s - loss: 0.0080 - val_loss: 0.0114 - 2s/epoch - 32ms/step
# Epoch 24/1000
# 53/53 - 2s - loss: 0.0084 - val_loss: 0.0148 - 2s/epoch - 32ms/step
# Epoch 25/1000
# 53/53 - 2s - loss: 0.0092 - val_loss: 0.0124 - 2s/epoch - 32ms/step
# Epoch 26/1000
# 53/53 - 2s - loss: 0.0089 - val_loss: 0.0134 - 2s/epoch - 32ms/step
# Epoch 27/1000
# 53/53 - 2s - loss: 0.0077 - val_loss: 0.0131 - 2s/epoch - 33ms/step
# Epoch 28/1000
# 53/53 - 2s - loss: 0.0068 - val_loss: 0.0122 - 2s/epoch - 33ms/step
# Epoch 29/1000
# 53/53 - 2s - loss: 0.0060 - val_loss: 0.0149 - 2s/epoch - 32ms/step
# Epoch 30/1000
# 53/53 - 2s - loss: 0.0059 - val_loss: 0.0127 - 2s/epoch - 32ms/step
# Epoch 31/1000
# 53/53 - 2s - loss: 0.0055 - val_loss: 0.0136 - 2s/epoch - 32ms/step
# Epoch 32/1000
# 53/53 - 2s - loss: 0.0062 - val_loss: 0.0170 - 2s/epoch - 32ms/step
# Epoch 33/1000
# 53/53 - 2s - loss: 0.0071 - val_loss: 0.0142 - 2s/epoch - 32ms/step
# Epoch 34/1000
# 53/53 - 2s - loss: 0.0058 - val_loss: 0.0149 - 2s/epoch - 33ms/step
# Epoch 35/1000
# 53/53 - 2s - loss: 0.0049 - val_loss: 0.0128 - 2s/epoch - 33ms/step
# Epoch 36/1000
# 53/53 - 2s - loss: 0.0045 - val_loss: 0.0123 - 2s/epoch - 32ms/step
# Epoch 37/1000
# 53/53 - 2s - loss: 0.0045 - val_loss: 0.0128 - 2s/epoch - 32ms/step
# Epoch 38/1000
# 53/53 - 2s - loss: 0.0040 - val_loss: 0.0136 - 2s/epoch - 32ms/step
# Epoch 39/1000
# 53/53 - 2s - loss: 0.0046 - val_loss: 0.0159 - 2s/epoch - 32ms/step
# Epoch 40/1000
# 53/53 - 2s - loss: 0.0053 - val_loss: 0.0163 - 2s/epoch - 32ms/step
# Epoch 41/1000
# 53/53 - 2s - loss: 0.0057 - val_loss: 0.0132 - 2s/epoch - 32ms/step
# Epoch 42/1000
# 53/53 - 2s - loss: 0.0052 - val_loss: 0.0145 - 2s/epoch - 32ms/step
# Epoch 43/1000
# 53/53 - 2s - loss: 0.0042 - val_loss: 0.0128 - 2s/epoch - 31ms/step
# Epoch 44/1000
# 53/53 - 2s - loss: 0.0040 - val_loss: 0.0142 - 2s/epoch - 32ms/step
# Epoch 45/1000
# 53/53 - 2s - loss: 0.0050 - val_loss: 0.0128 - 2s/epoch - 32ms/step
# Epoch 46/1000
# 53/53 - 2s - loss: 0.0035 - val_loss: 0.0128 - 2s/epoch - 35ms/step
# Epoch 47/1000
# 53/53 - 2s - loss: 0.0027 - val_loss: 0.0137 - 2s/epoch - 32ms/step
# Epoch 48/1000
# 53/53 - 2s - loss: 0.0026 - val_loss: 0.0142 - 2s/epoch - 32ms/step
# Epoch 49/1000
# 53/53 - 2s - loss: 0.0022 - val_loss: 0.0138 - 2s/epoch - 32ms/step
# Epoch 50/1000
# 53/53 - 2s - loss: 0.0022 - val_loss: 0.0148 - 2s/epoch - 32ms/step
# Epoch 51/1000
# 53/53 - 2s - loss: 0.0021 - val_loss: 0.0144 - 2s/epoch - 32ms/step
# Epoch 52/1000
# 53/53 - 2s - loss: 0.0025 - val_loss: 0.0148 - 2s/epoch - 32ms/step
# Epoch 53/1000
# 53/53 - 2s - loss: 0.0026 - val_loss: 0.0166 - 2s/epoch - 32ms/step
# Epoch 54/1000
# 53/53 - 2s - loss: 0.0021 - val_loss: 0.0160 - 2s/epoch - 32ms/step
# Epoch 55/1000
# 53/53 - 2s - loss: 0.0026 - val_loss: 0.0158 - 2s/epoch - 32ms/step
# Epoch 56/1000
# 53/53 - 2s - loss: 0.0023 - val_loss: 0.0133 - 2s/epoch - 32ms/step
# Epoch 57/1000
# 53/53 - 2s - loss: 0.0028 - val_loss: 0.0125 - 2s/epoch - 32ms/step
# Epoch 58/1000
# 53/53 - 2s - loss: 0.0027 - val_loss: 0.0120 - 2s/epoch - 35ms/step

# %%
class LNSimpleRNNCell(keras.layers.Layer):
       def __init__(self, units, activation="tanh", **kwargs):         
         super().__init__(**kwargs)         
         self.state_size = units         
         self.output_size = units         
         self.simple_rnn_cell = tfa.rnn.LayerNormLSTMCell(units)                     
       def call(self, inputs, states):         
         outputs, new_states = self.simple_rnn_cell(inputs, states)                
         return outputs

# %% [markdown]
# ## Predictions

# %%
# make a prediction using 2020 (not used for training or validation, and has different dynamics due to covid)
# adding back the data from 2020
Moggio = table.dropna(how="any")
Moggio = Moggio.reset_index()
#scaling and creating the new testing data
values = Moggio.iloc[:,3:].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
n_days = 5
reframed = series_to_supervised(scaled, n_days, 1) # info of the past 5 days to determine next (1) day
# drop columns we don't want to predict (we therefore keep Ammonia)
reframed.drop(reframed.columns[[36,37,38,39,40,41]], axis=1, inplace=True)
# split into train and test sets
values = reframed.values
n_features = 7 # number of variables, including the one to be predicted
n_train_days = 365 # we train using only the first year
train = values[:n_train_days, :]
test = values[n_train_days:, :] # we test using all successive years 
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (365, 35) 365 (365,)
# (365, 5, 7) (365,) (1662, 5, 7) (1662,)

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], n_days*n_features))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -6:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -6:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 2.409

# %% [markdown]
# #### Prediciton plots

# %%
pyplot.plot(inv_yhat, label = 'Prediction')
pyplot.plot(inv_y, label = 'Real')
pyplot.legend()
pyplot.show()
