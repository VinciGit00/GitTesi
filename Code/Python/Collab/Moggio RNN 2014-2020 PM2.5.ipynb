# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import seaborn as sns
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
table = read_csv('/content/drive/MyDrive/Thesis/csvs/NNdata14_20.csv')
table.head()
# Out:
#                    Date  IDStation  ... Wind_direction_max  Rainfall
# 0  2014-01-01T00:00:00Z        681  ...              143.0       0.0
# 1  2014-01-02T00:00:00Z        681  ...              153.0       7.8
# 2  2014-01-03T00:00:00Z        681  ...              152.0       0.0
# 3  2014-01-04T00:00:00Z        681  ...              164.0      35.8
# 4  2014-01-05T00:00:00Z        681  ...              136.0      25.0
#
# [5 rows x 28 columns]

# %%
#Moggio = table.loc[table.loc[:,"NameStation"]=="Moggio",:]
Moggio = table.loc[:,["Date","PM25","Ammonia","Wind_speed","Wind_direction","Temperature","Rainfall"]]
Moggio = Moggio.dropna(how="any")
Moggio = Moggio.reset_index()
Moggio = Moggio.iloc[:-365,:] # we train not using 2020, for now
Moggio.head()
# Out:
#    index                  Date  PM25  ...  Wind_direction  Temperature  Rainfall
# 0      0  2014-01-01T00:00:00Z   7.0  ...            99.0    -0.334965       0.0
# 1      1  2014-01-02T00:00:00Z   5.0  ...           105.0    -0.486111       7.8
# 2      2  2014-01-03T00:00:00Z   4.0  ...           120.0     2.220588       0.0
# 3      3  2014-01-04T00:00:00Z   7.0  ...           175.0     2.137063      35.8
# 4      4  2014-01-05T00:00:00Z   8.0  ...            94.0     2.416084      25.0
#
# [5 rows x 8 columns]

# %%
# sns.lineplot(x='Date', y='PM25', data=Moggio)

# %% [markdown]
# ##Convert series to supervised learning
# ### Activation function = tanh and logistic (s curve)

# %% [markdown]
# ###Conversion Function

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	"""
	Frame a time series as a supervised learning dataset.
	Arguments:
		data: Sequence of observations as a list or NumPy array.
		n_in: Number of lag observations as input (X).
		n_out: Number of observations as output (y).
		dropnan: Boolean whether or not to drop rows with NaN values.
	Returns:
		Pandas DataFrame of series framed for supervised learning.
	"""
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %% [markdown]
# ### Conversion of Moggio

# %%
values = Moggio.iloc[:,2:].values
# ensure all data is float
values = values.astype('float32') #cast in float 32 bit per evitare problemi
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
n_days = 5 #Memoria della NN
reframed = series_to_supervised(scaled, n_days, 1) # info of the past 5 days to determine next (1) day
# drop columns we don't want to predict (we therefore keep Ammonia)
reframed.drop(reframed.columns[[31,32,33,34,35]], axis=1, inplace=True)

reframed.head()
# Out:
#    var1(t-5)  var2(t-5)  var3(t-5)  ...  var5(t-1)  var6(t-1)   var1(t)
# 5   0.088608        0.0   0.169316  ...   0.358295   0.112816  0.025316
# 6   0.063291        0.0   0.135178  ...   0.406390   0.000000  0.088608
# 7   0.050633        0.0   0.077417  ...   0.397825   0.000000  0.050633
# 8   0.088608        0.0   0.395778  ...   0.408315   0.000000  0.088608
# 9   0.101266        0.0   0.256247  ...   0.392536   0.000000  0.063291
#
# [5 rows x 31 columns]

# %%
# split into train and test sets
values = reframed.values
n_features = 6 # number of variables, including the one to be predicted
n_train_days = 1312 # we train using only the first year
train = values[:n_train_days, :]
test = values[n_train_days:, :] # we test using all successive years 
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
# reshape from 2D to 3D
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1312, 30) 1312 (1312,)
# (1312, 5, 6) (1312,) (377, 5, 6) (377,)

# %% [markdown]
# # Modeling and training

# %%
# design the neural network
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
early_stopping = EarlyStopping(patience=50, restore_best_weights = True)
history = model.fit(train_X, train_y, epochs=500, batch_size=100, validation_data=(test_X, test_y), verbose=2, shuffle=False, callbacks=early_stopping)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/500
# 14/14 - 6s - loss: 0.0981 - val_loss: 0.0847 - 6s/epoch - 458ms/step
# Epoch 2/500
# 14/14 - 0s - loss: 0.0856 - val_loss: 0.0783 - 229ms/epoch - 16ms/step
# Epoch 3/500
# 14/14 - 0s - loss: 0.0811 - val_loss: 0.0786 - 228ms/epoch - 16ms/step
# Epoch 4/500
# 14/14 - 0s - loss: 0.0814 - val_loss: 0.0770 - 229ms/epoch - 16ms/step
# Epoch 5/500
# 14/14 - 0s - loss: 0.0803 - val_loss: 0.0770 - 246ms/epoch - 18ms/step
# Epoch 6/500
# 14/14 - 0s - loss: 0.0801 - val_loss: 0.0763 - 226ms/epoch - 16ms/step
# Epoch 7/500
# 14/14 - 0s - loss: 0.0796 - val_loss: 0.0761 - 237ms/epoch - 17ms/step
# Epoch 8/500
# 14/14 - 0s - loss: 0.0793 - val_loss: 0.0758 - 242ms/epoch - 17ms/step
# Epoch 9/500
# 14/14 - 0s - loss: 0.0790 - val_loss: 0.0756 - 242ms/epoch - 17ms/step
# Epoch 10/500
# 14/14 - 0s - loss: 0.0787 - val_loss: 0.0758 - 227ms/epoch - 16ms/step
# Epoch 11/500
# 14/14 - 0s - loss: 0.0784 - val_loss: 0.0755 - 231ms/epoch - 17ms/step
# Epoch 12/500
# 14/14 - 0s - loss: 0.0780 - val_loss: 0.0750 - 230ms/epoch - 16ms/step
# Epoch 13/500
# 14/14 - 0s - loss: 0.0777 - val_loss: 0.0751 - 253ms/epoch - 18ms/step
# Epoch 14/500
# 14/14 - 0s - loss: 0.0775 - val_loss: 0.0752 - 239ms/epoch - 17ms/step
# Epoch 15/500
# 14/14 - 0s - loss: 0.0772 - val_loss: 0.0747 - 240ms/epoch - 17ms/step
# Epoch 16/500
# 14/14 - 0s - loss: 0.0768 - val_loss: 0.0744 - 240ms/epoch - 17ms/step
# Epoch 17/500
# 14/14 - 0s - loss: 0.0763 - val_loss: 0.0740 - 238ms/epoch - 17ms/step
# Epoch 18/500
# 14/14 - 0s - loss: 0.0758 - val_loss: 0.0736 - 230ms/epoch - 16ms/step
# Epoch 19/500
# 14/14 - 0s - loss: 0.0752 - val_loss: 0.0728 - 242ms/epoch - 17ms/step
# Epoch 20/500
# 14/14 - 0s - loss: 0.0742 - val_loss: 0.0718 - 231ms/epoch - 17ms/step
# Epoch 21/500
# 14/14 - 0s - loss: 0.0731 - val_loss: 0.0701 - 232ms/epoch - 17ms/step
# Epoch 22/500
# 14/14 - 0s - loss: 0.0720 - val_loss: 0.0695 - 231ms/epoch - 16ms/step
# Epoch 23/500
# 14/14 - 0s - loss: 0.0712 - val_loss: 0.0686 - 237ms/epoch - 17ms/step
# Epoch 24/500
# 14/14 - 0s - loss: 0.0698 - val_loss: 0.0665 - 235ms/epoch - 17ms/step
# Epoch 25/500
# 14/14 - 0s - loss: 0.0684 - val_loss: 0.0646 - 236ms/epoch - 17ms/step
# Epoch 26/500
# 14/14 - 0s - loss: 0.0676 - val_loss: 0.0653 - 257ms/epoch - 18ms/step
# Epoch 27/500
# 14/14 - 0s - loss: 0.0672 - val_loss: 0.0625 - 235ms/epoch - 17ms/step
# Epoch 28/500
# 14/14 - 0s - loss: 0.0669 - val_loss: 0.0635 - 238ms/epoch - 17ms/step
# Epoch 29/500
# 14/14 - 0s - loss: 0.0666 - val_loss: 0.0614 - 222ms/epoch - 16ms/step
# Epoch 30/500
# 14/14 - 0s - loss: 0.0668 - val_loss: 0.0616 - 230ms/epoch - 16ms/step
# Epoch 31/500
# 14/14 - 0s - loss: 0.0661 - val_loss: 0.0612 - 227ms/epoch - 16ms/step
# Epoch 32/500
# 14/14 - 0s - loss: 0.0659 - val_loss: 0.0608 - 240ms/epoch - 17ms/step
# Epoch 33/500
# 14/14 - 0s - loss: 0.0659 - val_loss: 0.0607 - 229ms/epoch - 16ms/step
# Epoch 34/500
# 14/14 - 0s - loss: 0.0662 - val_loss: 0.0609 - 245ms/epoch - 18ms/step
# Epoch 35/500
# 14/14 - 0s - loss: 0.0662 - val_loss: 0.0611 - 245ms/epoch - 18ms/step
# Epoch 36/500
# 14/14 - 0s - loss: 0.0664 - val_loss: 0.0611 - 234ms/epoch - 17ms/step
# Epoch 37/500
# 14/14 - 0s - loss: 0.0664 - val_loss: 0.0615 - 223ms/epoch - 16ms/step
# Epoch 38/500
# 14/14 - 0s - loss: 0.0672 - val_loss: 0.0621 - 241ms/epoch - 17ms/step
# Epoch 39/500
# 14/14 - 0s - loss: 0.0678 - val_loss: 0.0618 - 231ms/epoch - 17ms/step
# Epoch 40/500
# 14/14 - 0s - loss: 0.0681 - val_loss: 0.0629 - 227ms/epoch - 16ms/step
# Epoch 41/500
# 14/14 - 0s - loss: 0.0680 - val_loss: 0.0667 - 244ms/epoch - 17ms/step
# Epoch 42/500
# 14/14 - 0s - loss: 0.0678 - val_loss: 0.0678 - 229ms/epoch - 16ms/step
# Epoch 43/500
# 14/14 - 0s - loss: 0.0679 - val_loss: 0.0636 - 234ms/epoch - 17ms/step
# Epoch 44/500
# 14/14 - 0s - loss: 0.0662 - val_loss: 0.0611 - 236ms/epoch - 17ms/step
# Epoch 45/500
# 14/14 - 0s - loss: 0.0654 - val_loss: 0.0602 - 233ms/epoch - 17ms/step
# Epoch 46/500
# 14/14 - 0s - loss: 0.0654 - val_loss: 0.0604 - 226ms/epoch - 16ms/step
# Epoch 47/500
# 14/14 - 0s - loss: 0.0661 - val_loss: 0.0619 - 239ms/epoch - 17ms/step
# Epoch 48/500
# 14/14 - 0s - loss: 0.0663 - val_loss: 0.0643 - 241ms/epoch - 17ms/step
# Epoch 49/500
# 14/14 - 0s - loss: 0.0659 - val_loss: 0.0631 - 226ms/epoch - 16ms/step
# Epoch 50/500
# 14/14 - 0s - loss: 0.0656 - val_loss: 0.0613 - 228ms/epoch - 16ms/step
# Epoch 51/500
# 14/14 - 0s - loss: 0.0652 - val_loss: 0.0602 - 233ms/epoch - 17ms/step
# Epoch 52/500
# 14/14 - 0s - loss: 0.0649 - val_loss: 0.0600 - 229ms/epoch - 16ms/step
# Epoch 53/500
# 14/14 - 0s - loss: 0.0653 - val_loss: 0.0606 - 233ms/epoch - 17ms/step
# Epoch 54/500
# 14/14 - 0s - loss: 0.0653 - val_loss: 0.0615 - 240ms/epoch - 17ms/step
# Epoch 55/500
# 14/14 - 0s - loss: 0.0651 - val_loss: 0.0621 - 227ms/epoch - 16ms/step
# Epoch 56/500
# 14/14 - 0s - loss: 0.0649 - val_loss: 0.0618 - 244ms/epoch - 17ms/step
# Epoch 57/500
# 14/14 - 0s - loss: 0.0649 - val_loss: 0.0610 - 226ms/epoch - 16ms/step
# Epoch 58/500
# 14/14 - 0s - loss: 0.0647 - val_loss: 0.0603 - 238ms/epoch - 17ms/step
# Epoch 59/500
# 14/14 - 0s - loss: 0.0644 - val_loss: 0.0601 - 226ms/epoch - 16ms/step
# Epoch 60/500
# 14/14 - 0s - loss: 0.0643 - val_loss: 0.0600 - 233ms/epoch - 17ms/step
# Epoch 61/500
# 14/14 - 0s - loss: 0.0644 - val_loss: 0.0600 - 233ms/epoch - 17ms/step
# Epoch 62/500
# 14/14 - 0s - loss: 0.0647 - val_loss: 0.0602 - 240ms/epoch - 17ms/step
# Epoch 63/500
# 14/14 - 0s - loss: 0.0645 - val_loss: 0.0607 - 229ms/epoch - 16ms/step
# Epoch 64/500
# 14/14 - 0s - loss: 0.0643 - val_loss: 0.0609 - 237ms/epoch - 17ms/step
# Epoch 65/500
# 14/14 - 0s - loss: 0.0641 - val_loss: 0.0610 - 221ms/epoch - 16ms/step
# Epoch 66/500
# 14/14 - 0s - loss: 0.0641 - val_loss: 0.0615 - 229ms/epoch - 16ms/step
# Epoch 67/500
# 14/14 - 0s - loss: 0.0642 - val_loss: 0.0613 - 246ms/epoch - 18ms/step
# Epoch 68/500
# 14/14 - 0s - loss: 0.0641 - val_loss: 0.0609 - 231ms/epoch - 16ms/step
# Epoch 69/500
# 14/14 - 0s - loss: 0.0639 - val_loss: 0.0603 - 243ms/epoch - 17ms/step
# Epoch 70/500
# 14/14 - 0s - loss: 0.0637 - val_loss: 0.0601 - 233ms/epoch - 17ms/step
# Epoch 71/500
# 14/14 - 0s - loss: 0.0637 - val_loss: 0.0601 - 230ms/epoch - 16ms/step
# Epoch 72/500
# 14/14 - 0s - loss: 0.0638 - val_loss: 0.0600 - 224ms/epoch - 16ms/step
# Epoch 73/500
# 14/14 - 0s - loss: 0.0638 - val_loss: 0.0601 - 240ms/epoch - 17ms/step
# Epoch 74/500
# 14/14 - 0s - loss: 0.0641 - val_loss: 0.0603 - 231ms/epoch - 16ms/step
# Epoch 75/500
# 14/14 - 0s - loss: 0.0647 - val_loss: 0.0605 - 228ms/epoch - 16ms/step
# Epoch 76/500
# 14/14 - 0s - loss: 0.0655 - val_loss: 0.0633 - 235ms/epoch - 17ms/step
# Epoch 77/500
# 14/14 - 0s - loss: 0.0649 - val_loss: 0.0656 - 255ms/epoch - 18ms/step
# Epoch 78/500
# 14/14 - 0s - loss: 0.0661 - val_loss: 0.0648 - 244ms/epoch - 17ms/step
# Epoch 79/500
# 14/14 - 0s - loss: 0.0659 - val_loss: 0.0616 - 239ms/epoch - 17ms/step
# Epoch 80/500
# 14/14 - 0s - loss: 0.0647 - val_loss: 0.0600 - 234ms/epoch - 17ms/step
# Epoch 81/500
# 14/14 - 0s - loss: 0.0637 - val_loss: 0.0599 - 247ms/epoch - 18ms/step
# Epoch 82/500
# 14/14 - 0s - loss: 0.0641 - val_loss: 0.0600 - 232ms/epoch - 17ms/step
# Epoch 83/500
# 14/14 - 0s - loss: 0.0640 - val_loss: 0.0607 - 230ms/epoch - 16ms/step
# Epoch 84/500
# 14/14 - 0s - loss: 0.0639 - val_loss: 0.0622 - 226ms/epoch - 16ms/step
# Epoch 85/500
# 14/14 - 0s - loss: 0.0636 - val_loss: 0.0610 - 229ms/epoch - 16ms/step
# Epoch 86/500
# 14/14 - 0s - loss: 0.0635 - val_loss: 0.0610 - 245ms/epoch - 17ms/step
# Epoch 87/500
# 14/14 - 0s - loss: 0.0635 - val_loss: 0.0600 - 231ms/epoch - 16ms/step
# Epoch 88/500
# 14/14 - 0s - loss: 0.0633 - val_loss: 0.0599 - 230ms/epoch - 16ms/step
# Epoch 89/500
# 14/14 - 0s - loss: 0.0632 - val_loss: 0.0598 - 235ms/epoch - 17ms/step
# Epoch 90/500
# 14/14 - 0s - loss: 0.0635 - val_loss: 0.0605 - 231ms/epoch - 17ms/step
# Epoch 91/500
# 14/14 - 0s - loss: 0.0633 - val_loss: 0.0617 - 221ms/epoch - 16ms/step
# Epoch 92/500
# 14/14 - 0s - loss: 0.0634 - val_loss: 0.0613 - 234ms/epoch - 17ms/step
# Epoch 93/500
# 14/14 - 0s - loss: 0.0635 - val_loss: 0.0609 - 224ms/epoch - 16ms/step
# Epoch 94/500
# 14/14 - 0s - loss: 0.0631 - val_loss: 0.0600 - 232ms/epoch - 17ms/step
# Epoch 95/500
# 14/14 - 0s - loss: 0.0629 - val_loss: 0.0600 - 242ms/epoch - 17ms/step
# Epoch 96/500
# 14/14 - 0s - loss: 0.0637 - val_loss: 0.0604 - 234ms/epoch - 17ms/step
# Epoch 97/500
# 14/14 - 0s - loss: 0.0632 - val_loss: 0.0610 - 235ms/epoch - 17ms/step
# Epoch 98/500
# 14/14 - 0s - loss: 0.0627 - val_loss: 0.0615 - 237ms/epoch - 17ms/step
# Epoch 99/500
# 14/14 - 0s - loss: 0.0633 - val_loss: 0.0609 - 238ms/epoch - 17ms/step
# Epoch 100/500
# 14/14 - 0s - loss: 0.0631 - val_loss: 0.0605 - 227ms/epoch - 16ms/step
# Epoch 101/500
# 14/14 - 0s - loss: 0.0627 - val_loss: 0.0600 - 227ms/epoch - 16ms/step
# Epoch 102/500
# 14/14 - 0s - loss: 0.0630 - val_loss: 0.0602 - 232ms/epoch - 17ms/step
# Epoch 103/500
# 14/14 - 0s - loss: 0.0631 - val_loss: 0.0608 - 230ms/epoch - 16ms/step
# Epoch 104/500
# 14/14 - 0s - loss: 0.0623 - val_loss: 0.0611 - 234ms/epoch - 17ms/step
# Epoch 105/500
# 14/14 - 0s - loss: 0.0625 - val_loss: 0.0610 - 240ms/epoch - 17ms/step
# Epoch 106/500
# 14/14 - 0s - loss: 0.0628 - val_loss: 0.0606 - 244ms/epoch - 17ms/step
# Epoch 107/500
# 14/14 - 0s - loss: 0.0624 - val_loss: 0.0599 - 233ms/epoch - 17ms/step
# Epoch 108/500
# 14/14 - 0s - loss: 0.0625 - val_loss: 0.0599 - 228ms/epoch - 16ms/step
# Epoch 109/500
# 14/14 - 0s - loss: 0.0629 - val_loss: 0.0604 - 237ms/epoch - 17ms/step
# Epoch 110/500
# 14/14 - 0s - loss: 0.0626 - val_loss: 0.0608 - 240ms/epoch - 17ms/step
# Epoch 111/500
# 14/14 - 0s - loss: 0.0624 - val_loss: 0.0606 - 264ms/epoch - 19ms/step
# Epoch 112/500
# 14/14 - 0s - loss: 0.0624 - val_loss: 0.0608 - 227ms/epoch - 16ms/step
# Epoch 113/500
# 14/14 - 0s - loss: 0.0621 - val_loss: 0.0596 - 230ms/epoch - 16ms/step
# Epoch 114/500
# 14/14 - 0s - loss: 0.0620 - val_loss: 0.0598 - 233ms/epoch - 17ms/step
# Epoch 115/500
# 14/14 - 0s - loss: 0.0619 - val_loss: 0.0598 - 224ms/epoch - 16ms/step
# Epoch 116/500
# 14/14 - 0s - loss: 0.0618 - val_loss: 0.0600 - 233ms/epoch - 17ms/step
# Epoch 117/500
# 14/14 - 0s - loss: 0.0615 - val_loss: 0.0598 - 224ms/epoch - 16ms/step
# Epoch 118/500
# 14/14 - 0s - loss: 0.0615 - val_loss: 0.0605 - 226ms/epoch - 16ms/step
# Epoch 119/500
# 14/14 - 0s - loss: 0.0614 - val_loss: 0.0601 - 235ms/epoch - 17ms/step
# Epoch 120/500
# 14/14 - 0s - loss: 0.0613 - val_loss: 0.0600 - 239ms/epoch - 17ms/step
# Epoch 121/500
# 14/14 - 0s - loss: 0.0612 - val_loss: 0.0598 - 235ms/epoch - 17ms/step
# Epoch 122/500
# 14/14 - 0s - loss: 0.0613 - val_loss: 0.0598 - 241ms/epoch - 17ms/step
# Epoch 123/500
# 14/14 - 0s - loss: 0.0613 - val_loss: 0.0601 - 222ms/epoch - 16ms/step
# Epoch 124/500
# 14/14 - 0s - loss: 0.0611 - val_loss: 0.0604 - 236ms/epoch - 17ms/step
# Epoch 125/500
# 14/14 - 0s - loss: 0.0609 - val_loss: 0.0608 - 245ms/epoch - 17ms/step
# Epoch 126/500
# 14/14 - 0s - loss: 0.0611 - val_loss: 0.0614 - 243ms/epoch - 17ms/step
# Epoch 127/500
# 14/14 - 0s - loss: 0.0615 - val_loss: 0.0621 - 228ms/epoch - 16ms/step
# Epoch 128/500
# 14/14 - 0s - loss: 0.0622 - val_loss: 0.0619 - 225ms/epoch - 16ms/step
# Epoch 129/500
# 14/14 - 0s - loss: 0.0615 - val_loss: 0.0604 - 229ms/epoch - 16ms/step
# Epoch 130/500
# 14/14 - 0s - loss: 0.0611 - val_loss: 0.0595 - 228ms/epoch - 16ms/step
# Epoch 131/500
# 14/14 - 0s - loss: 0.0609 - val_loss: 0.0597 - 236ms/epoch - 17ms/step
# Epoch 132/500
# 14/14 - 0s - loss: 0.0608 - val_loss: 0.0593 - 229ms/epoch - 16ms/step
# Epoch 133/500
# 14/14 - 0s - loss: 0.0616 - val_loss: 0.0600 - 238ms/epoch - 17ms/step
# Epoch 134/500
# 14/14 - 0s - loss: 0.0609 - val_loss: 0.0607 - 226ms/epoch - 16ms/step
# Epoch 135/500
# 14/14 - 0s - loss: 0.0607 - val_loss: 0.0628 - 218ms/epoch - 16ms/step
# Epoch 136/500
# 14/14 - 0s - loss: 0.0622 - val_loss: 0.0640 - 226ms/epoch - 16ms/step
# Epoch 137/500
# 14/14 - 0s - loss: 0.0635 - val_loss: 0.0601 - 241ms/epoch - 17ms/step
# Epoch 138/500
# 14/14 - 0s - loss: 0.0617 - val_loss: 0.0597 - 232ms/epoch - 17ms/step
# Epoch 139/500
# 14/14 - 0s - loss: 0.0613 - val_loss: 0.0597 - 231ms/epoch - 17ms/step
# Epoch 140/500
# 14/14 - 0s - loss: 0.0607 - val_loss: 0.0601 - 230ms/epoch - 16ms/step
# Epoch 141/500
# 14/14 - 0s - loss: 0.0603 - val_loss: 0.0606 - 244ms/epoch - 17ms/step
# Epoch 142/500
# 14/14 - 0s - loss: 0.0603 - val_loss: 0.0610 - 240ms/epoch - 17ms/step
# Epoch 143/500
# 14/14 - 0s - loss: 0.0608 - val_loss: 0.0598 - 227ms/epoch - 16ms/step
# Epoch 144/500
# 14/14 - 0s - loss: 0.0606 - val_loss: 0.0600 - 225ms/epoch - 16ms/step
# Epoch 145/500
# 14/14 - 0s - loss: 0.0600 - val_loss: 0.0592 - 225ms/epoch - 16ms/step
# Epoch 146/500
# 14/14 - 0s - loss: 0.0602 - val_loss: 0.0596 - 236ms/epoch - 17ms/step
# Epoch 147/500
# 14/14 - 0s - loss: 0.0599 - val_loss: 0.0601 - 224ms/epoch - 16ms/step
# Epoch 148/500
# 14/14 - 0s - loss: 0.0596 - val_loss: 0.0612 - 223ms/epoch - 16ms/step
# Epoch 149/500
# 14/14 - 0s - loss: 0.0600 - val_loss: 0.0606 - 241ms/epoch - 17ms/step
# Epoch 150/500
# 14/14 - 0s - loss: 0.0607 - val_loss: 0.0608 - 239ms/epoch - 17ms/step
# Epoch 151/500
# 14/14 - 0s - loss: 0.0600 - val_loss: 0.0602 - 229ms/epoch - 16ms/step
# Epoch 152/500
# 14/14 - 0s - loss: 0.0599 - val_loss: 0.0595 - 231ms/epoch - 16ms/step
# Epoch 153/500
# 14/14 - 0s - loss: 0.0598 - val_loss: 0.0610 - 235ms/epoch - 17ms/step
# Epoch 154/500
# 14/14 - 0s - loss: 0.0594 - val_loss: 0.0607 - 224ms/epoch - 16ms/step
# Epoch 155/500
# 14/14 - 0s - loss: 0.0593 - val_loss: 0.0608 - 242ms/epoch - 17ms/step
# Epoch 156/500
# 14/14 - 0s - loss: 0.0597 - val_loss: 0.0626 - 222ms/epoch - 16ms/step
# Epoch 157/500
# 14/14 - 0s - loss: 0.0601 - val_loss: 0.0604 - 222ms/epoch - 16ms/step
# Epoch 158/500
# 14/14 - 0s - loss: 0.0597 - val_loss: 0.0597 - 231ms/epoch - 16ms/step
# Epoch 159/500
# 14/14 - 0s - loss: 0.0594 - val_loss: 0.0607 - 237ms/epoch - 17ms/step
# Epoch 160/500
# 14/14 - 0s - loss: 0.0590 - val_loss: 0.0617 - 229ms/epoch - 16ms/step
# Epoch 161/500
# 14/14 - 0s - loss: 0.0593 - val_loss: 0.0605 - 233ms/epoch - 17ms/step
# Epoch 162/500
# 14/14 - 0s - loss: 0.0587 - val_loss: 0.0611 - 243ms/epoch - 17ms/step
# Epoch 163/500
# 14/14 - 0s - loss: 0.0590 - val_loss: 0.0632 - 243ms/epoch - 17ms/step
# Epoch 164/500
# 14/14 - 0s - loss: 0.0593 - val_loss: 0.0608 - 236ms/epoch - 17ms/step
# Epoch 165/500
# 14/14 - 0s - loss: 0.0591 - val_loss: 0.0606 - 260ms/epoch - 19ms/step
# Epoch 166/500
# 14/14 - 0s - loss: 0.0590 - val_loss: 0.0613 - 233ms/epoch - 17ms/step
# Epoch 167/500
# 14/14 - 0s - loss: 0.0592 - val_loss: 0.0623 - 234ms/epoch - 17ms/step
# Epoch 168/500
# 14/14 - 0s - loss: 0.0604 - val_loss: 0.0602 - 228ms/epoch - 16ms/step
# Epoch 169/500
# 14/14 - 0s - loss: 0.0590 - val_loss: 0.0612 - 233ms/epoch - 17ms/step
# Epoch 170/500
# 14/14 - 0s - loss: 0.0589 - val_loss: 0.0630 - 231ms/epoch - 17ms/step
# Epoch 171/500
# 14/14 - 0s - loss: 0.0593 - val_loss: 0.0603 - 239ms/epoch - 17ms/step
# Epoch 172/500
# 14/14 - 0s - loss: 0.0589 - val_loss: 0.0620 - 238ms/epoch - 17ms/step
# Epoch 173/500
# 14/14 - 0s - loss: 0.0590 - val_loss: 0.0617 - 219ms/epoch - 16ms/step
# Epoch 174/500
# 14/14 - 0s - loss: 0.0588 - val_loss: 0.0601 - 229ms/epoch - 16ms/step
# Epoch 175/500
# 14/14 - 0s - loss: 0.0584 - val_loss: 0.0610 - 224ms/epoch - 16ms/step
# Epoch 176/500
# 14/14 - 0s - loss: 0.0583 - val_loss: 0.0636 - 248ms/epoch - 18ms/step
# Epoch 177/500
# 14/14 - 0s - loss: 0.0589 - val_loss: 0.0622 - 226ms/epoch - 16ms/step
# Epoch 178/500
# 14/14 - 0s - loss: 0.0590 - val_loss: 0.0621 - 220ms/epoch - 16ms/step
# Epoch 179/500
# 14/14 - 0s - loss: 0.0586 - val_loss: 0.0628 - 238ms/epoch - 17ms/step
# Epoch 180/500
# 14/14 - 0s - loss: 0.0583 - val_loss: 0.0621 - 234ms/epoch - 17ms/step
# Epoch 181/500
# 14/14 - 0s - loss: 0.0584 - val_loss: 0.0611 - 234ms/epoch - 17ms/step
# Epoch 182/500
# 14/14 - 0s - loss: 0.0579 - val_loss: 0.0632 - 224ms/epoch - 16ms/step
# Epoch 183/500
# 14/14 - 0s - loss: 0.0581 - val_loss: 0.0634 - 234ms/epoch - 17ms/step
# Epoch 184/500
# 14/14 - 0s - loss: 0.0581 - val_loss: 0.0625 - 232ms/epoch - 17ms/step
# Epoch 185/500
# 14/14 - 0s - loss: 0.0580 - val_loss: 0.0630 - 238ms/epoch - 17ms/step
# Epoch 186/500
# 14/14 - 0s - loss: 0.0581 - val_loss: 0.0622 - 258ms/epoch - 18ms/step
# Epoch 187/500
# 14/14 - 0s - loss: 0.0584 - val_loss: 0.0619 - 223ms/epoch - 16ms/step
# Epoch 188/500
# 14/14 - 0s - loss: 0.0592 - val_loss: 0.0607 - 231ms/epoch - 16ms/step
# Epoch 189/500
# 14/14 - 0s - loss: 0.0578 - val_loss: 0.0631 - 261ms/epoch - 19ms/step
# Epoch 190/500
# 14/14 - 0s - loss: 0.0578 - val_loss: 0.0638 - 228ms/epoch - 16ms/step
# Epoch 191/500
# 14/14 - 0s - loss: 0.0576 - val_loss: 0.0645 - 229ms/epoch - 16ms/step
# Epoch 192/500
# 14/14 - 0s - loss: 0.0582 - val_loss: 0.0629 - 232ms/epoch - 17ms/step
# Epoch 193/500
# 14/14 - 0s - loss: 0.0580 - val_loss: 0.0609 - 239ms/epoch - 17ms/step
# Epoch 194/500
# 14/14 - 0s - loss: 0.0579 - val_loss: 0.0635 - 225ms/epoch - 16ms/step
# Epoch 195/500
# 14/14 - 0s - loss: 0.0597 - val_loss: 0.0616 - 227ms/epoch - 16ms/step

# %% [markdown]
# ## Predictions of the year 2019

# %%
# make a prediction
yhat = model.predict(test_X)
#Convert from 3D to 2D
test_X = test_X.reshape((test_X.shape[0], n_days*n_features))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -5:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -5:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 6.189

# %% [markdown]
# #### Prediciton plots

# %%
pyplot.plot(inv_yhat, label = 'Prediction')
pyplot.plot(inv_y, label = 'Real')
pyplot.legend()
pyplot.show()

# %% [markdown]
# # Modeling with hyperparamenter search
# # Goal: reduce the MSE without overfitting

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 98 kB 3.2 MB/s

# %%
import tensorflow as tf
from tensorflow import keras
import keras_tuner as kt #Keras Creates a better model

# %%
tf.config.list_physical_devices('GPU') #To undestand which GPU using during the training
# Out:
# []

# %% [markdown]
# ## Function to create new models

# %%
def model_builder(hp):
  #design network
  #object created with keras_tuner -> iterates some parameters to create the model
  #units = neurons we use 32 steps for each time
  hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
  #Initialization of the model
  model = Sequential() 
  model.add(LSTM(units = hp_units,return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
  #for loop to iterate different quantities of layer (from 1 to 3 layer)
  for i in range(hp.Int('layers',1,3)):
   model.add(LSTM(units = hp_units, return_sequences=True))
  model.add(LSTM(units = hp_units, return_sequences=False))
  model.add(Dense(1))
  #Choose from a list of given instructions -> we choose leanrning rates
  #We look the performances
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
  model.compile(loss='mae', optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate))
  return model

# %% [markdown]
# # Creation of the object with model_builder(hp)
# ## Parameter to look at: validation loss

# %%
tuner = kt.RandomSearch(
    model_builder,
    objective='val_loss',
    max_trials=10,
    executions_per_trial =3,
    directory = 'dir',
    project_name = 'namee')
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 3
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 3, 'step': 1, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
early_stopping = EarlyStopping(monitor='val_loss',patience=10)
tuner.search(train_X, train_y, epochs=100, batch_size=72, validation_data=(test_X, test_y),shuffle=False, callbacks=[early_stopping])
# Out:
# Trial 10 Complete [00h 16m 14s]
# val_loss: 0.08407227694988251
#
# Best val_loss So Far: 0.06101139013965925
# Total elapsed time: 01h 00m 09s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in dir/namee
# Showing 10 best trials
# Objective(name='val_loss', direction='min')

# %% [markdown]
# ### Hyperband

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_loss',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')
# Out:
# INFO:tensorflow:Reloading Oracle from existing project my_dir/intro_to_kt/oracle.json
# INFO:tensorflow:Reloading Tuner from my_dir/intro_to_kt/tuner0.json

# %%
tuner.search(train_X, train_y, epochs=1000, batch_size=72, validation_data=(test_X, test_y),shuffle=False, callbacks=[early_stopping])
