# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow.keras as keras

# %%
table = read_csv('/content/drive/MyDrive/Thesis/csvs/NNdata.csv')
table.head()
# Out:
#                    Date  IDStation  ... Wind_direction_max  Rainfall
# 0  2018-01-01T00:00:00Z        677  ...                NaN       7.2
# 1  2018-01-01T00:00:00Z        681  ...              144.0       2.4
# 2  2018-01-01T00:00:00Z        703  ...                NaN       5.8
# 3  2018-01-02T00:00:00Z        677  ...                NaN       0.0
# 4  2018-01-02T00:00:00Z        681  ...              213.0       0.0
#
# [5 rows x 31 columns]

# %%
Moggio = table.loc[table.loc[:,"NameStation"]=="Moggio",:]
Moggio = Moggio.loc[:,["Date","Ammonia","PM10","PM25","Wind_speed","Wind_direction","Temperature","Rainfall"]]
Moggio = Moggio.dropna(how="any")
Moggio = Moggio.reset_index()
Moggio = Moggio.iloc[:730,:] # we train not using 2020, for now
Moggio.head()
# Out:
#    index                  Date  Ammonia  ...  Wind_direction  Temperature  Rainfall
# 0      1  2018-01-01T00:00:00Z      1.4  ...            65.0     2.095833       2.4
# 1      4  2018-01-02T00:00:00Z      1.0  ...             9.0     1.670139       0.0
# 2      7  2018-01-03T00:00:00Z      1.0  ...            28.0     1.972222       0.6
# 3     10  2018-01-04T00:00:00Z      1.4  ...            21.0     3.081250       0.0
# 4     13  2018-01-05T00:00:00Z      1.7  ...            87.0     3.653472       0.0
#
# [5 rows x 9 columns]

# %% [markdown]
# ##Convert series to supervised learning

# %% [markdown]
# ###Conversion Function

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	"""
	Frame a time series as a supervised learning dataset.
	Arguments:
		data: Sequence of observations as a list or NumPy array.
		n_in: Number of lag observations as input (X).
		n_out: Number of observations as output (y).
		dropnan: Boolean whether or not to drop rows with NaN values.
	Returns:
		Pandas DataFrame of series framed for supervised learning.
	"""
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %% [markdown]
# ### Conversion of Moggio

# %%
values = Moggio.iloc[:,2:].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
n_days = 5
reframed = series_to_supervised(scaled, n_days, 1) # info of the past 5 days to determine next (1) day
# drop columns we don't want to predict (we therefore keep Ammonia)
reframed.drop(reframed.columns[[36,37,38,39,40,41]], axis=1, inplace=True)

reframed.head()
# Out:
#    var1(t-5)  var2(t-5)  var3(t-5)  ...  var6(t-1)  var7(t-1)   var1(t)
# 5   0.069307   0.081967   0.088889  ...   0.390648   0.000000  0.094059
# 6   0.049505   0.049180   0.044444  ...   0.403358   0.100204  0.094059
# 7   0.049505   0.081967   0.111111  ...   0.433662   0.012270  0.084158
# 8   0.069307   0.098361   0.066667  ...   0.459754   0.000000  0.084158
# 9   0.084158   0.114754   0.177778  ...   0.391011   0.329243  0.074257
#
# [5 rows x 36 columns]

# %%
# split into train and test sets
values = reframed.values
n_features = 7 # number of variables, including the one to be predicted
n_train_days = 365 # we train using only the first year
train = values[:n_train_days, :]
test = values[n_train_days:, :] # we test using all successive years 
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (365, 35) 365 (365,)
# (365, 5, 7) (365,) (360, 5, 7) (360,)

# %% [markdown]
# # Modeling and training

# %%
class LNSimpleRNNCell(keras.layers.Layer):
       def __init__(self, units, activation="tanh", **kwargs):         
         super().__init__(**kwargs)         
         self.state_size = units         
         self.output_size = units         
         self.simple_rnn_cell = keras.layers.SimpleRNNCell(units,                                                          
                                                           activation=None)         
         self.layer_norm = keras.layers.LayerNormalization()        
         self.activation = keras.activations.get(activation)     
       def call(self, inputs, states):         
         outputs, new_states = self.simple_rnn_cell(inputs, states)         
         norm_outputs = self.activation(self.layer_norm(outputs))        
         return norm_outputs, [norm_outputs]

# %%
# design network
model = keras.models.Sequential([     
                                 keras.layers.RNN(LNSimpleRNNCell(50), return_sequences=True, input_shape=[train_X.shape[1], train_X.shape[2]]),     
                                 keras.layers.RNN(LNSimpleRNNCell(50), return_sequences=True),    
                                 keras.layers.TimeDistributed(keras.layers.Dense(1)) ])
model.compile(loss='mae', optimizer='adam')
# fit network
early_stopping = EarlyStopping(patience=10, restore_best_weights = True)
history = model.fit(train_X, train_y, epochs=100, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False, callbacks=early_stopping)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/100
# 6/6 - 10s - loss: 0.4925 - val_loss: 0.3282 - 10s/epoch - 2s/step
# Epoch 2/100
# 6/6 - 0s - loss: 0.2933 - val_loss: 0.2514 - 266ms/epoch - 44ms/step
# Epoch 3/100
# 6/6 - 0s - loss: 0.1958 - val_loss: 0.2068 - 411ms/epoch - 69ms/step
# Epoch 4/100
# 6/6 - 0s - loss: 0.1649 - val_loss: 0.1843 - 259ms/epoch - 43ms/step
# Epoch 5/100
# 6/6 - 0s - loss: 0.1500 - val_loss: 0.1731 - 331ms/epoch - 55ms/step
# Epoch 6/100
# 6/6 - 0s - loss: 0.1321 - val_loss: 0.1713 - 256ms/epoch - 43ms/step
# Epoch 7/100
# 6/6 - 0s - loss: 0.1265 - val_loss: 0.1685 - 274ms/epoch - 46ms/step
# Epoch 8/100
# 6/6 - 0s - loss: 0.1248 - val_loss: 0.1628 - 237ms/epoch - 39ms/step
# Epoch 9/100
# 6/6 - 0s - loss: 0.1273 - val_loss: 0.1659 - 310ms/epoch - 52ms/step
# Epoch 10/100
# 6/6 - 0s - loss: 0.1185 - val_loss: 0.1617 - 369ms/epoch - 61ms/step
# Epoch 11/100
# 6/6 - 0s - loss: 0.1212 - val_loss: 0.1596 - 275ms/epoch - 46ms/step
# Epoch 12/100
# 6/6 - 0s - loss: 0.1279 - val_loss: 0.1637 - 262ms/epoch - 44ms/step
# Epoch 13/100
# 6/6 - 0s - loss: 0.1149 - val_loss: 0.1599 - 280ms/epoch - 47ms/step
# Epoch 14/100
# 6/6 - 0s - loss: 0.1182 - val_loss: 0.1581 - 250ms/epoch - 42ms/step
# Epoch 15/100
# 6/6 - 0s - loss: 0.1233 - val_loss: 0.1631 - 237ms/epoch - 40ms/step
# Epoch 16/100
# 6/6 - 0s - loss: 0.1162 - val_loss: 0.1589 - 230ms/epoch - 38ms/step
# Epoch 17/100
# 6/6 - 0s - loss: 0.1226 - val_loss: 0.1574 - 344ms/epoch - 57ms/step
# Epoch 18/100
# 6/6 - 0s - loss: 0.1219 - val_loss: 0.1599 - 291ms/epoch - 49ms/step
# Epoch 19/100
# 6/6 - 0s - loss: 0.1163 - val_loss: 0.1569 - 207ms/epoch - 35ms/step
# Epoch 20/100
# 6/6 - 0s - loss: 0.1166 - val_loss: 0.1568 - 227ms/epoch - 38ms/step
# Epoch 21/100
# 6/6 - 0s - loss: 0.1198 - val_loss: 0.1583 - 225ms/epoch - 38ms/step
# Epoch 22/100
# 6/6 - 0s - loss: 0.1129 - val_loss: 0.1581 - 323ms/epoch - 54ms/step
# Epoch 23/100
# 6/6 - 0s - loss: 0.1163 - val_loss: 0.1557 - 212ms/epoch - 35ms/step
# Epoch 24/100
# 6/6 - 0s - loss: 0.1197 - val_loss: 0.1587 - 226ms/epoch - 38ms/step
# Epoch 25/100
# 6/6 - 0s - loss: 0.1119 - val_loss: 0.1576 - 248ms/epoch - 41ms/step
# Epoch 26/100
# 6/6 - 0s - loss: 0.1226 - val_loss: 0.1551 - 264ms/epoch - 44ms/step
# Epoch 27/100
# 6/6 - 0s - loss: 0.1307 - val_loss: 0.1600 - 317ms/epoch - 53ms/step
# Epoch 28/100
# 6/6 - 0s - loss: 0.1171 - val_loss: 0.1566 - 244ms/epoch - 41ms/step
# Epoch 29/100
# 6/6 - 0s - loss: 0.1219 - val_loss: 0.1553 - 318ms/epoch - 53ms/step
# Epoch 30/100
# 6/6 - 0s - loss: 0.1293 - val_loss: 0.1597 - 203ms/epoch - 34ms/step
# Epoch 31/100
# 6/6 - 0s - loss: 0.1135 - val_loss: 0.1545 - 245ms/epoch - 41ms/step
# Epoch 32/100
# 6/6 - 0s - loss: 0.1171 - val_loss: 0.1556 - 304ms/epoch - 51ms/step
# Epoch 33/100
# 6/6 - 0s - loss: 0.1132 - val_loss: 0.1550 - 234ms/epoch - 39ms/step
# Epoch 34/100
# 6/6 - 0s - loss: 0.1120 - val_loss: 0.1535 - 227ms/epoch - 38ms/step
# Epoch 35/100
# 6/6 - 0s - loss: 0.1139 - val_loss: 0.1547 - 269ms/epoch - 45ms/step
# Epoch 36/100
# 6/6 - 0s - loss: 0.1151 - val_loss: 0.1538 - 310ms/epoch - 52ms/step
# Epoch 37/100
# 6/6 - 0s - loss: 0.1118 - val_loss: 0.1557 - 233ms/epoch - 39ms/step
# Epoch 38/100
# 6/6 - 0s - loss: 0.1142 - val_loss: 0.1529 - 226ms/epoch - 38ms/step
# Epoch 39/100
# 6/6 - 0s - loss: 0.1164 - val_loss: 0.1540 - 264ms/epoch - 44ms/step
# Epoch 40/100
# 6/6 - 0s - loss: 0.1118 - val_loss: 0.1561 - 238ms/epoch - 40ms/step
# Epoch 41/100
# 6/6 - 0s - loss: 0.1112 - val_loss: 0.1532 - 256ms/epoch - 43ms/step
# Epoch 42/100
# 6/6 - 0s - loss: 0.1123 - val_loss: 0.1528 - 317ms/epoch - 53ms/step
# Epoch 43/100
# 6/6 - 0s - loss: 0.1158 - val_loss: 0.1537 - 209ms/epoch - 35ms/step
# Epoch 44/100
# 6/6 - 0s - loss: 0.1088 - val_loss: 0.1630 - 235ms/epoch - 39ms/step
# Epoch 45/100
# 6/6 - 0s - loss: 0.1229 - val_loss: 0.1570 - 295ms/epoch - 49ms/step
# Epoch 46/100
# 6/6 - 0s - loss: 0.1296 - val_loss: 0.1594 - 277ms/epoch - 46ms/step
# Epoch 47/100
# 6/6 - 0s - loss: 0.1069 - val_loss: 0.1542 - 238ms/epoch - 40ms/step
# Epoch 48/100
# 6/6 - 0s - loss: 0.1191 - val_loss: 0.1536 - 218ms/epoch - 36ms/step
# Epoch 49/100
# 6/6 - 0s - loss: 0.1305 - val_loss: 0.1592 - 255ms/epoch - 42ms/step
# Epoch 50/100
# 6/6 - 0s - loss: 0.1143 - val_loss: 0.1530 - 251ms/epoch - 42ms/step
# Epoch 51/100
# 6/6 - 0s - loss: 0.1089 - val_loss: 0.1518 - 361ms/epoch - 60ms/step
# Epoch 52/100
# 6/6 - 0s - loss: 0.1125 - val_loss: 0.1531 - 180ms/epoch - 30ms/step
# Epoch 53/100
# 6/6 - 0s - loss: 0.1076 - val_loss: 0.1561 - 174ms/epoch - 29ms/step
# Epoch 54/100
# 6/6 - 0s - loss: 0.1153 - val_loss: 0.1523 - 121ms/epoch - 20ms/step
# Epoch 55/100
# 6/6 - 0s - loss: 0.1205 - val_loss: 0.1561 - 165ms/epoch - 27ms/step
# Epoch 56/100
# 6/6 - 0s - loss: 0.1071 - val_loss: 0.1533 - 172ms/epoch - 29ms/step
# Epoch 57/100
# 6/6 - 0s - loss: 0.1106 - val_loss: 0.1523 - 120ms/epoch - 20ms/step
# Epoch 58/100
# 6/6 - 0s - loss: 0.1206 - val_loss: 0.1549 - 153ms/epoch - 25ms/step
# Epoch 59/100
# 6/6 - 0s - loss: 0.1074 - val_loss: 0.1545 - 165ms/epoch - 27ms/step
# Epoch 60/100
# 6/6 - 0s - loss: 0.1130 - val_loss: 0.1527 - 180ms/epoch - 30ms/step
# Epoch 61/100
# 6/6 - 0s - loss: 0.1203 - val_loss: 0.1562 - 164ms/epoch - 27ms/step

# %%
# design network
model = keras.models.Sequential([     
                                 keras.layers.RNN(LNSimpleRNNCell(50), return_sequences=True, input_shape=[train_X.shape[1], train_X.shape[2]]),
                                 keras.layers.LSTM(50, return_sequences=True),        
                                 keras.layers.TimeDistributed(keras.layers.Dense(1)) ])
model.compile(loss='mae', optimizer='adam')
# fit network
early_stopping = EarlyStopping(patience=10, restore_best_weights = True)
history = model.fit(train_X, train_y, epochs=100, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False, callbacks=early_stopping)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/100
# 6/6 - 4s - loss: 0.2395 - val_loss: 0.2269 - 4s/epoch - 749ms/step
# Epoch 2/100
# 6/6 - 0s - loss: 0.1523 - val_loss: 0.1734 - 116ms/epoch - 19ms/step
# Epoch 3/100
# 6/6 - 0s - loss: 0.1462 - val_loss: 0.1608 - 107ms/epoch - 18ms/step
# Epoch 4/100
# 6/6 - 0s - loss: 0.1266 - val_loss: 0.1705 - 151ms/epoch - 25ms/step
# Epoch 5/100
# 6/6 - 0s - loss: 0.1175 - val_loss: 0.1574 - 162ms/epoch - 27ms/step
# Epoch 6/100
# 6/6 - 0s - loss: 0.1176 - val_loss: 0.1567 - 140ms/epoch - 23ms/step
# Epoch 7/100
# 6/6 - 0s - loss: 0.1149 - val_loss: 0.1587 - 156ms/epoch - 26ms/step
# Epoch 8/100
# 6/6 - 0s - loss: 0.1092 - val_loss: 0.1546 - 133ms/epoch - 22ms/step
# Epoch 9/100
# 6/6 - 0s - loss: 0.1116 - val_loss: 0.1544 - 126ms/epoch - 21ms/step
# Epoch 10/100
# 6/6 - 0s - loss: 0.1095 - val_loss: 0.1543 - 125ms/epoch - 21ms/step
# Epoch 11/100
# 6/6 - 0s - loss: 0.1092 - val_loss: 0.1534 - 111ms/epoch - 19ms/step
# Epoch 12/100
# 6/6 - 0s - loss: 0.1090 - val_loss: 0.1538 - 130ms/epoch - 22ms/step
# Epoch 13/100
# 6/6 - 0s - loss: 0.1113 - val_loss: 0.1538 - 151ms/epoch - 25ms/step
# Epoch 14/100
# 6/6 - 0s - loss: 0.1077 - val_loss: 0.1520 - 124ms/epoch - 21ms/step
# Epoch 15/100
# 6/6 - 0s - loss: 0.1099 - val_loss: 0.1548 - 128ms/epoch - 21ms/step
# Epoch 16/100
# 6/6 - 0s - loss: 0.1085 - val_loss: 0.1519 - 114ms/epoch - 19ms/step
# Epoch 17/100
# 6/6 - 0s - loss: 0.1087 - val_loss: 0.1521 - 111ms/epoch - 18ms/step
# Epoch 18/100
# 6/6 - 0s - loss: 0.1097 - val_loss: 0.1528 - 113ms/epoch - 19ms/step
# Epoch 19/100
# 6/6 - 0s - loss: 0.1064 - val_loss: 0.1514 - 115ms/epoch - 19ms/step
# Epoch 20/100
# 6/6 - 0s - loss: 0.1092 - val_loss: 0.1525 - 151ms/epoch - 25ms/step
# Epoch 21/100
# 6/6 - 0s - loss: 0.1062 - val_loss: 0.1513 - 141ms/epoch - 24ms/step
# Epoch 22/100
# 6/6 - 0s - loss: 0.1093 - val_loss: 0.1524 - 115ms/epoch - 19ms/step
# Epoch 23/100
# 6/6 - 0s - loss: 0.1055 - val_loss: 0.1508 - 139ms/epoch - 23ms/step
# Epoch 24/100
# 6/6 - 0s - loss: 0.1078 - val_loss: 0.1520 - 123ms/epoch - 21ms/step
# Epoch 25/100
# 6/6 - 0s - loss: 0.1060 - val_loss: 0.1510 - 125ms/epoch - 21ms/step
# Epoch 26/100
# 6/6 - 0s - loss: 0.1081 - val_loss: 0.1513 - 161ms/epoch - 27ms/step
# Epoch 27/100
# 6/6 - 0s - loss: 0.1058 - val_loss: 0.1505 - 117ms/epoch - 19ms/step
# Epoch 28/100
# 6/6 - 0s - loss: 0.1071 - val_loss: 0.1524 - 122ms/epoch - 20ms/step
# Epoch 29/100
# 6/6 - 0s - loss: 0.1076 - val_loss: 0.1504 - 118ms/epoch - 20ms/step
# Epoch 30/100
# 6/6 - 0s - loss: 0.1074 - val_loss: 0.1505 - 121ms/epoch - 20ms/step
# Epoch 31/100
# 6/6 - 0s - loss: 0.1071 - val_loss: 0.1522 - 194ms/epoch - 32ms/step
# Epoch 32/100
# 6/6 - 0s - loss: 0.1059 - val_loss: 0.1500 - 139ms/epoch - 23ms/step
# Epoch 33/100
# 6/6 - 0s - loss: 0.1073 - val_loss: 0.1505 - 107ms/epoch - 18ms/step
# Epoch 34/100
# 6/6 - 0s - loss: 0.1065 - val_loss: 0.1510 - 122ms/epoch - 20ms/step
# Epoch 35/100
# 6/6 - 0s - loss: 0.1050 - val_loss: 0.1498 - 155ms/epoch - 26ms/step
# Epoch 36/100
# 6/6 - 0s - loss: 0.1067 - val_loss: 0.1509 - 149ms/epoch - 25ms/step
# Epoch 37/100
# 6/6 - 0s - loss: 0.1067 - val_loss: 0.1502 - 115ms/epoch - 19ms/step
# Epoch 38/100
# 6/6 - 0s - loss: 0.1057 - val_loss: 0.1502 - 122ms/epoch - 20ms/step
# Epoch 39/100
# 6/6 - 0s - loss: 0.1081 - val_loss: 0.1508 - 119ms/epoch - 20ms/step
# Epoch 40/100
# 6/6 - 0s - loss: 0.1051 - val_loss: 0.1498 - 117ms/epoch - 20ms/step
# Epoch 41/100
# 6/6 - 0s - loss: 0.1082 - val_loss: 0.1514 - 125ms/epoch - 21ms/step
# Epoch 42/100
# 6/6 - 0s - loss: 0.1040 - val_loss: 0.1495 - 171ms/epoch - 29ms/step
# Epoch 43/100
# 6/6 - 0s - loss: 0.1071 - val_loss: 0.1509 - 162ms/epoch - 27ms/step
# Epoch 44/100
# 6/6 - 0s - loss: 0.1038 - val_loss: 0.1494 - 129ms/epoch - 21ms/step
# Epoch 45/100
# 6/6 - 0s - loss: 0.1059 - val_loss: 0.1500 - 131ms/epoch - 22ms/step
# Epoch 46/100
# 6/6 - 0s - loss: 0.1048 - val_loss: 0.1499 - 127ms/epoch - 21ms/step
# Epoch 47/100
# 6/6 - 0s - loss: 0.1068 - val_loss: 0.1500 - 135ms/epoch - 23ms/step
# Epoch 48/100
# 6/6 - 0s - loss: 0.1048 - val_loss: 0.1493 - 152ms/epoch - 25ms/step
# Epoch 49/100
# 6/6 - 0s - loss: 0.1058 - val_loss: 0.1511 - 129ms/epoch - 22ms/step
# Epoch 50/100
# 6/6 - 0s - loss: 0.1058 - val_loss: 0.1494 - 130ms/epoch - 22ms/step
# Epoch 51/100
# 6/6 - 0s - loss: 0.1057 - val_loss: 0.1493 - 134ms/epoch - 22ms/step
# Epoch 52/100
# 6/6 - 0s - loss: 0.1055 - val_loss: 0.1504 - 117ms/epoch - 19ms/step
# Epoch 53/100
# 6/6 - 0s - loss: 0.1045 - val_loss: 0.1492 - 129ms/epoch - 21ms/step
# Epoch 54/100
# 6/6 - 0s - loss: 0.1057 - val_loss: 0.1497 - 128ms/epoch - 21ms/step
# Epoch 55/100
# 6/6 - 0s - loss: 0.1060 - val_loss: 0.1500 - 121ms/epoch - 20ms/step
# Epoch 56/100
# 6/6 - 0s - loss: 0.1037 - val_loss: 0.1491 - 156ms/epoch - 26ms/step
# Epoch 57/100
# 6/6 - 0s - loss: 0.1055 - val_loss: 0.1499 - 111ms/epoch - 19ms/step
# Epoch 58/100
# 6/6 - 0s - loss: 0.1041 - val_loss: 0.1492 - 149ms/epoch - 25ms/step
# Epoch 59/100
# 6/6 - 0s - loss: 0.1051 - val_loss: 0.1494 - 111ms/epoch - 19ms/step
# Epoch 60/100
# 6/6 - 0s - loss: 0.1042 - val_loss: 0.1493 - 146ms/epoch - 24ms/step
# Epoch 61/100
# 6/6 - 0s - loss: 0.1052 - val_loss: 0.1496 - 116ms/epoch - 19ms/step
# Epoch 62/100
# 6/6 - 0s - loss: 0.1039 - val_loss: 0.1492 - 117ms/epoch - 19ms/step
# Epoch 63/100
# 6/6 - 0s - loss: 0.1063 - val_loss: 0.1498 - 109ms/epoch - 18ms/step
# Epoch 64/100
# 6/6 - 0s - loss: 0.1042 - val_loss: 0.1490 - 117ms/epoch - 20ms/step
# Epoch 65/100
# 6/6 - 0s - loss: 0.1052 - val_loss: 0.1502 - 116ms/epoch - 19ms/step
# Epoch 66/100
# 6/6 - 0s - loss: 0.1037 - val_loss: 0.1489 - 112ms/epoch - 19ms/step
# Epoch 67/100
# 6/6 - 0s - loss: 0.1051 - val_loss: 0.1492 - 124ms/epoch - 21ms/step
# Epoch 68/100
# 6/6 - 0s - loss: 0.1037 - val_loss: 0.1493 - 143ms/epoch - 24ms/step
# Epoch 69/100
# 6/6 - 0s - loss: 0.1055 - val_loss: 0.1498 - 112ms/epoch - 19ms/step
# Epoch 70/100
# 6/6 - 0s - loss: 0.1037 - val_loss: 0.1490 - 120ms/epoch - 20ms/step
# Epoch 71/100
# 6/6 - 0s - loss: 0.1048 - val_loss: 0.1499 - 111ms/epoch - 18ms/step
# Epoch 72/100
# 6/6 - 0s - loss: 0.1048 - val_loss: 0.1492 - 119ms/epoch - 20ms/step
# Epoch 73/100
# 6/6 - 0s - loss: 0.1043 - val_loss: 0.1490 - 117ms/epoch - 20ms/step
# Epoch 74/100
# 6/6 - 0s - loss: 0.1045 - val_loss: 0.1496 - 152ms/epoch - 25ms/step
# Epoch 75/100
# 6/6 - 0s - loss: 0.1035 - val_loss: 0.1490 - 122ms/epoch - 20ms/step
# Epoch 76/100
# 6/6 - 0s - loss: 0.1042 - val_loss: 0.1491 - 163ms/epoch - 27ms/step

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
from tensorflow.keras.layers import RNN
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.7/dist-packages (0.15.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)

# %%
# design network
model = Sequential()
model.add(RNN(tfa.rnn.LayerNormLSTMCell(50), return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(RNN(tfa.rnn.LayerNormLSTMCell(50), return_sequences=True))
model.add(RNN(tfa.rnn.LayerNormLSTMCell(50), return_sequences=False))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')
# fit network
early_stopping = EarlyStopping(patience=10, restore_best_weights = True)
history = model.fit(train_X, train_y, epochs=1000, batch_size=50, validation_data=(test_X, test_y), verbose=2, shuffle=False, callbacks=early_stopping)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/1000
# 8/8 - 12s - loss: 0.1508 - val_loss: 0.1688 - 12s/epoch - 1s/step
# Epoch 2/1000
# 8/8 - 0s - loss: 0.1023 - val_loss: 0.0710 - 435ms/epoch - 54ms/step
# Epoch 3/1000
# 8/8 - 0s - loss: 0.0223 - val_loss: 0.0488 - 468ms/epoch - 59ms/step
# Epoch 4/1000
# 8/8 - 0s - loss: 0.0374 - val_loss: 0.0403 - 443ms/epoch - 55ms/step
# Epoch 5/1000
# 8/8 - 0s - loss: 0.0208 - val_loss: 0.0371 - 490ms/epoch - 61ms/step
# Epoch 6/1000
# 8/8 - 0s - loss: 0.0206 - val_loss: 0.0344 - 472ms/epoch - 59ms/step
# Epoch 7/1000
# 8/8 - 0s - loss: 0.0174 - val_loss: 0.0295 - 478ms/epoch - 60ms/step
# Epoch 8/1000
# 8/8 - 0s - loss: 0.0128 - val_loss: 0.0258 - 457ms/epoch - 57ms/step
# Epoch 9/1000
# 8/8 - 0s - loss: 0.0115 - val_loss: 0.0231 - 437ms/epoch - 55ms/step
# Epoch 10/1000
# 8/8 - 0s - loss: 0.0102 - val_loss: 0.0226 - 482ms/epoch - 60ms/step
# Epoch 11/1000
# 8/8 - 0s - loss: 0.0097 - val_loss: 0.0217 - 460ms/epoch - 57ms/step
# Epoch 12/1000
# 8/8 - 0s - loss: 0.0091 - val_loss: 0.0206 - 484ms/epoch - 60ms/step
# Epoch 13/1000
# 8/8 - 0s - loss: 0.0080 - val_loss: 0.0206 - 476ms/epoch - 60ms/step
# Epoch 14/1000
# 8/8 - 0s - loss: 0.0078 - val_loss: 0.0210 - 469ms/epoch - 59ms/step
# Epoch 15/1000
# 8/8 - 0s - loss: 0.0085 - val_loss: 0.0194 - 456ms/epoch - 57ms/step
# Epoch 16/1000
# 8/8 - 0s - loss: 0.0072 - val_loss: 0.0190 - 489ms/epoch - 61ms/step
# Epoch 17/1000
# 8/8 - 0s - loss: 0.0066 - val_loss: 0.0227 - 462ms/epoch - 58ms/step
# Epoch 18/1000
# 8/8 - 0s - loss: 0.0105 - val_loss: 0.0211 - 469ms/epoch - 59ms/step
# Epoch 19/1000
# 8/8 - 0s - loss: 0.0105 - val_loss: 0.0203 - 451ms/epoch - 56ms/step
# Epoch 20/1000
# 8/8 - 0s - loss: 0.0112 - val_loss: 0.0220 - 472ms/epoch - 59ms/step
# Epoch 21/1000
# 8/8 - 0s - loss: 0.0169 - val_loss: 0.0284 - 452ms/epoch - 56ms/step
# Epoch 22/1000
# 8/8 - 0s - loss: 0.0185 - val_loss: 0.0228 - 451ms/epoch - 56ms/step
# Epoch 23/1000
# 8/8 - 0s - loss: 0.0070 - val_loss: 0.0202 - 473ms/epoch - 59ms/step
# Epoch 24/1000
# 8/8 - 0s - loss: 0.0068 - val_loss: 0.0179 - 458ms/epoch - 57ms/step
# Epoch 25/1000
# 8/8 - 0s - loss: 0.0061 - val_loss: 0.0223 - 475ms/epoch - 59ms/step
# Epoch 26/1000
# 8/8 - 0s - loss: 0.0086 - val_loss: 0.0184 - 484ms/epoch - 60ms/step
# Epoch 27/1000
# 8/8 - 0s - loss: 0.0066 - val_loss: 0.0177 - 500ms/epoch - 62ms/step
# Epoch 28/1000
# 8/8 - 0s - loss: 0.0061 - val_loss: 0.0226 - 458ms/epoch - 57ms/step
# Epoch 29/1000
# 8/8 - 0s - loss: 0.0077 - val_loss: 0.0185 - 481ms/epoch - 60ms/step
# Epoch 30/1000
# 8/8 - 0s - loss: 0.0055 - val_loss: 0.0172 - 456ms/epoch - 57ms/step
# Epoch 31/1000
# 8/8 - 0s - loss: 0.0050 - val_loss: 0.0208 - 483ms/epoch - 60ms/step
# Epoch 32/1000
# 8/8 - 0s - loss: 0.0065 - val_loss: 0.0175 - 451ms/epoch - 56ms/step
# Epoch 33/1000
# 8/8 - 0s - loss: 0.0051 - val_loss: 0.0168 - 480ms/epoch - 60ms/step
# Epoch 34/1000
# 8/8 - 0s - loss: 0.0049 - val_loss: 0.0227 - 444ms/epoch - 55ms/step
# Epoch 35/1000
# 8/8 - 0s - loss: 0.0073 - val_loss: 0.0178 - 461ms/epoch - 58ms/step
# Epoch 36/1000
# 8/8 - 0s - loss: 0.0055 - val_loss: 0.0167 - 479ms/epoch - 60ms/step
# Epoch 37/1000
# 8/8 - 0s - loss: 0.0053 - val_loss: 0.0251 - 463ms/epoch - 58ms/step
# Epoch 38/1000
# 8/8 - 0s - loss: 0.0093 - val_loss: 0.0179 - 478ms/epoch - 60ms/step
# Epoch 39/1000
# 8/8 - 0s - loss: 0.0061 - val_loss: 0.0163 - 468ms/epoch - 59ms/step
# Epoch 40/1000
# 8/8 - 0s - loss: 0.0062 - val_loss: 0.0278 - 467ms/epoch - 58ms/step
# Epoch 41/1000
# 8/8 - 0s - loss: 0.0110 - val_loss: 0.0191 - 450ms/epoch - 56ms/step
# Epoch 42/1000
# 8/8 - 0s - loss: 0.0060 - val_loss: 0.0175 - 457ms/epoch - 57ms/step
# Epoch 43/1000
# 8/8 - 0s - loss: 0.0063 - val_loss: 0.0212 - 451ms/epoch - 56ms/step
# Epoch 44/1000
# 8/8 - 0s - loss: 0.0071 - val_loss: 0.0174 - 473ms/epoch - 59ms/step
# Epoch 45/1000
# 8/8 - 0s - loss: 0.0050 - val_loss: 0.0200 - 457ms/epoch - 57ms/step
# Epoch 46/1000
# 8/8 - 0s - loss: 0.0061 - val_loss: 0.0182 - 459ms/epoch - 57ms/step
# Epoch 47/1000
# 8/8 - 0s - loss: 0.0044 - val_loss: 0.0166 - 457ms/epoch - 57ms/step
# Epoch 48/1000
# 8/8 - 0s - loss: 0.0040 - val_loss: 0.0202 - 488ms/epoch - 61ms/step
# Epoch 49/1000
# 8/8 - 0s - loss: 0.0049 - val_loss: 0.0174 - 494ms/epoch - 62ms/step

# %%
class LNSimpleRNNCell(keras.layers.Layer):
       def __init__(self, units, activation="tanh", **kwargs):         
         super().__init__(**kwargs)         
         self.state_size = units         
         self.output_size = units         
         self.simple_rnn_cell = tfa.rnn.LayerNormLSTMCell(units)                     
       def call(self, inputs, states):         
         outputs, new_states = self.simple_rnn_cell(inputs, states)                
         return outputs

# %% [markdown]
# ## Predictions

# %%
# make a prediction using 2020 (not used for training or validation, and has different dynamics due to covid)
# adding back the data from 2020
Moggio = table.loc[table.loc[:,"NameStation"]=="Moggio",:]
Moggio = Moggio.loc[:,["Date","Ammonia","PM10","PM25","Wind_speed","Wind_direction","Temperature","Rainfall"]]
Moggio = Moggio.dropna(how="any")
Moggio = Moggio.reset_index()
#scaling and creating the new testing data
values = Moggio.iloc[:,2:].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
n_days = 5
reframed = series_to_supervised(scaled, n_days, 1) # info of the past 5 days to determine next (1) day
# drop columns we don't want to predict (we therefore keep Ammonia)
reframed.drop(reframed.columns[[36,37,38,39,40,41]], axis=1, inplace=True)
# split into train and test sets
values = reframed.values
n_features = 7 # number of variables, including the one to be predicted
n_train_days = 365 # we train using only the first year
train = values[:n_train_days, :]
test = values[n_train_days:, :] # we test using all successive years 
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (365, 35) 365 (365,)
# (365, 5, 7) (365,) (568, 5, 7) (568,)

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], n_days*n_features))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -6:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -6:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 2.387

# %% [markdown]
# #### Prediciton plots

# %%
pyplot.plot(inv_yhat, label = 'Prediction')
pyplot.plot(inv_y, label = 'Real')
pyplot.legend()
pyplot.show()

# %% [markdown]
# # Modeling with hyperparamenter search

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 98 kB 2.8 MB/s

# %%
import tensorflow as tf
from tensorflow import keras
import keras_tuner as kt

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
def model_builder(hp):
  # design network
  hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
  model = Sequential()
  model.add(LSTM(units = hp_units,return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
  for i in range(hp.Int('layers',1,3)):
   model.add(LSTM(units = hp_units, return_sequences=True))
  model.add(LSTM(units = hp_units, return_sequences=False))
  model.add(Dense(1))
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
  model.compile(loss='mae', optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate))
  return model

# %%
tuner = kt.RandomSearch(
    model_builder,
    objective='val_loss',
    max_trials=10,
    executions_per_trial =3,
    directory = 'dir',
    project_name = 'namee')
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 3
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 3, 'step': 1, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
early_stopping = EarlyStopping(monitor='val_loss',patience=10)
tuner.search(train_X, train_y, epochs=100, batch_size=72, validation_data=(test_X, test_y),shuffle=False, callbacks=[early_stopping])
# Out:
# Trial 10 Complete [00h 03m 25s]
# val_loss: 0.08057895551125209
#
# Best val_loss So Far: 0.052939437329769135
# Total elapsed time: 00h 55m 57s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()

# %% [markdown]
# ### Hyperband

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_loss',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')
# Out:
# INFO:tensorflow:Reloading Oracle from existing project my_dir/intro_to_kt/oracle.json
# INFO:tensorflow:Reloading Tuner from my_dir/intro_to_kt/tuner0.json

# %%
tuner.search(train_X, train_y, epochs=1000, batch_size=72, validation_data=(test_X, test_y),shuffle=False, callbacks=[early_stopping])
