# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import seaborn as sns
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
table = read_csv('/content/drive/MyDrive/Quadranti.csv')
table.head()
# Out:
#    Unnamed: 0                  Date  Ammonia  ...  Temperature  Rainfall  Quadrante
# 0           0  2014-01-01T00:00:00Z      0.0  ...    -0.334965       0.0          2
# 1           1  2014-01-02T00:00:00Z      0.0  ...    -0.486111       7.8          2
# 2           2  2014-01-03T00:00:00Z      0.0  ...     2.220588       0.0          2
# 3           3  2014-01-04T00:00:00Z      0.0  ...     2.137063      35.8          2
# 4           4  2014-01-05T00:00:00Z      0.0  ...     2.416084      25.0          2
#
# [5 rows x 9 columns]

# %%
#Moggio = table.loc[table.loc[:,"NameStation"]=="Moggio",:]
Moggio = table.loc[:,["Date","PM10","PM25","Ammonia","Wind_speed","Quadrante","Temperature","Rainfall"]]
Moggio = Moggio.dropna(how="any")
Moggio = Moggio.reset_index()
Moggio = Moggio.iloc[:-365,:] # we train not using 2020, for now
Moggio.head()
# Out:
#    index                  Date  PM10  ...  Quadrante  Temperature  Rainfall
# 0      0  2014-01-01T00:00:00Z   6.0  ...          2    -0.334965       0.0
# 1      1  2014-01-02T00:00:00Z   6.0  ...          2    -0.486111       7.8
# 2      2  2014-01-03T00:00:00Z  11.0  ...          2     2.220588       0.0
# 3      3  2014-01-04T00:00:00Z   6.0  ...          2     2.137063      35.8
# 4      4  2014-01-05T00:00:00Z   3.0  ...          2     2.416084      25.0
#
# [5 rows x 9 columns]

# %%
# sns.lineplot(x='Date', y='PM25', data=Moggio)

# %% [markdown]
# ##Convert series to supervised learning
# ### Activation function = tanh and logistic (s curve)

# %% [markdown]
# ###Conversion Function

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	"""
	Frame a time series as a supervised learning dataset.
	Arguments:
		data: Sequence of observations as a list or NumPy array.
		n_in: Number of lag observations as input (X).
		n_out: Number of observations as output (y).
		dropnan: Boolean whether or not to drop rows with NaN values.
	Returns:
		Pandas DataFrame of series framed for supervised learning.
	"""
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %% [markdown]
# ### Conversion of Moggio

# %%
values = Moggio.iloc[:,2:].values
# ensure all data is float
values = values.astype('float32') #cast in float 32 bit per evitare problemi
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
n_days = 5 #Memoria della NN
reframed = series_to_supervised(scaled, n_days, 1) # info of the past 5 days to determine next (1) day
# drop columns we don't want to predict (we therefore keep Ammonia)
reframed.drop(reframed.columns[[36, 37,38,39,40,41]], axis=1, inplace=True)

print(reframed.shape)
reframed.head()
# Out:
# (1662, 36)
#    var1(t-5)  var2(t-5)  var3(t-5)  ...  var6(t-1)  var7(t-1)   var1(t)
# 5   0.066667   0.088608        0.0  ...   0.358295   0.112816  0.022222
# 6   0.066667   0.063291        0.0  ...   0.406390   0.000000  0.077778
# 7   0.122222   0.050633        0.0  ...   0.397825   0.000000  0.044444
# 8   0.066667   0.088608        0.0  ...   0.408315   0.000000  0.044444
# 9   0.033333   0.101266        0.0  ...   0.392536   0.000000  0.133333
#
# [5 rows x 36 columns]

# %%
# split into train and test sets
values = reframed.values
n_features = 7 # number of variables, including the one to be predicted
n_train_days = 1312 # we train using only the first year
train = values[:n_train_days, :]
test = values[n_train_days:, :] # we test using all successive years 
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
# reshape from 2D to 3D
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1312, 35) 1312 (1312,)
# (1312, 5, 7) (1312,) (350, 5, 7) (350,)

# %% [markdown]
# # Modeling and training

# %%
# design the neural network
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
early_stopping = EarlyStopping(patience=50, restore_best_weights = True)
history = model.fit(train_X, train_y, epochs=500, batch_size=100, validation_data=(test_X, test_y), verbose=2, shuffle=False, callbacks=early_stopping)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/500
# 14/14 - 7s - loss: 0.1087 - val_loss: 0.0924 - 7s/epoch - 485ms/step
# Epoch 2/500
# 14/14 - 0s - loss: 0.0927 - val_loss: 0.0863 - 196ms/epoch - 14ms/step
# Epoch 3/500
# 14/14 - 0s - loss: 0.0909 - val_loss: 0.0856 - 202ms/epoch - 14ms/step
# Epoch 4/500
# 14/14 - 0s - loss: 0.0898 - val_loss: 0.0851 - 192ms/epoch - 14ms/step
# Epoch 5/500
# 14/14 - 0s - loss: 0.0894 - val_loss: 0.0845 - 197ms/epoch - 14ms/step
# Epoch 6/500
# 14/14 - 0s - loss: 0.0891 - val_loss: 0.0849 - 205ms/epoch - 15ms/step
# Epoch 7/500
# 14/14 - 0s - loss: 0.0887 - val_loss: 0.0843 - 195ms/epoch - 14ms/step
# Epoch 8/500
# 14/14 - 0s - loss: 0.0886 - val_loss: 0.0847 - 191ms/epoch - 14ms/step
# Epoch 9/500
# 14/14 - 0s - loss: 0.0884 - val_loss: 0.0843 - 197ms/epoch - 14ms/step
# Epoch 10/500
# 14/14 - 0s - loss: 0.0881 - val_loss: 0.0843 - 190ms/epoch - 14ms/step
# Epoch 11/500
# 14/14 - 0s - loss: 0.0878 - val_loss: 0.0842 - 211ms/epoch - 15ms/step
# Epoch 12/500
# 14/14 - 0s - loss: 0.0873 - val_loss: 0.0838 - 197ms/epoch - 14ms/step
# Epoch 13/500
# 14/14 - 0s - loss: 0.0869 - val_loss: 0.0837 - 192ms/epoch - 14ms/step
# Epoch 14/500
# 14/14 - 0s - loss: 0.0865 - val_loss: 0.0837 - 209ms/epoch - 15ms/step
# Epoch 15/500
# 14/14 - 0s - loss: 0.0858 - val_loss: 0.0827 - 188ms/epoch - 13ms/step
# Epoch 16/500
# 14/14 - 0s - loss: 0.0851 - val_loss: 0.0818 - 202ms/epoch - 14ms/step
# Epoch 17/500
# 14/14 - 0s - loss: 0.0843 - val_loss: 0.0810 - 196ms/epoch - 14ms/step
# Epoch 18/500
# 14/14 - 0s - loss: 0.0832 - val_loss: 0.0796 - 186ms/epoch - 13ms/step
# Epoch 19/500
# 14/14 - 0s - loss: 0.0822 - val_loss: 0.0780 - 193ms/epoch - 14ms/step
# Epoch 20/500
# 14/14 - 0s - loss: 0.0811 - val_loss: 0.0771 - 196ms/epoch - 14ms/step
# Epoch 21/500
# 14/14 - 0s - loss: 0.0802 - val_loss: 0.0764 - 202ms/epoch - 14ms/step
# Epoch 22/500
# 14/14 - 0s - loss: 0.0803 - val_loss: 0.0777 - 192ms/epoch - 14ms/step
# Epoch 23/500
# 14/14 - 0s - loss: 0.0841 - val_loss: 0.0777 - 192ms/epoch - 14ms/step
# Epoch 24/500
# 14/14 - 0s - loss: 0.0877 - val_loss: 0.0787 - 188ms/epoch - 13ms/step
# Epoch 25/500
# 14/14 - 0s - loss: 0.0797 - val_loss: 0.0765 - 195ms/epoch - 14ms/step
# Epoch 26/500
# 14/14 - 0s - loss: 0.0775 - val_loss: 0.0731 - 207ms/epoch - 15ms/step
# Epoch 27/500
# 14/14 - 0s - loss: 0.0769 - val_loss: 0.0721 - 195ms/epoch - 14ms/step
# Epoch 28/500
# 14/14 - 0s - loss: 0.0778 - val_loss: 0.0716 - 184ms/epoch - 13ms/step
# Epoch 29/500
# 14/14 - 0s - loss: 0.0767 - val_loss: 0.0710 - 194ms/epoch - 14ms/step
# Epoch 30/500
# 14/14 - 0s - loss: 0.0742 - val_loss: 0.0699 - 213ms/epoch - 15ms/step
# Epoch 31/500
# 14/14 - 0s - loss: 0.0729 - val_loss: 0.0686 - 235ms/epoch - 17ms/step
# Epoch 32/500
# 14/14 - 0s - loss: 0.0730 - val_loss: 0.0690 - 208ms/epoch - 15ms/step
# Epoch 33/500
# 14/14 - 0s - loss: 0.0755 - val_loss: 0.0688 - 210ms/epoch - 15ms/step
# Epoch 34/500
# 14/14 - 0s - loss: 0.0742 - val_loss: 0.0688 - 221ms/epoch - 16ms/step
# Epoch 35/500
# 14/14 - 0s - loss: 0.0730 - val_loss: 0.0691 - 228ms/epoch - 16ms/step
# Epoch 36/500
# 14/14 - 0s - loss: 0.0723 - val_loss: 0.0687 - 212ms/epoch - 15ms/step
# Epoch 37/500
# 14/14 - 0s - loss: 0.0720 - val_loss: 0.0683 - 195ms/epoch - 14ms/step
# Epoch 38/500
# 14/14 - 0s - loss: 0.0721 - val_loss: 0.0682 - 193ms/epoch - 14ms/step
# Epoch 39/500
# 14/14 - 0s - loss: 0.0723 - val_loss: 0.0683 - 198ms/epoch - 14ms/step
# Epoch 40/500
# 14/14 - 0s - loss: 0.0721 - val_loss: 0.0684 - 198ms/epoch - 14ms/step
# Epoch 41/500
# 14/14 - 0s - loss: 0.0720 - val_loss: 0.0687 - 198ms/epoch - 14ms/step
# Epoch 42/500
# 14/14 - 0s - loss: 0.0717 - val_loss: 0.0685 - 190ms/epoch - 14ms/step
# Epoch 43/500
# 14/14 - 0s - loss: 0.0716 - val_loss: 0.0683 - 186ms/epoch - 13ms/step
# Epoch 44/500
# 14/14 - 0s - loss: 0.0716 - val_loss: 0.0681 - 197ms/epoch - 14ms/step
# Epoch 45/500
# 14/14 - 0s - loss: 0.0716 - val_loss: 0.0679 - 193ms/epoch - 14ms/step
# Epoch 46/500
# 14/14 - 0s - loss: 0.0719 - val_loss: 0.0678 - 202ms/epoch - 14ms/step
# Epoch 47/500
# 14/14 - 0s - loss: 0.0716 - val_loss: 0.0678 - 200ms/epoch - 14ms/step
# Epoch 48/500
# 14/14 - 0s - loss: 0.0720 - val_loss: 0.0679 - 189ms/epoch - 13ms/step
# Epoch 49/500
# 14/14 - 0s - loss: 0.0722 - val_loss: 0.0683 - 196ms/epoch - 14ms/step
# Epoch 50/500
# 14/14 - 0s - loss: 0.0715 - val_loss: 0.0684 - 194ms/epoch - 14ms/step
# Epoch 51/500
# 14/14 - 0s - loss: 0.0712 - val_loss: 0.0683 - 237ms/epoch - 17ms/step
# Epoch 52/500
# 14/14 - 0s - loss: 0.0711 - val_loss: 0.0685 - 195ms/epoch - 14ms/step
# Epoch 53/500
# 14/14 - 0s - loss: 0.0710 - val_loss: 0.0683 - 198ms/epoch - 14ms/step
# Epoch 54/500
# 14/14 - 0s - loss: 0.0710 - val_loss: 0.0680 - 190ms/epoch - 14ms/step
# Epoch 55/500
# 14/14 - 0s - loss: 0.0711 - val_loss: 0.0680 - 192ms/epoch - 14ms/step
# Epoch 56/500
# 14/14 - 0s - loss: 0.0710 - val_loss: 0.0677 - 211ms/epoch - 15ms/step
# Epoch 57/500
# 14/14 - 0s - loss: 0.0713 - val_loss: 0.0677 - 191ms/epoch - 14ms/step
# Epoch 58/500
# 14/14 - 0s - loss: 0.0710 - val_loss: 0.0675 - 197ms/epoch - 14ms/step
# Epoch 59/500
# 14/14 - 0s - loss: 0.0715 - val_loss: 0.0674 - 218ms/epoch - 16ms/step
# Epoch 60/500
# 14/14 - 0s - loss: 0.0717 - val_loss: 0.0676 - 225ms/epoch - 16ms/step
# Epoch 61/500
# 14/14 - 0s - loss: 0.0727 - val_loss: 0.0676 - 203ms/epoch - 14ms/step
# Epoch 62/500
# 14/14 - 0s - loss: 0.0732 - val_loss: 0.0689 - 196ms/epoch - 14ms/step
# Epoch 63/500
# 14/14 - 0s - loss: 0.0716 - val_loss: 0.0694 - 187ms/epoch - 13ms/step
# Epoch 64/500
# 14/14 - 0s - loss: 0.0709 - val_loss: 0.0681 - 192ms/epoch - 14ms/step
# Epoch 65/500
# 14/14 - 0s - loss: 0.0707 - val_loss: 0.0675 - 197ms/epoch - 14ms/step
# Epoch 66/500
# 14/14 - 0s - loss: 0.0706 - val_loss: 0.0677 - 207ms/epoch - 15ms/step
# Epoch 67/500
# 14/14 - 0s - loss: 0.0710 - val_loss: 0.0681 - 192ms/epoch - 14ms/step
# Epoch 68/500
# 14/14 - 0s - loss: 0.0707 - val_loss: 0.0680 - 199ms/epoch - 14ms/step
# Epoch 69/500
# 14/14 - 0s - loss: 0.0706 - val_loss: 0.0682 - 191ms/epoch - 14ms/step
# Epoch 70/500
# 14/14 - 0s - loss: 0.0704 - val_loss: 0.0686 - 200ms/epoch - 14ms/step
# Epoch 71/500
# 14/14 - 0s - loss: 0.0703 - val_loss: 0.0684 - 201ms/epoch - 14ms/step
# Epoch 72/500
# 14/14 - 0s - loss: 0.0702 - val_loss: 0.0682 - 190ms/epoch - 14ms/step
# Epoch 73/500
# 14/14 - 0s - loss: 0.0702 - val_loss: 0.0683 - 186ms/epoch - 13ms/step
# Epoch 74/500
# 14/14 - 0s - loss: 0.0701 - val_loss: 0.0674 - 194ms/epoch - 14ms/step
# Epoch 75/500
# 14/14 - 0s - loss: 0.0711 - val_loss: 0.0677 - 199ms/epoch - 14ms/step
# Epoch 76/500
# 14/14 - 0s - loss: 0.0704 - val_loss: 0.0675 - 205ms/epoch - 15ms/step
# Epoch 77/500
# 14/14 - 0s - loss: 0.0710 - val_loss: 0.0680 - 190ms/epoch - 14ms/step
# Epoch 78/500
# 14/14 - 0s - loss: 0.0705 - val_loss: 0.0684 - 187ms/epoch - 13ms/step
# Epoch 79/500
# 14/14 - 0s - loss: 0.0701 - val_loss: 0.0688 - 195ms/epoch - 14ms/step
# Epoch 80/500
# 14/14 - 0s - loss: 0.0699 - val_loss: 0.0683 - 196ms/epoch - 14ms/step
# Epoch 81/500
# 14/14 - 0s - loss: 0.0698 - val_loss: 0.0681 - 205ms/epoch - 15ms/step
# Epoch 82/500
# 14/14 - 0s - loss: 0.0698 - val_loss: 0.0683 - 191ms/epoch - 14ms/step
# Epoch 83/500
# 14/14 - 0s - loss: 0.0697 - val_loss: 0.0675 - 195ms/epoch - 14ms/step
# Epoch 84/500
# 14/14 - 0s - loss: 0.0703 - val_loss: 0.0679 - 191ms/epoch - 14ms/step
# Epoch 85/500
# 14/14 - 0s - loss: 0.0697 - val_loss: 0.0675 - 203ms/epoch - 14ms/step
# Epoch 86/500
# 14/14 - 0s - loss: 0.0700 - val_loss: 0.0675 - 251ms/epoch - 18ms/step
# Epoch 87/500
# 14/14 - 0s - loss: 0.0703 - val_loss: 0.0675 - 218ms/epoch - 16ms/step
# Epoch 88/500
# 14/14 - 0s - loss: 0.0708 - val_loss: 0.0685 - 193ms/epoch - 14ms/step
# Epoch 89/500
# 14/14 - 0s - loss: 0.0699 - val_loss: 0.0688 - 195ms/epoch - 14ms/step
# Epoch 90/500
# 14/14 - 0s - loss: 0.0697 - val_loss: 0.0693 - 194ms/epoch - 14ms/step
# Epoch 91/500
# 14/14 - 0s - loss: 0.0695 - val_loss: 0.0683 - 202ms/epoch - 14ms/step
# Epoch 92/500
# 14/14 - 0s - loss: 0.0692 - val_loss: 0.0679 - 186ms/epoch - 13ms/step
# Epoch 93/500
# 14/14 - 0s - loss: 0.0694 - val_loss: 0.0682 - 190ms/epoch - 14ms/step
# Epoch 94/500
# 14/14 - 0s - loss: 0.0691 - val_loss: 0.0677 - 191ms/epoch - 14ms/step
# Epoch 95/500
# 14/14 - 0s - loss: 0.0697 - val_loss: 0.0680 - 195ms/epoch - 14ms/step
# Epoch 96/500
# 14/14 - 0s - loss: 0.0691 - val_loss: 0.0676 - 204ms/epoch - 15ms/step
# Epoch 97/500
# 14/14 - 0s - loss: 0.0697 - val_loss: 0.0676 - 194ms/epoch - 14ms/step
# Epoch 98/500
# 14/14 - 0s - loss: 0.0699 - val_loss: 0.0677 - 226ms/epoch - 16ms/step
# Epoch 99/500
# 14/14 - 0s - loss: 0.0701 - val_loss: 0.0688 - 191ms/epoch - 14ms/step
# Epoch 100/500
# 14/14 - 0s - loss: 0.0693 - val_loss: 0.0693 - 198ms/epoch - 14ms/step
# Epoch 101/500
# 14/14 - 0s - loss: 0.0690 - val_loss: 0.0693 - 202ms/epoch - 14ms/step
# Epoch 102/500
# 14/14 - 0s - loss: 0.0688 - val_loss: 0.0688 - 218ms/epoch - 16ms/step
# Epoch 103/500
# 14/14 - 0s - loss: 0.0686 - val_loss: 0.0683 - 193ms/epoch - 14ms/step
# Epoch 104/500
# 14/14 - 0s - loss: 0.0687 - val_loss: 0.0688 - 195ms/epoch - 14ms/step
# Epoch 105/500
# 14/14 - 0s - loss: 0.0686 - val_loss: 0.0687 - 192ms/epoch - 14ms/step
# Epoch 106/500
# 14/14 - 0s - loss: 0.0684 - val_loss: 0.0687 - 204ms/epoch - 15ms/step
# Epoch 107/500
# 14/14 - 0s - loss: 0.0683 - val_loss: 0.0685 - 190ms/epoch - 14ms/step
# Epoch 108/500
# 14/14 - 0s - loss: 0.0682 - val_loss: 0.0683 - 189ms/epoch - 13ms/step
# Epoch 109/500
# 14/14 - 0s - loss: 0.0681 - val_loss: 0.0687 - 188ms/epoch - 13ms/step

# %% [markdown]
# ## Predictions of the year 2019

# %%
# make a prediction
yhat = model.predict(test_X)
#Convert from 3D to 2D
n_features = 7
test_X = test_X.reshape((test_X.shape[0], n_days*n_features))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -6:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -6:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 7.966

# %% [markdown]
# #### Prediciton plots

# %%
pyplot.plot(inv_yhat, label = 'Prediction')
pyplot.plot(inv_y, label = 'Real')
pyplot.title("Previsione con Ammonia e PM 2.5")
pyplot.xlabel('Days') 
pyplot.ylabel('PM10') 
pyplot.legend()
pyplot.show()

# %% [markdown]
# prediction with 2020

# %%
#Moggio = table.loc[table.loc[:,"NameStation"]=="Moggio",:]

Moggio = table.loc[:,["Date","PM10","PM25","Ammonia","Wind_speed","Quadrante","Temperature","Rainfall"]]
Moggio = Moggio.dropna(how="any")
Moggio = Moggio.reset_index()
Moggio = Moggio.iloc[:,:] # this is the differrence!!!!
Moggio.head()
values = Moggio.iloc[:,2:].values
# ensure all data is float
values = values.astype('float32') #cast in float 32 bit per evitare problemi
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
n_days = 5 #Memoria della NN
reframed = series_to_supervised(scaled, n_days, 1) # info of the past 5 days to determine next (1) day
# drop columns we don't want to predict (we therefore keep Ammonia)
reframed.drop(reframed.columns[[36, 37,38,39,40,41]], axis=1, inplace=True)


# split into train and test sets
values = reframed.values
n_features = 7 # number of variables, including the one to be predicted
n_train_days = 1312 # we train using only the first year
train = values[:n_train_days, :]
test = values[n_train_days:, :] # we test using all successive years 
# split into input and outputs
n_obs = n_days * n_features
train_X, train_y = train[:, :n_obs], train[:, -1]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
# reshape from 2D to 3D
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1312, 35) 1312 (1312,)
# (1312, 5, 7) (1312,) (715, 5, 7) (715,)

# %%
# make a prediction
yhat = model.predict(test_X)
#Convert from 3D to 2D
test_X = test_X.reshape((test_X.shape[0], n_days*n_features))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -6:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -6:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 7.285

# %%
pyplot.plot(inv_yhat[-365:], label = 'Prediction')
pyplot.plot(inv_y[-365:], label = 'Real')
pyplot.title("Previsione con Ammonia e PM 2.5")
pyplot.xlabel('Days') 
pyplot.ylabel('PM10') 
pyplot.legend()
pyplot.show()
