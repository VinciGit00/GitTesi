# %%
import matplotlib
from matplotlib import pyplot
from pandas import DataFrame
from pandas import Series
from pandas import concat
from pandas import read_csv
from pandasql import sqldf
from pandas import datetime
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from math import sqrt
# be able to save images on server
matplotlib.use('Agg')
# Out:
# /var/folders/m5/1xdj8pfj2cs3wjpc41g9qkj80000gn/T/ipykernel_9151/1460567149.py:8: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %% [markdown]
# ## Air quality anno 2014-2020

# %%
airQuality = read_csv("AirQuality1420.csv")
airQuality.drop(["CO", "NO2", "NOx", "Ozone",
                "Sulfur_dioxide"], axis=1, inplace=True)


airQuality
# Out:
#       IDStation                   NameStation        Date  Ammonia  PM10  PM25
# 0           677  Cremona Via Fatebenefratelli  2014-01-01      2.5  73.0  66.0
# 1           677  Cremona Via Fatebenefratelli  2014-01-02      4.5  51.0   NaN
# 2           677  Cremona Via Fatebenefratelli  2014-01-03      1.6  47.0  46.0
# 3           677  Cremona Via Fatebenefratelli  2014-01-04      1.1  42.0  38.0
# 4           677  Cremona Via Fatebenefratelli  2014-01-05      0.7  21.0  21.0
# ...         ...                           ...         ...      ...   ...   ...
# 2543        677  Cremona Via Fatebenefratelli  2020-12-27      7.3  35.0  31.0
# 2544        677  Cremona Via Fatebenefratelli  2020-12-28      6.7   NaN  20.0
# 2545        677  Cremona Via Fatebenefratelli  2020-12-29      6.9  46.0  45.0
# 2546        677  Cremona Via Fatebenefratelli  2020-12-30      7.3  62.0  60.0
# 2547        677  Cremona Via Fatebenefratelli  2020-12-31      7.7  59.0  57.0
#
# [2548 rows x 6 columns]

# %% [markdown]
# ## Weather 2014-2015

# %%
w14_15 = read_csv("Weather14-15.csv")
w16_17 = read_csv("Weather16-17.csv")
w18_19 = read_csv("Weather18-19.csv")
w20    = read_csv("Weather20.csv")

# %% [markdown]
# ### Unione delle tabelle del meteo

# %%
weather = sqldf('''
                SELECT *
                FROM w14_15
                UNION
                 SELECT *
                FROM w16_17
                UNION
                SELECT *
                FROM w18_19
                UNION
                SELECT *
                FROM w20  
                ''')
a = 730+726+729+366
print("Check per vedere se le dimensioni tornano: "+str(a))
weather
# Out:
# Check per vedere se le dimensioni tornano: 2551
#       IDStation                   NameStation        Date  Wind_speed  \
# 0           677  Cremona Via Fatebenefratelli  2014-01-01         NaN
# 1           677  Cremona Via Fatebenefratelli  2014-01-02         NaN
# 2           677  Cremona Via Fatebenefratelli  2014-01-03         NaN
# 3           677  Cremona Via Fatebenefratelli  2014-01-04         NaN
# 4           677  Cremona Via Fatebenefratelli  2014-01-05         NaN
# ...         ...                           ...         ...         ...
# 2546        677  Cremona Via Fatebenefratelli  2020-12-27    0.045293
# 2547        677  Cremona Via Fatebenefratelli  2020-12-28    0.212185
# 2548        677  Cremona Via Fatebenefratelli  2020-12-29    0.451607
# 2549        677  Cremona Via Fatebenefratelli  2020-12-30    0.634008
# 2550        677  Cremona Via Fatebenefratelli  2020-12-31    0.360339
#
#       Wind_direction  Temperature  Relative_humidity  Global_radiation  \
# 0                NaN     2.233333          88.487500         56.600000
# 1                NaN     3.658333          96.533333          9.841667
# 2                NaN     4.029167          99.662500         12.537500
# 3                NaN     4.691667          99.900000          4.316667
# 4                NaN     5.412500          99.900000          7.887500
# ...              ...          ...                ...               ...
# 2546             4.0     0.952083          92.725000         58.411806
# 2547           321.0     0.277465          99.597183          8.239437
# 2548           275.0    -0.663889          99.598611         28.943750
# 2549           253.0     1.771528          99.568056         29.232639
# 2550           277.0     0.025000          98.976389         59.245139
#
#       Rainfall
# 0          0.0
# 1          0.6
# 2          1.0
# 3         16.6
# 4         19.2
# ...        ...
# 2546       0.0
# 2547       0.0
# 2548       0.0
# 2549       0.0
# 2550       0.0
#
# [2551 rows x 9 columns]

# %% [markdown]
# # Join per creare la tabella che ci interessa

# %%
final = sqldf('''SELECT *
         FROM airQuality AS a JOIN weather AS w
         ON a.Date =  w.Date
         ''')

print("Dimensioni qualità aria: "+str(airQuality.shape))
print("Dimensioni meteo: "+str(weather.shape))
print("Dimensioni matrice finale"+str(final.shape))
final
# Out:
# Dimensioni qualità aria: (2548, 6)
# Dimensioni meteo: (2551, 9)
# Dimensioni matrice finale(2548, 15)
#       IDStation                   NameStation        Date  Ammonia  PM10  \
# 0           677  Cremona Via Fatebenefratelli  2014-01-01      2.5  73.0
# 1           677  Cremona Via Fatebenefratelli  2014-01-02      4.5  51.0
# 2           677  Cremona Via Fatebenefratelli  2014-01-03      1.6  47.0
# 3           677  Cremona Via Fatebenefratelli  2014-01-04      1.1  42.0
# 4           677  Cremona Via Fatebenefratelli  2014-01-05      0.7  21.0
# ...         ...                           ...         ...      ...   ...
# 2543        677  Cremona Via Fatebenefratelli  2020-12-27      7.3  35.0
# 2544        677  Cremona Via Fatebenefratelli  2020-12-28      6.7   NaN
# 2545        677  Cremona Via Fatebenefratelli  2020-12-29      6.9  46.0
# 2546        677  Cremona Via Fatebenefratelli  2020-12-30      7.3  62.0
# 2547        677  Cremona Via Fatebenefratelli  2020-12-31      7.7  59.0
#
#       PM25  IDStation                   NameStation        Date  Wind_speed  \
# 0     66.0        677  Cremona Via Fatebenefratelli  2014-01-01         NaN
# 1      NaN        677  Cremona Via Fatebenefratelli  2014-01-02         NaN
# 2     46.0        677  Cremona Via Fatebenefratelli  2014-01-03         NaN
# 3     38.0        677  Cremona Via Fatebenefratelli  2014-01-04         NaN
# 4     21.0        677  Cremona Via Fatebenefratelli  2014-01-05         NaN
# ...    ...        ...                           ...         ...         ...
# 2543  31.0        677  Cremona Via Fatebenefratelli  2020-12-27    0.045293
# 2544  20.0        677  Cremona Via Fatebenefratelli  2020-12-28    0.212185
# 2545  45.0        677  Cremona Via Fatebenefratelli  2020-12-29    0.451607
# 2546  60.0        677  Cremona Via Fatebenefratelli  2020-12-30    0.634008
# 2547  57.0        677  Cremona Via Fatebenefratelli  2020-12-31    0.360339
#
#       Wind_direction  Temperature  Relative_humidity  Global_radiation  \
# 0                NaN     2.233333          88.487500         56.600000
# 1                NaN     3.658333          96.533333          9.841667
# 2                NaN     4.029167          99.662500         12.537500
# 3                NaN     4.691667          99.900000          4.316667
# 4                NaN     5.412500          99.900000          7.887500
# ...              ...          ...                ...               ...
# 2543             4.0     0.952083          92.725000         58.411806
# 2544           321.0     0.277465          99.597183          8.239437
# 2545           275.0    -0.663889          99.598611         28.943750
# 2546           253.0     1.771528          99.568056         29.232639
# 2547           277.0     0.025000          98.976389         59.245139
#
#       Rainfall
# 0          0.0
# 1          0.6
# 2          1.0
# 3         16.6
# 4         19.2
# ...        ...
# 2543       0.0
# 2544       0.0
# 2545       0.0
# 2546       0.0
# 2547       0.0
#
# [2548 rows x 15 columns]

# %% [markdown]
# # Export del file

# %%
import os

# %%
os.chdir('/Users/marcovinciguerra/Github/GitTesi/Python/Cremona')

# %%
final.to_csv('RisultatiCremona.csv')

# %%
os.chdir('/Users/marcovinciguerra/Github/GitTesi/Python/Cremona/QuadrantiCremona')
final.to_csv('RisultatiCremona.csv')
